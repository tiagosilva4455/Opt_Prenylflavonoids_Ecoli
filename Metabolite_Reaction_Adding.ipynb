# %%
import cobra
from cobra import Reaction, Metabolite

# %%
model= cobra.io.read_sbml_model("iML1515.xml")
model
# Out:
# <Model iML1515 at 0x7fe05bc52970>

# %%
for metabolite in model.metabolites:
        print(metabolite.name)
        print(metabolite.id)
        print()
# Out:
# Octanoate (protein bound)
# octapb_c
#
# L Cystine C6H12N2O4S2
# cysi__L_e
#
# Dihydroxyacetone phosphate
# dhap_c
#
# 1-(5-Phosphoribosyl)-ATP
# prbatp_c
#
# 10-Formyltetrahydrofolate
# 10fthf_c
#
# Butanal C4H8O
# btal_c
#
# 6-Phospho-beta-D-glucosyl-(1,4)-D-glucose
# 6pgg_c
#
# CO2 CO2
# co2_e
#
# 2-Oxoglutarate
# akg_e
#
# Guanosine
# gsn_e
#
# Pyridoxal 5'-phosphate
# pydx5p_c
#
# 3-keto-L-gulonate-6-phosphate
# 3dhgulnp_c
#
# Glycerophosphoserine
# g3ps_c
#
# ADP-L-glycero-D-manno-heptose
# adphep_LD_c
#
# L-Lyxose
# lyx__L_c
#
# Deoxyinosine
# din_p
#
# D-Glycerate 2-phosphate
# 2pg_c
#
# Putrescine
# ptrc_p
#
# Maltose C12H22O11
# malt_p
#
# Phenylpropanoate
# pppn_p
#
# Aerobactin minus Fe3
# arbtn_p
#
# Heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA
# hphhlipa_c
#
# Phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA
# phphhlipa_c
#
# 3-Phospho-D-glyceroyl phosphate
# 13dpg_c
#
# Two disacharide linked murein units, tripeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain)
# murein3px4p_p
#
# 3,4-Dihydroxyphenylacetaldehyde
# 34dhpac_e
#
# 1-octadec-11-enoyl-sn-glycerol 3-phosphate
# 1odec11eg3p_c
#
# 1,2-Diacyl-sn-glycerol (dioctadec-11-enoyl, n-C18:1)
# 12dgr181_p
#
# N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid
# anhgm_e
#
# 1-(5-Phosphoribosyl)-AMP
# prbamp_c
#
# Fused thiol:disulfide interchange protein (reduced)
# dsbdrd_c
#
# Copper
# cu2_p
#
# Sulpholactaldehyde
# sla_c
#
# 1,4-alpha-D-glucan
# 14glucan_p
#
# Geranyl diphosphate
# grdp_c
#
# Riboflavin C17H20N4O6
# ribflv_p
#
# Dimethyl sulfide
# dms_e
#
# Phosphatidylglycerophosphate (ditetradec-7-enoyl, n-C14:1)
# pgp141_c
#
# L Cystine C6H12N2O4S2
# cysi__L_c
#
# 2-(Formamido)-N1-(5-phospho-D-ribosyl)acetamidine
# fpram_c
#
# D-Fructose 1-phosphate
# f1p_c
#
# Periplasmic protein disulfide isomerase I (reduced)
# dsbard_p
#
# L-Threonine
# thr__L_c
#
# Deoxycytidine
# dcyt_p
#
# 2-Dehydro-3-deoxy-D-gluconate
# 2ddglcn_c
#
# Fumarate
# fum_p
#
# L-Galactonate
# galctn__L_e
#
# Biotin
# btn_e
#
# Pyridoxine
# pydxn_p
#
# Octadecenoate (n-C18:1)
# ocdcea_e
#
# 7-cyano-7-carbaguanine
# preq0_c
#
# L-Tyrosine
# tyr__L_p
#
# DTDP-4-dehydro-6-deoxy-D-glucose
# dtdp4d6dg_c
#
# N-Acetylmuramate
# acmum_e
#
# D-Mannose
# man_p
#
# Adenosylcobalamin
# adocbl_e
#
# IscU with bound [2Fe-2S] cluster
# iscu_2fe2s_c
#
# Fructoselysine Phosphate
# frulysp_c
#
# DUMP C9H11N2O8P
# dump_p
#
# Novobiocin
# novbcn_e
#
# Fe-enterobactin
# feenter_e
#
# (enterobacterial common antigen)x4 undecaprenyl-diphosphate
# eca4und_p
#
# Gamma-glutamyl-gamma aminobutyric acid
# gg4abut_c
#
# Flavodoxin reduced
# flxr_c
#
# 1,2-dihexadecanoyl-sn-glycerol 3-phosphate
# pa160_c
#
# Lactose C12H22O11
# lcts_c
#
# Aerobactin minus Fe3
# arbtn_e
#
# CDP-1,2-dihexadec-9-enoylglycerol
# cdpdhdec9eg_c
#
# Arsenite
# aso3_c
#
# L-Prolinylglycine
# progly_c
#
# 3-Oxohexadecanoyl-CoA
# 3ohdcoa_c
#
# Cardiolipin (tetrahexadec-9-enoyl, n-C16:1)
# clpn161_p
#
# 1-dodecanoyl-sn-glycerol 3-phosphate
# 1ddecg3p_p
#
# L-Glutamine
# gln__L_e
#
# Coprogen unloaded (no Fe(III))
# cpgn_un_e
#
# Calcium
# ca2_p
#
# Trehalose
# tre_e
#
# IscS with bound sulfur
# iscssh_c
#
# D-Glyceraldehyde
# glyald_c
#
# D-Alanyl-D-alanine
# alaala_e
#
# Novobiocin
# novbcn_p
#
# 3-Oxohexanoyl-[acyl-carrier protein]
# 3ohexACP_c
#
# Glycerophosphoglycerol
# g3pg_c
#
# ?-D-ribose-1-methylphosphonate-5-triphosphate
# rpntp_c
#
# Adenosylcobalamin
# adocbl_c
#
# 3-oxo-cis-dodec-5-enoyl-[acyl-carrier protein]
# 3ocddec5eACP_c
#
# GMP-N-?-(N-?-acetyl lysine methyl ester) 5'-phosphoramidate
# gmplys_c
#
# Alpha-D-Ribose 5-phosphate
# r5p_c
#
# Cardiolipin (tetradodecanoyl, n-C12:0)
# clpn120_p
#
# L-Idonate
# idon__L_e
#
# 2-Oxoglutarate
# akg_c
#
# Thiocyanate
# tcynt_c
#
# Acyl phosphatidylglycerol (n-C14:1)
# apg141_c
#
# Acetate
# ac_c
#
# Decanoate (n-C10:0)
# dca_c
#
# Protoheme C34H30FeN4O4
# pheme_e
#
# L-Citrulline
# citr__L_c
#
# (S)-3-Hydroxyoctadecanoyl-CoA
# 3hodcoa_c
#
# D-Allose
# all__D_e
#
# Calcium
# ca2_e
#
# Fe2+ mitochondria
# fe2_p
#
# 2,5-Diketo-3-deoxy-D-gluconate
# dkdglcn_c
#
# N,N'-diacetylchitobiose
# chtbs_p
#
# 3-(4-Hydroxyphenyl)pyruvate
# 34hpp_c
#
# Fusidic acid
# fusa_p
#
# 1-O-methyl-Beta-D-glucuronate
# metglcur_c
#
# D-Glucose 1-phosphate
# g1p_e
#
# Deoxyuridine
# duri_c
#
# Undecaprenyl diphosphate
# udcpdp_p
#
# Silver
# ag_e
#
# Phosphoenolpyruvate
# pep_c
#
# Beta-Alanine
# ala_B_c
#
# H+
# h_c
#
# 1,2-ditetradec-7-enoyl-sn-glycerol 3-phosphate
# pa141_c
#
# Nitrite
# no2_e
#
# CDP-1,2-didodecanoylglycerol
# cdpdddecg_c
#
# D-Ribose
# rib__D_c
#
# D-Tagatose 6-phosphate
# tag6p__D_c
#
# 2-Deoxy-D-ribose 1-phosphate
# 2dr1p_c
#
# Reduced glutathione
# gthrd_c
#
# Phosphatidylethanolamine (ditetradecanoyl, n-C14:0)
# pe140_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0)
# 2agpg120_c
#
# 3-(2,3-Dihydroxyphenyl)propanoate
# dhpppn_c
#
# 2-tetradecanoyl-sn-glycerol 3-phosphate
# 2tdecg3p_p
#
# L-Alanine
# ala__L_e
#
# D-Glucose 6-phosphate
# g6p_e
#
# Acetoacetyl-ACP
# actACP_c
#
# 2-octadecanoyl-sn-glycerol 3-phosphate
# 2odecg3p_c
#
# Hexadecenoate (n-C16:1)
# hdcea_c
#
# Hexadecenoyl-CoA (n-C16:1CoA)
# hdcoa_c
#
# Acetyl phosphate
# actp_c
#
# 2-Phosphoglycolate
# 2pglyc_c
#
# (O16 antigen)x4 core oligosaccharide lipid A
# o16a4colipa_e
#
# N-Acetyl-D-glucosamine 6-phosphate
# acgam6p_c
#
# Sn-Glycero-3-phosphocholine
# g3pc_c
#
# Thiamine diphosphate
# thmpp_c
#
# 5,6-Dimethylbenzimidazole
# dmbzid_c
#
# L-Valine
# val__L_p
#
# XTP
# xtp_c
#
# Undecaprenol-diphosphate-glucose
# udcpgl_c
#
# Methylphosphonic acid
# mepn_c
#
# Phosphonate
# ppt_p
#
# Methylphosphonic acid
# mepn_p
#
# Cadmium
# cd2_c
#
# Pyruvate
# pyr_p
#
# Thiocyanate
# tcynt_p
#
# Nickel
# ni2_c
#
# N-Acetylanthranilate
# acanth_c
#
# L-Cystathionine
# cyst__L_c
#
# Sulfur dioxide
# so2_p
#
# Phenethylamine
# peamn_p
#
# Methanesulfonate
# mso3_e
#
# Manganese
# mn2_c
#
# DUTP C9H11N2O14P3
# dutp_c
#
# Two linked disacharide pentapeptide murein units (uncrosslinked, middle of chain)
# murein5p5p_p
#
# 6,7-Dimethyl-8-(1-D-ribityl)lumazine
# dmlz_c
#
# Pantetheine 4'-phosphate
# pan4p_c
#
# 1,2-dioctadec-11-enoyl-sn-glycerol 3-phosphate
# pa181_c
#
# L-Threonine O-3-phosphate
# thrp_e
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1)
# 2agpg181_p
#
# ADPribose C15H21N5O14P2
# adprib_c
#
# Octanoate (n-C8:0)
# octa_c
#
# Quinolinate
# quln_c
#
# Tetradecenoyl-CoA (n-C14:1CoA)
# tdecoa_c
#
# 1-octadecanoyl-sn-glycerol 3-phosphate
# 1odecg3p_p
#
# 1-deoxy-D-xylulose
# dxyl_c
#
# 4,5-dihydroxy-2,3-pentanedione
# dhptd_c
#
# Thymine C5H6N2O2
# thym_p
#
# L-alanine-L-glutamate
# LalaLglu_e
#
# Molybdopterin guanine dinucleotide
# mocogdp_c
#
# KDO(2)-lipid (A)
# lipa_c
#
# (2R,4S)-2-methyl-2,3,3,4-tetrahydroxytetrahydrofuran
# mththf_c
#
# Siroheme C42H36FeN4O16
# sheme_c
#
# SufBCD with bound [2Fe-2S] cluster
# sufbcd_2fe2s_c
#
# D-Allose
# all__D_p
#
# L-methionine-R-sulfoxide
# metsox_R__L_e
#
# Tungsten bispterin cofactor
# bwco_c
#
# Protoheme C34H30FeN4O4
# pheme_p
#
# H2O H2O
# h2o_p
#
# Fluoride
# f_p
#
# Hexadecanoate (n-C16:0)
# hdca_p
#
# D-Fructose
# fru_c
#
# Alpha-D-Galactose 1-phosphate
# gal1p_p
#
# Sn-Glycero-3-phosphoethanolamine
# g3pe_e
#
# DIMP C10H12N4O7P
# dimp_p
#
# Glycerol 3-phosphate
# glyc3p_c
#
# Crotonobetaine
# ctbt_p
#
# 1,6-anhydrous-N-Acetylmuramyl-tripeptide
# anhm3p_c
#
# (S)-2-Aceto-2-hydroxybutanoate
# 2ahbut_c
#
# Cardiolipin (tetratetradecanoyl, n-C14:0)
# clpn140_p
#
# Two linked disacharide pentapeptide and tetrapeptide murein units (uncrosslinked, middle of chain)
# murein5p4p_p
#
# L-Serine
# ser__L_c
#
# Trans-Oct-2-enoyl-[acyl-carrier protein]
# toct2eACP_c
#
# Cardiolipin (tetratetradec-7-enoyl, n-C14:1)
# clpn141_p
#
# 1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)
# 12dgr180_p
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:0)
# 2agpe140_p
#
# UMP C9H11N2O9P
# ump_c
#
# 5'-deoxyribose
# 5drib_c
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C12:0)
# 2agpe120_c
#
# 4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol
# 4c2me_c
#
# 1-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1)
# 1agpg181_p
#
# Oxalyl-CoA
# oxalcoa_c
#
# Ureidoacrylate peracid
# uracp_c
#
# 7-aminomethyl-7-deazaguanine
# preq1_c
#
# Bis-molybdenum cofactor
# bmoco_c
#
# Hexadecanoyl-phosphate (n-C16:1)
# hdceap_c
#
# Adenine
# ade_e
#
# Methylphosphonic acid
# mepn_e
#
# Bis-molybdopterin mono-guanine dinucleotide
# bmoco1gdp_c
#
# L-Rhamnose
# rmn_e
#
# Fluoride
# f_e
#
# 3-Phospho-D-glycerate
# 3pg_c
#
# Isoprimeverose
# iprimv_c
#
# 2-Dehydro-L-gulonate
# 2dhguln_c
#
# Pseudouridine
# psuri_c
#
# CTP C9H12N3O14P3
# ctp_c
#
# DADP C10H12N5O9P2
# dadp_c
#
# 2-Dehydro-3-deoxy-D-gluconate
# 2ddglcn_e
#
# Xanthine
# xan_c
#
# D-Xylulose 5-phosphate
# xu5p__D_c
#
# L-Aspartate 4-semialdehyde
# aspsa_c
#
# Glycine betaine
# glyb_e
#
# Xanthosine
# xtsn_c
#
# 2-phospho-4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol
# 2p4c2me_c
#
# D-Glucarate
# glcr_e
#
# (R)-S-Lactoylglutathione
# lgt__S_c
#
# Allantoin
# alltn_e
#
# Hydrogen cyanide
# cyan_c
#
# D-Fructose 6-phosphate
# f6p_e
#
# D-Glucosamine 1-phosphate
# gam1p_c
#
# Copper
# cu2_e
#
# Zinc
# zn2_e
#
# Uracil
# ura_e
#
# Flavin adenine dinucleotide reduced
# fadh2_c
#
# Dihydroneopterin monophosphate
# dhpmp_c
#
# 1,5-Diaminopentane
# 15dap_p
#
# Inorganic triphosphate
# pppi_c
#
# L-Lysine
# lys__L_e
#
# Cyanate
# cynt_c
#
# L-Xylulose 5-phosphate
# xu5p__L_c
#
# L-ascorbate-6-phosphate
# ascb6p_c
#
# N-acetylmuramate 6-phosphate
# acmum6p_c
#
# Octadecanoate (n-C18:0)
# ocdca_e
#
# Glycolate C2H3O3
# glyclt_c
#
# Propanoyl phosphate
# ppap_c
#
# 2-hydroxy-6-ketononatrienedioate
# hkntd_c
#
# P1,P4-Bis(5'-guanosyl) tetraphosphate
# gp4g_c
#
# D-Allose
# all__D_c
#
# N-Acetylneuraminate
# acnam_p
#
# Sucrose C12H22O11
# sucr_p
#
# D-Glucose 6-phosphate
# g6p_p
#
# Glycine betaine
# glyb_c
#
# GMP C10H12N5O8P
# gmp_e
#
# Phenylacetyl-CoA
# phaccoa_c
#
# Butyrate (n-C4:0)
# but_e
#
# (R)-Pantothenate
# pnto__R_p
#
# Isethionic acid
# isetac_p
#
# AMP C10H12N5O7P
# amp_p
#
# KDO(2)-lipid IV(A) with palmitoleoyl
# kdo2lipid4p_c
#
# Dihydromonapterin-triphosphate
# dhmptp_c
#
# Co2+
# cobalt2_e
#
# Cob(I)alamin
# cbl1_c
#
# Beta D-Galactose
# gal_bD_p
#
# D-Alanyl-D-alanine
# alaala_p
#
# Formaldehyde
# fald_p
#
# Uridine
# uri_p
#
# Trans-Hex-2-enoyl-[acyl-carrier protein]
# thex2eACP_c
#
# Octadecenoate (n-C18:1)
# ocdcea_p
#
# L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine
# LalaDgluMdapDala_e
#
# Trans-3-cis-9-palmitoleoyl-[acyl-carrier protein]
# t3c9palmeACP_c
#
# Heptosyl-kdo2-lipidA
# hlipa_c
#
# DIMP C10H12N4O7P
# dimp_c
#
# Octadecenoyl-CoA (n-C18:1CoA)
# odecoa_c
#
# Cyclopropane phosphatidylethanolamine (dihexadec-9,10-cyclo-anoyl, n-C16:0 cyclo)
# cpe160_c
#
# Cys Gly C5H10N2O3S
# cgly_c
#
# Phospho-heptosyl-heptosyl-kdo2-lipidA
# phhlipa_c
#
# Applipoprotein
# alpp_p
#
# Lipoprotein
# lpp_p
#
# 5-Methylthio-D-ribose
# 5mtr_p
#
# 1-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:1)
# 1agpe181_p
#
# 6-deoxy-6-sulphofructose
# sf_c
#
# L-Fucose
# fuc__L_c
#
# Gamma-hydroxybutyrate
# ghb_c
#
# 4-Aminobutanal
# 4abutn_c
#
# Acetyl-CoA
# accoa_c
#
# L-Arginine
# arg__L_c
#
# L-alanine-L-glutamate
# LalaLglu_p
#
# LL-2,6-Diaminoheptanedioate
# 26dap_LL_c
#
# Trimethylamine
# tma_e
#
# (2R,4S)-2-methyl-2,4-dihydroxydihydrofuran-3-one
# mdhdhf_c
#
# Octanoyl-CoA (n-C8:0CoA)
# occoa_c
#
# MoaD Protein with bound AMP
# moadamp_c
#
# L-Lyxose
# lyx__L_e
#
# (2R,4S)-2-methyl-2,3,3,4-tetrahydroxytetrahydrofuran
# mththf_p
#
# GTP C10H12N5O14P3
# gtp_e
#
# 3-Hydroxybenzoate
# 3hbz_c
#
# D-Mannose 6-phosphate
# man6p_p
#
# Cellobiose
# cellb_e
#
# ?-D-ribose-1-methylphosphonate 5-phosphate
# prpmn_c
#
# UDP-N-acetylmuramate
# uamr_c
#
# Ferrichrome minus Fe(III)
# fecrm_un_c
#
# L-Aspartate
# asp__L_c
#
# Cold adapted KDO(2)-lipid (A)
# lipa_cold_p
#
# D-Sorbitol
# sbt__D_e
#
# N-Acetyl-L-glutamate 5-semialdehyde
# acg5sa_c
#
# L-Arginine
# arg__L_e
#
# Two linked disacharide tripeptide murein units (uncrosslinked, middle of chain)
# murein3p3p_p
#
# Hexanoyl-ACP (n-C6:0ACP)
# hexACP_c
#
# Deoxyguanosine
# dgsn_e
#
# Spermidine
# spmd_e
#
# Phosphatidylglycerol (dihexadec-9-enoyl, n-C16:1)
# pg161_c
#
# Shikimate
# skm_c
#
# Phosphatidylethanolamine (didodecanoyl, n-C12:0)
# pe120_p
#
# N2-Succinyl-L-glutamate 5-semialdehyde
# sucgsa_c
#
# IMP C10H11N4O8P
# imp_c
#
# L-tartrate
# tartr__L_c
#
# Propanal
# ppal_p
#
# Core oligosaccharide lipid A diphosphate
# colipap_p
#
# O2 O2
# o2_c
#
# 2,3-Dihydroxypropane-1-sulfonate
# dhps_p
#
# Octadecenoate (n-C18:1)
# ocdcea_c
#
# H+
# h_p
#
# (S)-3-Hydroxybutanoyl-CoA
# 3hbcoa_c
#
# Succinate
# succ_p
#
# D-Galactose
# gal_p
#
# 2-hydroxycyclohepta-1,4,6-triene-1-carboxylate
# 2hptcl_c
#
# Phenylpyruvate
# phpyr_c
#
# Sedoheptulose 1,7-bisphosphate
# s17bp_c
#
# 4-Amino-2-methyl-5-phosphomethylpyrimidine
# 4ampm_c
#
# Maltotetraose
# maltttr_p
#
# Pyridoxine
# pydxn_c
#
# D-Methionine
# met__D_c
#
# D-Fructose
# fru_e
#
# N2-Succinyl-L-ornithine
# sucorn_c
#
# Pyruvate
# pyr_e
#
# DTMP C10H13N2O8P
# dtmp_p
#
# 2,3-dihydroxicinnamic acid
# dhcinnm_c
#
# Arsenate
# aso4_c
#
# N-Acetyl-D-galactosamine
# acgal_p
#
# DTDP-4-amino-4,6-dideoxy-D-galactose
# dtdp4addg_c
#
# Undecaprenyl-diphospho N-acetylglucosamine-N-acetylmannosaminuronate-N-acetamido-4,6-dideoxy-D-galactose
# unagamuf_c
#
# L-Idonate
# idon__L_c
#
# Maltotriose C18H32O16
# malttr_e
#
# D-Cysteine
# cys__D_e
#
# Phenylacetic acid
# pac_c
#
# Phosphatidylglycerophosphate (dihexadecanoyl, n-C16:0)
# pgp160_p
#
# Carbamate
# cbm_c
#
# 5-Methyltetrahydrofolate
# 5mthf_c
#
# 3-(3-hydroxy-phenyl)propionate
# 3hpppn_e
#
# Phosphonate
# ppt_e
#
# Pimeloyl-[acyl-carrier protein] methyl ester
# pmeACP_c
#
# Crotonobetaine
# ctbt_c
#
# Nicotinamide adenine dinucleotide
# nad_c
#
# Sodium
# na1_p
#
# D-Glyceraldehyde
# glyald_p
#
# Alpha-D-Ribose 1-phosphate
# r1p_c
#
# Cis-tetradec-7-enoyl-[acyl-carrier protein] (n-C14:1)
# tdeACP_c
#
# 5-Methylthioadenosine
# 5mta_c
#
# (2,3-Dihydroxybenzoyl)adenylate
# 23dhba_c
#
# L-Valine
# val__L_e
#
# Dodecanoyl-CoA (n-C12:0CoA)
# ddcacoa_c
#
# GDP-4-oxo-L-fucose
# gdpofuc_c
#
# D-Ribulose
# rbl__D_c
#
# Choline C5H14NO
# chol_c
#
# L-Histidine
# his__L_p
#
# Maltose C12H22O11
# malt_c
#
# L-Homoserine
# hom__L_e
#
# Nitrite
# no2_p
#
# DCMP C9H12N3O7P
# dcmp_e
#
# DGMP C10H12N5O7P
# dgmp_e
#
# S-Ribosyl-L-homocysteine
# rhcys_c
#
# Cadmium
# cd2_e
#
# D-Methionine
# met__D_e
#
# Gamma-butyrobetaine
# gbbtn_c
#
# Formaldehyde
# fald_c
#
# N-Methyltryptophan
# Nmtrp_c
#
# 2',3'-Cyclic CMP
# 23ccmp_e
#
# Dimethyl sulfoxide
# dmso_e
#
# UDPglucose
# udpg_e
#
# Inner core oligosaccharide lipid A (E coli)
# icolipa_c
#
# N-Acetyl-D-galactosamine
# acgal_e
#
# D-Ribose 1,5-bisphosphate
# r15bp_c
#
# Sn-Glycero-3-phosphoethanolamine
# g3pe_p
#
# D-Carnitine
# crn__D_p
#
# 3-oxo-cis-vacc-11-enoyl-[acyl-carrier protein]
# 3ocvac11eACP_c
#
# Cadmium
# cd2_p
#
# (R)-3-Hydroxyoctadecanoyl-[acyl-carrier protein]
# 3hoctaACP_c
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:1)
# 2agpe181_p
#
# D Arabinose C5H10O5
# arab__D_c
#
# 2 Deoxy D glucose 6 phosphate C6H11O8P
# 2doxg6p_c
#
# Octadecanoate (n-C18:0)
# ocdca_c
#
# Three disacharide linked murein units (tetrapeptide crosslinked tetrapeptide (A2pm->D-ala), one uncrosslinked tetrapaptide) (middle of chain)
# murein4px4p4p_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0)
# 2agpg180_c
#
# 2-tetradec-7-enoyl-sn-glycerol 3-phosphate
# 2tdec7eg3p_p
#
# Sulfoacetate
# sulfac_c
#
# Magnesium
# mg2_c
#
# 4-Deoxy-L-threo-5-hexosulose uronate
# dt5hsu_c
#
# Acetyl-maltose
# acmalt_c
#
# Malonyl-CoA methyl ester
# malcoame_c
#
# Selenite
# slnt_p
#
# Glutaryl-[acyl-carrier protein] methyl ester
# gmeACP_c
#
# 1-hexadecanoyl-sn-glycerol 3-phosphate
# 1hdecg3p_c
#
# 3-Hydroxyglutaryl-[acyl-carrier protein] methyl ester
# hgmeACP_c
#
# Phosphatidylglycerol (ditetradec-7-enoyl, n-C14:1)
# pg141_p
#
# Molybdopterin
# mpt_c
#
# Tetracycline
# ttrcyc_p
#
# P-Cresol
# 4crsol_c
#
# Acyl phosphatidylglycerol (n-C18:1)
# apg181_c
#
# Pyridoxal
# pydx_p
#
# 2-succinyl-5-enolpyruvyl-6-hydroxy-3-cyclohexene-1-carboxylate
# 2sephchc_c
#
# Cellobiose
# cellb_p
#
# ADP C10H12N5O10P2
# adp_c
#
# 2,3-Dihydroxypropane-1-sulfonate
# dhps_c
#
# L-Malate
# mal__L_c
#
# Urea CH4N2O
# urea_c
#
# D-Glucosamine
# gam_c
#
# Mercaptoethanol
# mercpeth_c
#
# Pseudouridine
# psuri_p
#
# 5-Amino-6-(5'-phosphoribosylamino)uracil
# 5apru_c
#
# Glyceraldehyde 3-phosphate
# g3p_c
#
# Poly-?-1,6-N-acetyl-D-glucosamine
# puacgam_p
#
# Ethanol
# etoh_c
#
# (R)-Pantothenate
# pnto__R_c
#
# (S)-NADPHX
# nadphx__S_c
#
# Guanosine 3'-diphosphate 5'-triphosphate
# gdptp_c
#
# (S)-3-Hydroxydodecanoyl-CoA
# 3hddcoa_c
#
# Sulfite
# so3_c
#
# L-Methionine
# met__L_c
#
# 5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide
# aicar_c
#
# D-Altronate
# altrn_c
#
# Thymidine C10H14N2O5
# thymd_e
#
# Nicotinamide
# ncam_c
#
# 5-amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxylate
# 5aizc_c
#
# D-Fructuronate
# fruur_c
#
# O-Succinylbenzoate
# sucbz_c
#
# Acetate
# ac_e
#
# Glyoxylate
# glx_c
#
# Potassium
# k_e
#
# 2,3-Bis(3-hydroxytetradecanoyl)-beta-D-glucosaminyl 1-phosphate
# lipidX_c
#
# Acyl phosphatidylglycerol (n-C14:0)
# apg140_c
#
# 1,4-Dihydroxy-2-naphthoate
# dhna_c
#
# Ethanol
# etoh_e
#
# L-Galactonate
# galctn__L_c
#
# 1D-myo-Inositol 1-phosphate
# mi1p__D_c
#
# L-Proline
# pro__L_e
#
# Taurine C2H7NO3S
# taur_e
#
# Cold adapted KDO(2)-lipid (A)
# lipa_cold_e
#
# Tungsten bispterin cofactor guanine dinucleotide
# bwcogdp_c
#
# Protoporphyrin
# ppp9_c
#
# 5,6,7,8-tetrahydropteridine
# thptdn_c
#
# D-Gluconate
# glcn_p
#
# Guanine
# gua_p
#
# 5-amino-1-(5-phospho-D-ribosyl)imidazole
# air_c
#
# 6-Phospho-D-gluconate
# 6pgc_c
#
# 6-hydroxymethyl-dihydropterin pyrophosphate
# 6hmhptpp_c
#
# UDPgalactose
# udpgal_c
#
# Ammonium
# nh4_c
#
# Fe(III)hydoxamate, unloaded
# fe3hox_un_p
#
# Xanthosine 5'-phosphate
# xmp_e
#
# Pyridoxamine
# pydam_c
#
# Sulfite
# so3_p
#
# L-Rhamnulose 1-phosphate
# rml1p_c
#
# D-Glucosamine 6-phosphate
# gam6p_e
#
# Cytidine
# cytd_c
#
# D-Glucuronate 1-phosphate
# glcur1p_e
#
# Nicotinate
# nac_e
#
# Trans-Dec-2-enoyl-[acyl-carrier protein]
# tdec2eACP_c
#
# Thymine C5H6N2O2
# thym_c
#
# D-Galactonate
# galctn__D_c
#
# O-Succinylbenzoyl-CoA
# sbzcoa_c
#
# D-Galactose
# gal_e
#
# 3-Hydroxypropanoate
# 3hpp_p
#
# Pimeloyl-[acyl-carrier protein]
# pimACP_c
#
# Methylisocitrate
# micit_c
#
# 3?,12?-dihydroxy-7-oxo-5?-cholan-24-oate
# dhcholn_c
#
# N-Acetylneuraminate
# acnam_c
#
# Cis-hexadec-9-enoyl-[acyl-carrier protein] (n-C16:1)
# hdeACP_c
#
# Dihydroxyacetone
# dha_e
#
# Phosphate
# pi_c
#
# N-Acetyl-D-mannosamine
# acmana_p
#
# N(omega)-(L-Arginino)succinate
# argsuc_c
#
# Aminoacetaldehyde
# aacald_c
#
# Gamma-butyrobetaine
# gbbtn_p
#
# Ammonium
# nh4_p
#
# 4-Aminobutanoate
# 4abut_p
#
# Chorismate
# chor_c
#
# L-Homoserine
# hom__L_c
#
# Cobinamide
# cbi_p
#
# Thymidine C10H14N2O5
# thymd_c
#
# D-Mannitol
# mnl_p
#
# Beta D-Galactose
# gal_bD_e
#
# (R)-Propane-1,2-diol
# 12ppd__R_c
#
# DGDP C10H12N5O10P2
# dgdp_c
#
# L-Glutamate 1-semialdehyde
# glu1sa_c
#
# 5'-Deoxyadenosine
# dad_5_c
#
# IMP C10H11N4O8P
# imp_p
#
# L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate
# LalaDgluMdap_p
#
# Citrate
# cit_e
#
# D-Glucuronate 1-phosphate
# glcur1p_p
#
# L-Leucine
# leu__L_e
#
# Heptosyl-heptosyl-kdo2-lipidA
# hhlipa_c
#
# Shikimate
# skm_p
#
# D-carnitinyl-CoA
# crnDcoa_c
#
# Zinc
# zn2_c
#
# Ubiquinol-8
# q8h2_c
#
# D-Alanine
# ala__D_e
#
# Two disacharide linked murein units, pentapeptide corsslinked tripeptide (A2pm->A2pm) (middle of chain)
# murein5px3p_p
#
# Fe2+ mitochondria
# fe2_e
#
# Shikimate
# skm_e
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:1)
# 2agpe161_p
#
# 3-Oxodecanoyl-[acyl-carrier protein]
# 3odecACP_c
#
# Galactitol
# galt_e
#
# 5-Dehydro-D-gluconate
# 5dglcn_e
#
# Undecaprenyl-diphospho-N-acetylglucosamine-N-acetylmannosaminuronate
# unagamu_c
#
# N1-(5-Phospho-alpha-D-ribosyl)-5,6-dimethylbenzimidazole
# 5prdmbz_c
#
# 1-tetradecanoyl-sn-glycerol 3-phosphate
# 1tdecg3p_c
#
# 1,2-ditetradecanoyl-sn-glycerol 3-phosphate
# pa140_c
#
# CDP-1,2-ditetradec-7-enoylglycerol
# cdpdtdec7eg_c
#
# Cyanate
# cynt_e
#
# Selenodiglutathione
# dgslnt_c
#
# Citrate
# cit_p
#
# Xanthine
# xan_p
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:0)
# 2agpe140_c
#
# Tellurite
# teo2_c
#
# SufSE with bound sulfur
# sufsesh_c
#
# L-Tyrosine
# tyr__L_c
#
# D-Fructuronate
# fruur_p
#
# Gamma-glutamyl-putrescine
# ggptrc_c
#
# L-Cysteine
# cys__L_c
#
# 4-aminobenzoyl-glutamate
# 4abzglu_e
#
# L-2-Amino-3-oxobutanoate
# 2aobut_c
#
# Sulfoacetate
# sulfac_e
#
# 2-dehydro-3-deoxy-L-rhamnonate
# lkdr_c
#
# Phosphatidylserine (dihexadecanoyl, n-C16:0)
# ps160_c
#
# 4-(1-D-Ribitylamino)-5-aminouracil
# 4r5au_c
#
# 3-hydroxybenzoyl-CoA
# 3hbzcoa_c
#
# D-Glucosamine
# gam_e
#
# Phosphatidylglycerol (didodecanoyl, n-C12:0)
# pg120_c
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1)
# 2agpe141_p
#
# L-Methionine
# met__L_e
#
# D-Xylulose
# xylu__D_c
#
# 4-Hydroxybenzoate
# 4hbz_c
#
# S-Adenosyl-L-methionine
# amet_c
#
# Dihydrosirohydrochlorin
# dscl_c
#
# Hexanoate (n-C6:0)
# hxa_c
#
# Hydrogen sulfide
# h2s_c
#
# O-Phospho-4-hydroxy-L-threonine
# phthr_c
#
# N-Acetyl-D-mannosamine
# acmana_e
#
# 3-Oxooctanoyl-CoA
# 3oocoa_c
#
# N8-Acetylspermidine
# n8aspmd_c
#
# N-Acetyl-D-glucosamine 1-phosphate
# acgam1p_c
#
# L-Ascorbate
# ascb__L_e
#
# Maltose C12H22O11
# malt_e
#
# Thymidine C10H14N2O5
# thymd_p
#
# Manganese
# mn2_e
#
# DITP(4-)
# ditp_c
#
# UDP-2,3-bis(3-hydroxytetradecanoyl)glucosamine
# u23ga_c
#
# 2,3-diaminopropionate
# 23dappa_e
#
# UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate-D-alanine
# um4p_c
#
# 3-Hydroxypropanal
# 3hppnl_c
#
# Cesium ion
# cs1_e
#
# Glycerol 2-phosphate
# glyc2p_c
#
# Tungsten binding cofactor
# wco_c
#
# Undecaprenyl phosphate-4-amino-4-formyl-L-arabinose
# uLa4fn_c
#
# KDO(2)-lipid (A)
# lipa_p
#
# D-Glucose
# glc__D_c
#
# Zinc
# zn2_p
#
# Dihydromonapterin
# dhmpt_c
#
# D-Erythrose 4-phosphate
# e4p_c
#
# Minocycline
# mincyc_p
#
# Mercury  charged 2  Hg
# hg2_c
#
# D-Mannose 1-phosphate
# man1p_c
#
# 2'-(5''-triphosphoribosyl)-3'-dephospho-CoA
# 2tpr3dpcoa_c
#
# Branching glycogen
# bglycogen_c
#
# Sulphoquinovose
# sq_c
#
# 6-deoxy-6-sulphofructose 1-phosphate
# sfp_c
#
# L-Tryptophan
# trp__L_c
#
# Sulphoquinovose
# sq_e
#
# Fused thiol:disulfide interchange protein (oxidized)
# dsbdox_c
#
# O-Acetyl-L-serine
# acser_c
#
# L-Prolinylglycine
# progly_e
#
# Phenylhydantoin
# 5phdt_c
#
# L-Lysine
# lys__L_c
#
# ADPglucose C16H23N5O15P2
# adpglc_c
#
# 3-Oxo-glutaryl-[acyl-carrier protein] methyl ester
# ogmeACP_c
#
# 3-Hydroxypimeloyl-[acyl-carrier protein] methyl ester
# hpmeACP_c
#
# DUDP C9H11N2O11P2
# dudp_c
#
# 2-Succinyl-6-hydroxy-2,4-cyclohexadiene-1-carboxylate
# 2shchc_c
#
# D-4'-Phosphopantothenate
# 4ppan_c
#
# SufSE sulfur acceptor complex
# sufse_c
#
# 1-deoxy-D-xylulose 5-phosphate
# dxyl5p_c
#
# Cesium ion
# cs1_p
#
# 2,3-Dihydroxybenzoate
# 23dhb_c
#
# D-Mannose
# man_e
#
# 2-C-methyl-D-erythritol 2,4-cyclodiphosphate
# 2mecdp_c
#
# ATP C10H12N5O13P3
# atp_c
#
# N-Acetyl-D-mannosamine
# acmana_c
#
# L-Ribulose
# rbl__L_c
#
# Deoxycytidine
# dcyt_e
#
# L-fuculose
# fcl__L_c
#
# Orotate C5H3N2O4
# orot_e
#
# Adenosine-GDP-cobinamide
# agdpcbi_c
#
# Indole
# indole_c
#
# D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate
# eig3p_c
#
# Hydrogen
# h2_e
#
# Meso-2,6-Diaminoheptanedioate
# 26dap__M_c
#
# UDP-3-O-(3-hydroxytetradecanoyl)-N-acetylglucosamine
# u3aga_c
#
# NMN C11H14N2O8P
# nmn_e
#
# Thiamin
# thm_c
#
# 5,6,7,8-Tetrahydrofolate
# thf_c
#
# D-Mannose 6-phosphate
# man6p_e
#
# Orotidine 5'-phosphate
# orot5p_c
#
# Generic ferrioxamine-Fe-III
# feoxam_c
#
# H+
# h_e
#
# Cytosine
# csn_p
#
# Aminoacetone
# aact_c
#
# L-Glutamine
# gln__L_p
#
# Glycerol
# glyc_p
#
# Cytidine
# cytd_p
#
# L-Threonine
# thr__L_p
#
# L-Asparagine
# asn__L_e
#
# L-Fucose
# fuc__L_p
#
# 5-phosphoribosyl-5-carboxyaminoimidazole
# 5caiz_c
#
# Dihydroneopterin
# dhnpt_c
#
# Pyridoxamine 5'-phosphate
# pyam5p_c
#
# Tetradecanoate (n-C14:0)
# ttdca_p
#
# N-Acetyl-D-glucosamine
# acgam_c
#
# L-Methionine Sulfoxide
# metsox_S__L_p
#
# L-Malate
# mal__L_p
#
# Phenylacetaldehyde
# pacald_p
#
# (enterobacterial common antigen)x4 core oligosaccharide lipid A
# eca4colipa_p
#
# Lactose C12H22O11
# lcts_e
#
# Butanoyl-CoA
# btcoa_c
#
# Trimethylamine N-oxide
# tmao_p
#
# UDP-3-O-(3-hydroxytetradecanoyl)-D-glucosamine
# u3hga_c
#
# Tetradecanoyl-CoA (n-C14:0CoA)
# tdcoa_c
#
# UDP-D-glucuronate
# udpglcur_e
#
# Hexanoate (n-C6:0)
# hxa_p
#
# Two disacharide linked murein units, tripeptide crosslinked tripeptide (A2pm->A2pm) (middle of chain)
# murein3px3p_p
#
# (R)-3-hydroxy-cis-palm-9-eoyl-[acyl-carrier protein]
# 3hcpalm9eACP_c
#
# Decanoate (n-C10:0)
# dca_e
#
# Molybdate
# mobd_p
#
# Maltose 6'-phosphate
# malt6p_c
#
# L-Methionine
# met__L_p
#
# D-Glucose 1-phosphate
# g1p_p
#
# L-Serine
# ser__L_p
#
# 3-oxo-cis-palm-9-eoyl-[acyl-carrier protein]
# 3ocpalm9eACP_c
#
# 2-dodecanoyl-sn-glycerol 3-phosphate
# 2ddecg3p_c
#
# N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide
# anhgm3p_c
#
# 1-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:1)
# 1agpe161_p
#
# Octanoate (n-C8:0)
# octa_p
#
# Glucosyl-galactosyl-glucosyl-inner core oligosaccharide lipid A
# ggagicolipa_c
#
# N,N'-diacetylchitobiose
# chtbs_e
#
# Dopamine
# dopa_e
#
# Propionate (n-C3:0)
# ppa_p
#
# Malonate semialdehyde
# msa_c
#
# O-Phospho-L-serine
# pser__L_p
#
# Selenite
# slnt_c
#
# Isethionic acid
# isetac_e
#
# Ferric 2,3-dihydroxybenzoylserine
# fe3dhbzs_p
#
# Coprogen
# cpgn_c
#
# Butyryl-ACP (n-C4:0ACP)
# butACP_c
#
# 1-O-methyl-Beta-D-glucuronate
# metglcur_e
#
# Cu+
# cu_e
#
# Deoxyguanosine
# dgsn_c
#
# 1-hexadec-9-enoyl-sn-glycerol 3-phosphate
# 1hdec9eg3p_c
#
# CDP-1,2-ditetradecanoylglycerol
# cdpdtdecg_c
#
# Phosphatidylethanolamine (dioctadec-11-enoyl, n-C18:1)
# pe181_c
#
# DTTP C10H13N2O14P3
# dttp_c
#
# Phosphatidylethanolamine (didodecanoyl, n-C12:0)
# pe120_c
#
# Butyrate (n-C4:0)
# but_c
#
# Phosphatidylethanolamine (dihexadecanoyl, n-C16:0)
# pe160_p
#
# Phosphatidylglycerol (dihexadecanoyl, n-C16:0)
# pg160_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0)
# 2agpg160_c
#
# L-Glutamyl-tRNA(Glu)
# glutrna_c
#
# 1,2-didodecanoyl-sn-glycerol 3-phosphate
# pa120_p
#
# Adenosine
# adn_e
#
# 3-Oxotetradecanoyl-CoA
# 3otdcoa_c
#
# Dodecanoly-phosphate (n-C12:0)
# ddcap_c
#
# (S)-3-Hydroxyhexadecanoyl-CoA
# 3hhdcoa_c
#
# All-trans-Octaprenyl diphosphate
# octdp_c
#
# Hexadecanoyl-phosphate (n-C16:0)
# hdcap_c
#
# Trans-Cinnamate
# cinnm_c
#
# Trans-Hex-2-enoyl-CoA
# hx2coa_c
#
# Enoylglutaryl-[acyl-carrier protein] methyl ester
# egmeACP_c
#
# UDP-N-acetyl-D-mannosamine
# uacmam_c
#
# Arbutin 6-phosphate
# arbt6p_c
#
# 6-carboxy-5,6,7,8-tetrahydropterin
# cph4_c
#
# Tetradecanoate (n-C14:0)
# ttdca_c
#
# Glycogen C6H10O5
# glycogen_c
#
# IscU with two bound [2Fe-2S] clusters
# iscu_2fe2s2_c
#
# S-Adenosyl-L-homocysteine
# ahcys_c
#
# Pyridoxal
# pydx_c
#
# Trimethylamine
# tma_p
#
# Fe(III)dicitrate
# fe3dcit_e
#
# Tetrahydromonapterin
# thmnp_c
#
# Fe(III)hydoxamate, unloaded
# fe3hox_un_c
#
# D-Lactate
# lac__D_e
#
# Oxidized thioredoxin
# trdox_c
#
# Cis-2-Methylaconitate
# 2mcacn_c
#
# DAMP C10H12N5O6P
# damp_e
#
# 5-Methylthio-D-ribose
# 5mtr_c
#
# (O16 antigen)x4 undecaprenyl diphosphate
# o16a4und_p
#
# E-3-carboxy-2-pentenedioate 6-methyl ester
# aconm_c
#
# Adenosine
# adn_p
#
# C'-(3-Indolyl)-glycerol 3-phosphate
# 3ig3p_c
#
# L-Asparagine
# asn__L_p
#
# Nitrous oxide
# n2o_c
#
# N-Succinyl-LL-2,6-diaminoheptanedioate
# sl26da_c
#
# Mercury  charged 2  Hg
# hg2_e
#
# Deoxyguanosine
# dgsn_p
#
# (R)-3-Hydroxyoctanoyl-[acyl-carrier protein]
# 3hoctACP_c
#
# DCTP C9H12N3O13P3
# dctp_c
#
# Trans-octadec-2-enoyl-[acyl-carrier protein]
# toctd2eACP_c
#
# 2(alpha-D-Mannosyl)-D-glycerate
# manglyc_p
#
# Dimethyl sulfide
# dms_p
#
# Deoxyinosine
# din_c
#
# Hydrogen sulfide
# h2s_p
#
# Protein disulfide isomerase II (oxidized)
# dsbcox_p
#
# Isochorismate
# ichor_c
#
# Cardiolipin (tetrahexadecanoyl, n-C16:0)
# clpn160_p
#
# Cardiolipin (tetraoctadec-11-enoyl, n-C18:1)
# clpn181_p
#
# Generic ferrioxamine-Fe-III
# feoxam_e
#
# Lipoate
# lipoate_e
#
# Phenylacetaldehyde
# pacald_c
#
# Arbutin C12H16O7
# arbt_p
#
# Coproporphyrinogen III
# cpppg3_c
#
# Tetradecanoyl-phosphate (n-C14:1)
# ttdceap_c
#
# Cyclic pyranopterin monophosphate
# cpmp_c
#
# Isethionic acid
# isetac_c
#
# N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide
# anhgm4p_c
#
# 3-Oxohexanoyl-CoA
# 3ohcoa_c
#
# Glucosyl-glucosyl-galactosyl-glucosyl-inner core oligosaccharide lipid A
# gggagicolipa_c
#
# Doxorubicin
# doxrbcn_e
#
# D-Xylonate
# dxylnt_p
#
# D-Serine
# ser__D_e
#
# 2-hydroxycyclohepta-1,4,6-triene-1-carboxyl-CoA
# 2hptcoa_c
#
# Glutaredoxin (reduced)
# grxrd_c
#
# Sulfur dioxide
# so2_e
#
# 2-Oxo-3-hydroxy-4-phosphobutanoate
# ohpb_c
#
# D-Cysteine
# cys__D_c
#
# 1,2-dihexadec-9-enoyl-sn-glycerol 3-phosphate
# pa161_c
#
# D-Ribulose 5-phosphate
# ru5p__D_c
#
# (R)-2,3-Dihydroxy-3-methylbutanoate
# 23dhmb_c
#
# AMP C10H12N5O7P
# amp_e
#
# D-Galacturonate
# galur_c
#
# L-Arabinose
# arab__L_e
#
# Phosphatidylglycerophosphate (ditetradecanoyl, n-C14:0)
# pgp140_c
#
# Superoxide anion
# o2s_c
#
# Phosphatidylglycerophosphate (dihexadec-9-enoyl, n-C16:1)
# pgp161_c
#
# Phosphatidylserine (dioctadecanoyl, n-C18:0)
# ps180_c
#
# L-Lactaldehyde
# lald__L_c
#
# UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate
# ugmd_c
#
# 6-hydroxymethyl dihydropterin
# 6hmhpt_c
#
# Propanoyl-CoA
# ppcoa_c
#
# Phosphatidylethanolamine (ditetradec-7-enoyl, n-C14:1)
# pe141_c
#
# Cyclopropane phosphatidylglycerol (dihexadec-9,10-cyclo-anoyl, n-C16:0 cyclo)
# cpg160_c
#
# Ferrichrome
# fecrm_c
#
# Adenosyl cobinamide
# adocbi_c
#
# L-Isoleucine
# ile__L_p
#
# Acetoacetate
# acac_c
#
# D-Carnitine
# crn__D_e
#
# N-Acetyl-D-mannosamine 6-phosphate
# acmanap_c
#
# NMN C11H14N2O8P
# nmn_p
#
# Phenylpropanoate
# pppn_e
#
# 1,3-Propanediol
# 13ppd_c
#
# Hypoxanthine
# hxan_p
#
# N-(5-Phospho-D-ribosyl)anthranilate
# pran_c
#
# 3-hydroxycinnamic acid
# 3hcinnm_e
#
# Guanosine
# gsn_c
#
# L-methionine-R-sulfoxide
# metsox_R__L_p
#
# Inosine
# ins_c
#
# Trimethylamine N-oxide
# tmao_c
#
# Thiosulfate
# tsul_c
#
# 2',3'-Cyclic GMP
# 23cgmp_p
#
# 2(alpha-D-Mannosyl-6-phosphate)-D-glycerate
# man6pglyc_c
#
# Uracil
# ura_c
#
# L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate
# LalaDgluMdap_e
#
# Choline C5H14NO
# chol_e
#
# Glycine
# gly_e
#
# Oxamate
# oxam_c
#
# Dihydroxyacetone
# dha_p
#
# Cys Gly C5H10N2O3S
# cgly_p
#
# L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine
# LalaDgluMdapDala_c
#
# 8-Amino-7-oxononanoate
# 8aonn_c
#
# 2-hexadecanoyl-sn-glycerol 3-phosphate
# 2hdecg3p_c
#
# Pyridoxine 5'-phosphate
# pdx5p_c
#
# Core oligosaccharide lipid A
# colipa_p
#
# 2,3-Dioxo-L-gulonate
# 23doguln_c
#
# 1-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0)
# 1agpg160_p
#
# Trimethylamine N-oxide
# tmao_e
#
# Core oligosaccharide lipid A
# colipa_e
#
# Glycerol 2-phosphate
# glyc2p_p
#
# 4-aminobenzoyl-glutamate
# 4abzglu_p
#
# Phosphatidylethanolamine (ditetradec-7-enoyl, n-C14:1)
# pe141_p
#
# Acetoacetate
# acac_p
#
# 3-4-Dihydroxyphenylacetate
# 34dhpha_c
#
# Butyrate (n-C4:0)
# but_p
#
# 3,4-Dihydroxyphenylacetaldehyde
# 34dhpac_p
#
# KDO(2)-lipid (A)
# lipa_e
#
# Phosphatidylethanolamine (dioctadec-11-enoyl, n-C18:1)
# pe181_p
#
# 1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 12dgr140_p
#
# 2-hexadecanoyl-sn-glycerol 3-phosphate
# 2hdecg3p_p
#
# D-Gluconate
# glcn_c
#
# 3-Oxoadipyl-CoA
# oxadpcoa_c
#
# Phosphoethanolamine KDO(2)-lipid (A)
# enlipa_e
#
# Nitrous oxide
# n2o_e
#
# Adenylated molybdopterin
# mptamp_c
#
# 3'-Phosphoadenylyl sulfate
# paps_c
#
# Co2+
# cobalt2_c
#
# UTP C9H11N2O15P3
# utp_c
#
# Co2+
# cobalt2_p
#
# (S)-Dihydroorotate
# dhor__S_c
#
# S-Methyl-L-methionine
# mmet_p
#
# Arsenite
# aso3_e
#
# Glycerol
# glyc_e
#
# Adenosine
# adn_c
#
# 4-Methyl-2-oxopentanoate
# 4mop_c
#
# Alpha-D-Galactose 1-phosphate
# gal1p_c
#
# Periplasmic disulfide isomerase/thiol-disulphide oxidase (oxidized)
# dsbgox_p
#
# 2-C-methyl-D-erythritol 4-phosphate
# 2me4p_c
#
# Phosphatidylglycerol (ditetradecanoyl, n-C14:0)
# pg140_p
#
# 7,8-Diaminononanoate
# dann_c
#
# Trehalose
# tre_c
#
# GDP-D-mannose
# gdpmann_c
#
# 2-Hydroxy-3-oxopropanoate
# 2h3oppan_c
#
# Hydroxypyruvate
# hpyr_c
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1)
# 2agpg181_c
#
# Acyl phosphatidylglycerol (n-C12:0)
# apg120_c
#
# Acyl phosphatidylglycerol (n-C16:0)
# apg160_c
#
# Deoxyadenosine
# dad_2_e
#
# N-monoacetylchitobiose 6'-phosphate
# mchtbs6p_c
#
# D-Fructose 1,6-bisphosphate
# fdp_c
#
# Methylglyoxal
# mthgxl_c
#
# L-tartrate
# tartr__L_e
#
# Cobinamide
# cbi_c
#
# Octanoate (n-C8:0)
# octa_e
#
# Thymine C5H6N2O2
# thym_e
#
# GDP C10H12N5O11P2
# gdp_e
#
# L-Rhamnose
# rmn_c
#
# DTMP C10H13N2O8P
# dtmp_c
#
# Dimethyl sulfoxide
# dmso_p
#
# Ferrichrome
# fecrm_p
#
# GDP C10H12N5O11P2
# gdp_p
#
# GDP C10H12N5O11P2
# gdp_c
#
# Inosine
# ins_p
#
# D-Mannose
# man_c
#
# Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-ala-D-glu-meso-2,6-diaminopimeloyl-D-ala-D-ala
# uaagmda_c
#
# 4-Hydroxyphenylacetaldehyde
# 4hoxpacd_e
#
# O-Acetyl-L-serine
# acser_p
#
# Potassium
# k_c
#
# O2 O2
# o2_p
#
# Beta-Alanine
# ala_B_p
#
# Cobinamide
# cbi_e
#
# Tungstate
# tungs_p
#
# L-Carnitine
# crn_e
#
# DTMP C10H13N2O8P
# dtmp_e
#
# Fe2+ mitochondria
# fe2_c
#
# CDP-1,2-dioctadecanoylglycerol
# cdpdodecg_c
#
# Phosphatidylserine (ditetradecanoyl, n-C14:0)
# ps140_c
#
# 1,2-Diacyl-sn-glycerol (dihexadecanoyl, n-C16:0)
# 12dgr160_c
#
# 2-tetradecanoyl-sn-glycerol 3-phosphate
# 2tdecg3p_c
#
# Thiamin
# thm_e
#
# D-Glyceraldehyde
# glyald_e
#
# 1,2-Diacyl-sn-glycerol (dioctadec-11-enoyl, n-C18:1)
# 12dgr181_c
#
# Indole
# indole_e
#
# 2-tetradec-7-enoyl-sn-glycerol 3-phosphate
# 2tdec7eg3p_c
#
# Protein disulfide isomerase II (reduced)
# dsbcrd_p
#
# Bis-molybdopterin guanine dinucleotide
# bmocogdp_c
#
# Magnesium
# mg2_e
#
# Phosphatidylglycerophosphate (dioctadec-11-enoyl, n-C18:1)
# pgp181_p
#
# (2R,4S)-2-methyl-2,3,3,4-tetrahydroxytetrahydrofuran
# mththf_e
#
# (4S)-4-hydroxy-5-phosphonooxypentane-2,3-dione
# dhptdp_c
#
# Orotate C5H3N2O4
# orot_p
#
# L-alanine-D-glutamate
# LalaDglu_p
#
# Cyclic diguanosine monophosphate
# cdigmp_c
#
# Uridine
# uri_c
#
# Deoxyadenosine
# dad_2_c
#
# DATP C10H12N5O12P3
# datp_c
#
# Cholate c
# cholate_c
#
# (S)-3-Hydroxyhexanoyl-CoA
# 3hhcoa_c
#
# 3,4-dihydroxyphenylacetyl-CoA
# 34dphacoa_c
#
# Poly-?-1,6-N-acetyl-D-glucosamine
# puacgam_c
#
# Diphosphate
# ppi_c
#
# Nicotinamide adenine dinucleotide phosphate
# nadp_c
#
# (S)-2-Hydroxyglutarate
# S2hglut_c
#
# Glycolate C2H3O3
# glyclt_p
#
# 1-O-methyl-Beta-D-glucuronate
# metglcur_p
#
# Xanthosine
# xtsn_p
#
# L-Glutamate
# glu__L_c
#
# D-Glucose 1-phosphate
# g1p_c
#
# Fumarate
# fum_c
#
# 2-Oxoglutarate
# akg_p
#
# N2-Acetyl-L-ornithine
# acorn_c
#
# Fructoselysine
# frulys_c
#
# Spermidine
# spmd_c
#
# L-Glutamate 5-semialdehyde
# glu5sa_c
#
# L-Isoleucine
# ile__L_c
#
# Glycerophosphoglycerol
# g3pg_e
#
# 2-Dehydropantoate
# 2dhp_c
#
# Octanoyl-ACP (n-C8:0ACP)
# ocACP_c
#
# Tetradecenoate (n-C14:1)
# ttdcea_p
#
# 3-Dehydroquinate
# 3dhq_c
#
# L-Histidinol phosphate
# hisp_c
#
# Acetoacetyl-CoA
# aacoa_c
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0)
# 2agpe160_c
#
# Sulfate
# so4_e
#
# Heme O C49H56FeN4O5
# hemeO_c
#
# Ornithine
# orn_e
#
# KDO(2)-lipid IV(A)
# kdo2lipid4_p
#
# 4-Aminobutanoate
# 4abut_e
#
# Adenosine thiamine triphosphate
# athtp_c
#
# Galactitol 1-phosphate
# galt1p_c
#
# L-Glutamate
# glu__L_e
#
# Propionate (n-C3:0)
# ppa_c
#
# 3-Oxooctadecanoyl-CoA
# 3ohodcoa_c
#
# 2-Octaprenylphenol
# 2oph_c
#
# Taurine C2H7NO3S
# taur_c
#
# CMP-3-deoxy-D-manno-octulosonate
# ckdo_c
#
# UDP-N-acetylmuramoyl-L-alanyl-D-glutamate
# uamag_c
#
# 2-3-dihydroxybenzoylserine trimer
# 23dhbzs3_c
#
# D-Glucarate
# glcr_c
#
# Dihydropteroate
# dhpt_c
#
# 1-(?-D-sulfoquinovosyl)glycerol
# sqg_c
#
# D-Glycero-D-manno-heptose 7-phosphate
# gmhep7p_c
#
# Flavin adenine dinucleotide oxidized
# fad_p
#
# 2(alpha-D-Mannosyl)-D-glycerate
# manglyc_e
#
# L-Ascorbate
# ascb__L_p
#
# Trans-Octadec-2-enoyl-CoA
# od2coa_c
#
# L-Idonate
# idon__L_p
#
# Urea CH4N2O
# urea_p
#
# L-rhamnonate
# rhmn_c
#
# Carbamoyl phosphate
# cbp_c
#
# Agmatine
# agm_p
#
# 3-Methyl-2-oxobutanoate
# 3mob_c
#
# O-Succinyl-L-homoserine
# suchms_c
#
# Glucosyl-inner core oligosaccharide lipid A
# gicolipa_c
#
# Hepta-acylated KDO(2)-lipid (A)
# halipa_e
#
# Choline C5H14NO
# chol_p
#
# Butanesulfonate
# butso3_c
#
# Deoxycytidine
# dcyt_c
#
# 3-(3-hydroxy-phenyl)propionate
# 3hpppn_p
#
# Trans-Dec-2-enoyl-CoA
# dc2coa_c
#
# Lipoate
# lipoate_p
#
# Myo-Inositol hexakisphosphate
# minohp_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0)
# 2agpg120_p
#
# DCMP C9H12N3O7P
# dcmp_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0)
# 2agpg180_p
#
# 6-Acetyl-D-glucose
# acglc__D_c
#
# (enterobacterial common antigen)x3 undecaprenyl-diphosphate
# eca3und_p
#
# Alpha-D-Ribose 5-phosphate
# r5p_p
#
# 1-Acyl-sn-glycero-3-phosphoethanolamine (n-C12:0)
# 1agpe120_p
#
# Rhamanosyl-N-acetylglucosamyl-undecaprenyl diphosphate
# ragund_c
#
# Oxalate
# oxa_c
#
# Alpha-D-Ribose 5-phosphate
# r5p_e
#
# Nitric oxide
# no_p
#
# O-Acetyl-L-serine
# acser_e
#
# D-Xylonate
# dxylnt_e
#
# Two linked disacharide tetrapeptide murein units (uncrosslinked, middle of chain)
# murein4p4p_p
#
# N-?-acetyl lysine methyl ester
# nalme_c
#
# Manganese
# mn2_p
#
# Trans-Hexadec-2-enoyl-[acyl-carrier protein]
# tpalm2eACP_c
#
# R-3-hydroxypalmitoyl-[acyl-carrier protein]
# 3hpalmACP_c
#
# 1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 12dgr140_c
#
# UDPglucose
# udpg_c
#
# L-Glutamine
# gln__L_c
#
# Phosphatidylglycerophosphate (dihexadecanoyl, n-C16:0)
# pgp160_c
#
# 3-Carboxy-3-hydroxy-4-methylpentanoate
# 3c3hmp_c
#
# Acyl phosphatidylglycerol (n-C16:1)
# apg161_c
#
# Phosphatidylethanolamine (dihexadecanoyl, n-C16:0)
# pe160_c
#
# D-tartrate
# tartr__D_e
#
# Anthranilate
# anth_c
#
# Phosphoethanolamine KDO(2)-lipid (A)
# enlipa_p
#
# Adenosine 3',5'-bisphosphate
# pap_c
#
# Phosphatidylglycerol (dioctadec-11-enoyl, n-C18:1)
# pg181_p
#
# Xanthosine 5'-phosphate
# xmp_c
#
# (R)-2-Hydroxyglutarate
# r2hglut_c
#
# Tetrahydrocurcumin
# thcur_c
#
# Phenylureidoacetic acid
# 5phua_c
#
# L-Isoleucine
# ile__L_e
#
# (R)-NADHX
# nadhx__R_c
#
# 2-Octaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinol
# 2omhmbl_c
#
# Uroporphyrinogen III
# uppg3_c
#
# (S)-3-Hydroxyoctanoyl-CoA
# 3hocoa_c
#
# 1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate
# 2cpr5p_c
#
# Undecaprenyl-diphospho-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# uagmda_c
#
# 5-Dehydro-4-deoxy-D-glucarate
# 5dh4dglc_c
#
# DCMP C9H12N3O7P
# dcmp_c
#
# Cis-3-(3-carboxyethyl)-3,5-cyclohexadiene-1,2-diol
# cechddd_c
#
# 2,5-diketo-D-gluconate
# 25dkglcn_c
#
# L-Histidine
# his__L_e
#
# DGMP C10H12N5O7P
# dgmp_c
#
# Hypoxanthine
# hxan_e
#
# ADP-D-glycero-D-manno-heptose
# adphep_DD_c
#
# 4-Methyl-5-(2-hydroxyethyl)-thiazole
# 4mhetz_c
#
# Hydrogen sulfide
# h2s_e
#
# Sodium
# na1_e
#
# L-Tyrosine
# tyr__L_e
#
# Acetoacetate
# acac_e
#
# 2-Demethylmenaquinone 8
# 2dmmq8_c
#
# 4-amino-4-deoxychorismate
# 4adcho_c
#
# FMN C17H19N4O9P
# fmn_e
#
# L-Cysteine
# cys__L_e
#
# Glycerol 3-phosphate
# glyc3p_e
#
# D-Ribose
# rib__D_p
#
# Meso-2,6-Diaminoheptanedioate
# 26dap__M_e
#
# D-Xylose
# xyl__D_p
#
# 3-hydroxycinnamic acid
# 3hcinnm_c
#
# Myo-Inositol
# inost_p
#
# Phenylpropanoate
# pppn_c
#
# Octadecanoate (n-C18:0)
# ocdca_p
#
# DTDP-4-acetamido-4,6-dideoxy-D-galactose
# dtdp4aaddg_c
#
# Maltohexaose
# malthx_c
#
# Maltopentaose
# maltpt_c
#
# Glycerophosphoserine
# g3ps_e
#
# Trans-Aconitate
# acon_T_c
#
# Guanosine 3  phosphate C10H12N5O8P
# 3gmp_p
#
# Maltotetraose
# maltttr_c
#
# Gamma-butyrobetainyl-CoA
# bbtcoa_c
#
# Deoxyuridine
# duri_p
#
# N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide
# anhgm4p_p
#
# Dodecanoate (n-C12:0)
# ddca_e
#
# Uridine 5''-diphospho-{beta}-4-deoxy-4-amino-L-arabinose
# udpLa4n_c
#
# L-tartrate
# tartr__L_p
#
# Cis-octadec-11-enoyl-[acyl-carrier protein] (n-C18:1)
# octeACP_c
#
# Meso-2,6-Diaminoheptanedioate
# 26dap__M_p
#
# Hepta-acylated core oligosaccharide lipid A (E. coli)
# hacolipa_e
#
# Glutathionylspermidine
# gtspmd_c
#
# O16 antigen undecaprenyl diphosphate
# o16aund_c
#
# O16 antigen undecaprenyl diphosphate
# o16aund_p
#
# (R)-3-Hydroxyhexanoyl-[acyl-carrier protein]
# 3hhexACP_c
#
# Adenosylcobalamin
# adocbl_p
#
# 4-Amino-4-deoxy-L-arabinose modified core oligosaccharide lipid A
# acolipa_p
#
# Butanesulfonate
# butso3_p
#
# L-Cysteine
# cys__L_p
#
# Coprogen unloaded (no Fe(III))
# cpgn_un_c
#
# Phosphatidylserine (dihexadec-9-enoyl, n-C16:1)
# ps161_c
#
# Trans-3-cis-5-dodecenoyl-[acyl-carrier protein]
# t3c5ddeceACP_c
#
# Phosphatidylserine (didodecanoyl, n-C12:0)
# ps120_c
#
# Aerobactin
# arbtn_fe3_p
#
# 1,2-Diacyl-sn-glycerol (dihexadec-9-enoyl, n-C16:1)
# 12dgr161_p
#
# L-Prolinylglycine
# progly_p
#
# Ornithine
# orn_p
#
# 1,2-dioctadec-11-enoyl-sn-glycerol 3-phosphate
# pa181_p
#
# 1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)
# 12dgr120_p
#
# L-Aspartate
# asp__L_p
#
# Pyridoxamine
# pydam_p
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0)
# 2agpe160_p
#
# L-Carnitine
# crn_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0)
# 2agpg140_c
#
# 1-hexadecanoyl-sn-glycerol 3-phosphate
# 1hdecg3p_p
#
# Biotin
# btn_p
#
# L-Proline
# pro__L_p
#
# Tetradecanoyl-phosphate (n-C14:0)
# ttdcap_c
#
# D-Malate
# mal__D_p
#
# CO2 CO2
# co2_p
#
# 5-Dehydro-D-gluconate
# 5dglcn_p
#
# Iron (Fe3+)
# fe3_c
#
# Arbutin C12H16O7
# arbt_e
#
# Methane
# ch4_p
#
# Flavin adenine dinucleotide oxidized
# fad_e
#
# FMN C17H19N4O9P
# fmn_p
#
# 3-hydroxy-5-phosphonooxypentane-2,4-dione
# dhptdd_c
#
# Quinate
# quin_c
#
# Selenate
# sel_p
#
# Enoylpimeloyl-[acyl-carrier protein] methyl ester
# epmeACP_c
#
# 2-hydroxyethyldisulfide
# dtgcl_c
#
# 2,3-diaminopropionate
# 23dappa_c
#
# Cholate c
# cholate_p
#
# Molybdopterin cytosine dinucleotide
# mococdp_c
#
# Doxorubicin
# doxrbcn_p
#
# Dopamine
# dopa_p
#
# L-Alanine
# ala__L_c
#
# Sn-Glycero-3-phosphocholine
# g3pc_p
#
# Bicarbonate
# hco3_c
#
# D-Alanyl-D-alanine
# alaala_c
#
# N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide
# anhgm3p_p
#
# Spermidine
# spmd_p
#
# L-Phenylalanine
# phe__L_c
#
# 1,6-anhydrous-N-Acetylmuramyl-tetrapeptide
# anhm4p_c
#
# 1,5-Diaminopentane
# 15dap_c
#
# Nickel
# ni2_p
#
# D-Serine
# ser__D_c
#
# Undecaprenyl phosphate
# udcpp_p
#
# 5,10-Methylenetetrahydrofolate
# mlthf_c
#
# Xanthosine 5'-phosphate
# xmp_p
#
# Magnesium
# mg2_p
#
# Phenylacetaldehyde
# pacald_e
#
# N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid
# anhgm_c
#
# Farnesyl diphosphate
# frdp_c
#
# Hydrogen cyanide
# cyan_p
#
# (R)-Pantoate
# pant__R_c
#
# L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine
# LalaDgluMdapDala_p
#
# Mercaptopyruvate
# mercppyr_c
#
# Glucosyl-O-acetyl-rhamanosyl-N-acetylglucosamyl-undecaprenyl diphosphate
# garagund_c
#
# D-Glucuronate
# glcur_c
#
# UDPglucose
# udpg_p
#
# Myo-Inositol
# inost_e
#
# Ferric 2,3-dihydroxybenzoylserine
# fe3dhbzs_e
#
# Cytidine
# cytd_e
#
# (O16 antigen)x3 undecaprenyl diphosphate
# o16a3und_p
#
# Sulfoacetate
# sulfac_p
#
# 2-Demethylmenaquinol 8
# 2dmmql8_c
#
# Trans-3-cis-7-myristoleoyl-[acyl-carrier protein]
# t3c7mrseACP_c
#
# Sn-Glycero-3-phosphoethanolamine
# g3pe_c
#
# Copper
# cu2_c
#
# Trans-3-cis-11-vacceoyl-[acyl-carrier protein]
# t3c11vaceACP_c
#
# Thiocyanate
# tcynt_e
#
# Glycolate C2H3O3
# glyclt_e
#
# Phosphatidylglycerol (dioctadecanoyl, n-C18:0)
# pg180_c
#
# (S)-Propane-1,2-diol
# 12ppd__S_e
#
# 1,4-alpha-D-glucan
# 14glucan_c
#
# CDP-1,2-dioctadec-11-enoylglycerol
# cdpdodec11eg_c
#
# 1-Pyrroline-5-carboxylate
# 1pyr5c_c
#
# 1-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0)
# 1agpe160_p
#
# Propionate (n-C3:0)
# ppa_e
#
# Phosphatidylglycerophosphate (didodecanoyl, n-C12:0)
# pgp120_p
#
# Diacetylchitobiose-6-phosphate
# chtbs6p_c
#
# 1-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0)
# 1agpg180_p
#
# N-Acetylmuramate
# acmum_p
#
# Quinate
# quin_p
#
# Maltotriose C18H32O16
# malttr_p
#
# Psicoselysine
# psclys_c
#
# Selenite
# slnt_e
#
# Core oligosaccharide lipid A diphosphate
# colipap_e
#
# Acetaldehyde
# acald_p
#
# MoaD Protein with carboxylate
# moadcoo_c
#
# Glycine
# gly_p
#
# Dehydroglycine
# dhgly_c
#
# Lipoate (protein bound)
# lipopb_c
#
# 2-Isopropylmaleate
# 2ippm_c
#
# D-Serine
# ser__D_p
#
# Fluoride
# f_c
#
# Superoxide anion
# o2s_p
#
# 2',3'-Cyclic UMP
# 23cump_p
#
# 5-O-(1-Carboxyvinyl)-3-phosphoshikimate
# 3psme_c
#
# 3-(Imidazol-4-yl)-2-oxopropyl phosphate
# imacp_c
#
# 3-Carboxy-2-hydroxy-4-methylpentanoate
# 3c2hmp_c
#
# Xanthine
# xan_e
#
# Uridine 5''-diphospho-{beta}-4-deoxy-4-formamido-L-arabinose
# udpLa4fn_c
#
# O-Phospho-L-serine
# pser__L_c
#
# UDP-N-acetyl-D-glucosamine
# uacgam_e
#
# Tetradecenoate (n-C14:1)
# ttdcea_e
#
# 4-Aminobutanoate
# 4abut_c
#
# Trimethylamine
# tma_c
#
# Octadecanoyl-ACP (n-C18:0ACP)
# ocdcaACP_c
#
# Phosphatidylglycerol (dihexadecanoyl, n-C16:0)
# pg160_c
#
# GMP C10H12N5O8P
# gmp_c
#
# 1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)
# 12dgr120_c
#
# UDP-N-acetylmuramoyl-L-alanine
# uama_c
#
# L-Tryptophan
# trp__L_p
#
# Guanine
# gua_c
#
# Lactose C12H22O11
# lcts_p
#
# 1,2-dihexadecanoyl-sn-glycerol 3-phosphate
# pa160_p
#
# Undecaprenyl diphosphate
# udcpdp_c
#
# 2-octadec-11-enoyl-sn-glycerol 3-phosphate
# 2odec11eg3p_c
#
# D-Fructuronate
# fruur_e
#
# D-Glutamate
# glu__D_c
#
# Fructoselysine
# frulys_p
#
# (R)-Propane-1,2-diol
# 12ppd__R_p
#
# D-Fructose 6-phosphate
# f6p_p
#
# 3-Octaprenyl-4-hydroxybenzoate
# 3ophb_c
#
# KDO(2)-lipid IV(A)
# kdo2lipid4_e
#
# Palmitoyl-CoA (n-C16:0CoA)
# pmtcoa_c
#
# DUMP C9H11N2O8P
# dump_e
#
# 3-Dehydroshikimate
# 3dhsk_c
#
# 3  AMP C10H12N5O7P
# 3amp_p
#
# Acetyl-ACP
# acACP_c
#
# Kdo-phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA
# kphphhlipa_c
#
# 5-Phosphoguanylyl(3->5)guanosine
# 5pg35pg_c
#
# Urate C5H4N4O3
# urate_p
#
# UDP-D-galacto-1,4-furanose
# udpgalfur_c
#
# H2O H2O
# h2o_c
#
# Galactosyl-glucosyl-inner core oligosaccharide lipid A
# gagicolipa_c
#
# Fe-enterobactin
# feenter_p
#
# Mercury  charged 2  Hg
# hg2_p
#
# D-Alanine
# ala__D_c
#
# D-Glucarate
# glcr_p
#
# (S)-2-Acetolactate
# alac__S_c
#
# 2-Aminomalonate semialdehyde
# 2amsa_c
#
# Periplasmic protein disulfide isomerase I (oxidized)
# dsbaox_p
#
# Trehalose
# tre_p
#
# 1,2-dihexadec-9-enoyl-sn-glycerol 3-phosphate
# pa161_p
#
# DCDP C9H12N3O10P2
# dcdp_c
#
# IMP C10H11N4O8P
# imp_e
#
# 3,4-dihydroxy-2-butanone 4-phosphate
# db4p_c
#
# Calcium
# ca2_c
#
# Ferroxamine minus Fe(3)
# feoxam_un_p
#
# L-Galactonate
# galctn__L_p
#
# NMN C11H14N2O8P
# nmn_c
#
# Alpha-D-Galactose 1-phosphate
# gal1p_e
#
# Glycine
# gly_c
#
# [2Fe-1S] desulfurated iron-sulfur cluster
# 2fe1s_c
#
# L-alanine-D-glutamate
# LalaDglu_c
#
# Flavodoxin semi oxidized
# flxso_c
#
# Hydrogen peroxide
# h2o2_c
#
# Malonyl CoA C24H33N7O19P3S
# malcoa_c
#
# D-Fructose
# fru_p
#
# D-Xylose
# xyl__D_e
#
# D-Galactonate
# galctn__D_e
#
# D-Galactose
# gal_c
#
# O-Phospho-L-homoserine
# phom_c
#
# D-Glucose
# glc__D_e
#
# Indole
# indole_p
#
# 3-Oxodecanoyl-CoA
# 3odcoa_c
#
# Reduced FMN
# fmnh2_c
#
# Propanal
# ppal_c
#
# UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# ugmda_c
#
# 1,2-Diacyl-sn-glycerol (dihexadec-9-enoyl, n-C16:1)
# 12dgr161_c
#
# Molybdate
# mobd_e
#
# Sn-Glycero-3-phospho-1-inositol
# g3pi_e
#
# Ammonium
# nh4_e
#
# D-tartrate
# tartr__D_c
#
# Sn-Glycero-3-phosphocholine
# g3pc_e
#
# 3-oxo-5,6-dehydrosuberyl-CoA
# 3oxdhscoa_c
#
# 2',3'-Cyclic AMP
# 23camp_p
#
# IDP C10H11N4O11P2
# idp_c
#
# Glutathiolselenolate
# gslnt_c
#
# 2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxypropyl)dihydropteridine triphosphate
# ahdt_c
#
# Undecaprenyl phosphate-4-amino-4-deoxy-L-arabinose
# uLa4n_c
#
# Hexadecanoate (n-C16:0)
# hdca_e
#
# Aminomethylphosphonate
# ampnt_c
#
# Cis-3-(3-carboxyethenyl)-3,5-cyclohexadiene-1,2-diol
# cenchddd_c
#
# Phosphotyrosine
# tyrp_p
#
# Phosphatidylserine (dioctadec-11-enoyl, n-C18:1)
# ps181_c
#
# D-Fructose 6-phosphate
# f6p_c
#
# Phosphatidylglycerophosphate (ditetradecanoyl, n-C14:0)
# pgp140_p
#
# UDP-N-acetyl-D-mannosaminouronate
# uacmamu_c
#
# S-Adenosylmethioninamine
# ametam_c
#
# Hexanoyl-CoA (n-C6:0CoA)
# hxcoa_c
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:1)
# 2agpg141_c
#
# Cyanate
# cynt_p
#
# 3-hydroxycinnamic acid
# 3hcinnm_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1)
# 2agpg161_c
#
# Prephenate
# pphn_c
#
# L Cystine C6H12N2O4S2
# cysi__L_p
#
# Uracil
# ura_p
#
# Formaldehyde
# fald_e
#
# 5-[(5-phospho-1-deoxyribulos-1-ylamino)methylideneamino]-1-(5-phosphoribosyl)imidazole-4-carboxamide
# prlp_c
#
# UDP-N-acetyl-D-glucosamine
# uacgam_p
#
# 2-dehydro-3-deoxy-D-arabinonate
# 2ddara_c
#
# 2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphate
# 2mahmp_c
#
# Sedoheptulose 7-phosphate
# s7p_c
#
# 1-(5-Phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino]imidazole-4-carboxamide
# prfp_c
#
# Three linked disacharide pentapeptide murein units (uncrosslinked, middle of chain)
# murein5p5p5p_p
#
# Nicotinate D-ribonucleotide
# nicrnt_c
#
# Two disacharide linked murein units, tetrapeptide corsslinked tetrapeptide (A2pm->D-ala) (middle of chain)
# murein4px4p_p
#
# Cytosine
# csn_e
#
# Trans-Tetradec-2-enoyl-[acyl-carrier protein]
# tmrs2eACP_c
#
# O2 O2
# o2_e
#
# Phosphatidylethanolamine (dioctadecanoyl, n-C18:0)
# pe180_c
#
# 3-Deoxy-D-manno-octulosonate 8-phosphate
# kdo8p_c
#
# Succinate
# succ_e
#
# L-Serine
# ser__L_e
#
# Cyclopropane phosphatidylglycerol (dioctadec-11,12-cyclo-anoyl, n-C18:0 cyclo)
# cpg180_c
#
# Menaquinol 8
# mql8_c
#
# Phosphatidylglycerol (didodecanoyl, n-C12:0)
# pg120_p
#
# S-Adenosyl-4-methylthio-2-oxobutanoate
# amob_c
#
# Xanthosine
# xtsn_e
#
# Tetradecanoate (n-C14:0)
# ttdca_e
#
# 2-hexadec-9-enoyl-sn-glycerol 3-phosphate
# 2hdec9eg3p_c
#
# 5-Dehydro-D-gluconate
# 5dglcn_c
#
# Chloride
# cl_c
#
# 2-oxepin-2(3H)-ylideneacetyl-CoA
# 2oxpaccoa_c
#
# (S)-Methylmalonyl-CoA
# mmcoa__S_c
#
# (R)-Glycerate
# glyc__R_c
#
# S-Methyl-L-methionine
# mmet_e
#
# Dimethyl sulfide
# dms_c
#
# D-Glucose 6-phosphate
# g6p_c
#
# N1-Acetylspermidine
# N1aspmd_c
#
# Reduced thioredoxin
# trdrd_c
#
# 2-Dehydro-3-deoxy-D-galactonate
# 2dh3dgal_c
#
# 5,10-Methenyltetrahydrofolate
# methf_c
#
# Dodecanoyl-ACP (n-C12:0ACP)
# ddcaACP_c
#
# D-Mannitol 1-phosphate
# mnl1p_c
#
# Agmatine
# agm_c
#
# L-Alanine
# ala__L_p
#
# 5-Phospho-alpha-D-ribose 1-diphosphate
# prpp_c
#
# 2-Hydroxy-6-oxonona-2,4-diene-1,9-dioate
# hkndd_c
#
# D-Galacturonate
# galur_p
#
# D-Allose 6-phosphate
# all6p_c
#
# Allulose 6-phosphate
# allul6p_c
#
# L-Histidinol
# histd_c
#
# Formate
# for_p
#
# Orotate C5H3N2O4
# orot_c
#
# Galactitol
# galt_p
#
# Ferrichrome
# fecrm_e
#
# D-Glucose
# glc__D_p
#
# DAMP C10H12N5O6P
# damp_c
#
# FMN C17H19N4O9P
# fmn_c
#
# D-Malate
# mal__D_e
#
# 3-Oxododecanoyl-CoA
# 3oddcoa_c
#
# L-Phenylalanine
# phe__L_p
#
# Glycerophosphoglycerol
# g3pg_p
#
# Thiosulfate
# tsul_p
#
# TRNA (Glu)
# trnaglu_c
#
# Guanosine 3',5'-bis(diphosphate)
# ppgpp_c
#
# Inosine
# ins_e
#
# Thiamin
# thm_p
#
# Ethanesulfonate
# ethso3_c
#
# Aerobactin
# arbtn_fe3_e
#
# Ubiquinone-8
# q8_c
#
# N-Acetyl-D-glucosamine 1-phosphate
# acgam1p_p
#
# Ornithine
# orn_c
#
# Chloride
# cl_e
#
# Stearoyl-CoA (n-C18:0CoA)
# stcoa_c
#
# 2-Octaprenyl-6-methoxy-1,4-benzoquinol
# 2ombzl_c
#
# Two disacharide linked murein units, pentapeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain)
# murein5px4p_p
#
# Oxidized glutathione
# gthox_e
#
# DAMP C10H12N5O6P
# damp_p
#
# Decanoyl-ACP (n-C10:0ACP)
# dcaACP_c
#
# Guanosine 3  phosphate C10H12N5O8P
# 3gmp_e
#
# Ethanolamine
# etha_c
#
# (R)-3-hydroxy-cis-dodec-5-enoyl-[acyl-carrier protein]
# 3hcddec5eACP_c
#
# Betaine aldehyde
# betald_c
#
# UDP-D-glucuronate
# udpglcur_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0)
# 2agpg140_p
#
# Trans-Dodec-2-enoyl-[acyl-carrier protein]
# tddec2eACP_c
#
# Hexadecanoate (n-C16:0)
# hdca_c
#
# 1-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:0)
# 1agpe180_p
#
# N2-Formyl-N1-(5-phospho-D-ribosyl)glycinamide
# fgam_c
#
# Phosphatidylethanolamine (dioctadecanoyl, n-C18:0)
# pe180_p
#
# 1-Acyl-sn-glycero-3-phosphoglycerol (n-C14:1)
# 1agpg141_p
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:1)
# 2agpe181_c
#
# Trans-Dodec-2-enoyl-CoA
# dd2coa_c
#
# SufBCD scaffold complex
# sufbcd_c
#
# Iminoaspartate
# iasp_c
#
# 3-Hydroxypropanoate
# 3hpp_e
#
# (R)-NADPHX
# nadphx__R_c
#
# 3-Oxo-pimeloyl-[acyl-carrier protein] methyl ester
# opmeACP_c
#
# Methanol
# meoh_p
#
# Tungsten bispterin cofactor mono-guanine dinucleotide
# bwco1gdp_c
#
# Citrate
# cit_c
#
# Shikimate 5-phosphate
# skm5p_c
#
# Oxaloacetate
# oaa_c
#
# Trans-Tetradec-2-enoyl-CoA
# td2coa_c
#
# N-Acetylmethionine
# acmet_c
#
# Adenosine 5'-(3-{5-[(2S)-5-carbamoyl-2-hydroxy-3,4-dihydropyridin-1-yl]-5-deoxy-?-D-ribofuranosyl} dihydrogen diphosphate)
# nadhx__S_c
#
# Alpha,alpha'-Trehalose 6-phosphate
# tre6p_c
#
# (R)-2,3-Dihydroxy-3-methylpentanoate
# 23dhmp_c
#
# D-Tagaturonate
# tagur_c
#
# D-Mannose 6-phosphate
# man6p_c
#
# N-Acetyl-D-glucosamine
# acgam_e
#
# Hydroxymethylbilane
# hmbil_c
#
# Nitrate
# no3_e
#
# 5-Formamido-1-(5-phospho-D-ribosyl)imidazole-4-carboxamide
# fprica_c
#
# D-Arabinose 5-phosphate
# ara5p_c
#
# (R)-Pantothenate
# pnto__R_e
#
# DTDP-L-rhamnose
# dtdprmn_c
#
# D-Mannonate
# mana_c
#
# 3-Dehydro-L-gulonate
# 3dhguln_c
#
# 3-Deoxy-D-manno-2-octulosonate
# kdo_c
#
# D-Gluconate
# glcn_e
#
# Deoxyuridine
# duri_e
#
# Hydroquinone
# hqn_c
#
# 2,3,2'3'-Tetrakis(beta-hydroxymyristoyl)-D-glucosaminyl-1,6-beta-D-glucosamine 1,4'-bisphosphate
# lipidA_c
#
# Gamma-L-Glutamyl-L-cysteine
# glucys_c
#
# 2-Octaprenyl-6-methoxyphenol
# 2omph_c
#
# D-Sorbitol 6-phosphate
# sbt6p_c
#
# Sirohydrochlorin
# scl_c
#
# Myo-Inositol hexakisphosphate
# minohp_e
#
# Protoporphyrinogen IX
# pppg9_c
#
# Cytosine
# csn_c
#
# N-Acetylneuraminate
# acnam_e
#
# Acetate
# ac_p
#
# P1,P5-Bis(5'-adenosyl) pentaphosphate
# ap5a_c
#
# Maltohexaose
# malthx_p
#
# Cys Gly C5H10N2O3S
# cgly_e
#
# Myo-Inositol
# inost_c
#
# Selenide
# seln_c
#
# D-Glycero-D-manno-heptose 1-phosphate
# gmhep1p_c
#
# Ferrichrome minus Fe(III)
# fecrm_un_p
#
# Apoprotein [acyl carrier protein]
# apoACP_c
#
# (O16 antigen)x4 core oligosaccharide lipid A
# o16a4colipa_p
#
# Tetradecenoate (n-C14:1)
# ...
# 2fe2s_c
#
# DIDP; 2'-deoxyinosine-5'-diphosphate(3-)
# didp_c
#
# 2,3-Dioxo-L-gulonate
# 23doguln_p
#
# Riboflavin C17H20N4O6
# ribflv_c
#
# Phosphatidylglycerol (dihexadec-9-enoyl, n-C16:1)
# pg161_p
#
# L-Lactate
# lac__L_e
#
# Sulfate
# so4_c
#
# 6-phospho-D-glucono-1,5-lactone
# 6pgl_c
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:1)
# 2agpg141_p
#
# Putrescine
# ptrc_c
#
# 2-Dehydro-3-deoxy-D-arabino-heptonate 7-phosphate
# 2dda7p_c
#
# ITP C10H11N4O14P3
# itp_c
#
# 1-hexadec-9-enoyl-sn-glycerol 3-phosphate
# 1hdec9eg3p_p
#
# 2-Methylcitrate
# 2mcit_c
#
# N-Succinyl-2-L-amino-6-oxoheptanedioate
# sl2a6o_c
#
# IscU with bound [4Fe-4S] cluster
# iscu_4fe4s_c
#
# CMP C9H12N3O8P
# cmp_c
#
# DTDPglucose
# dtdpglu_c
#
# Chloramphenicol
# cm_p
#
# Sn-Glycero-3-phospho-1-inositol
# g3pi_c
#
# GTP C10H12N5O14P3
# gtp_c
#
# Curcumin
# cur_c
#
# UDP-N-acetyl-D-glucosamine
# uacgam_c
#
# UDP-N-acetyl-3-O-(1-carboxyvinyl)-D-glucosamine
# uaccg_c
#
# Lipid A Disaccharide
# lipidAds_c
#
# 1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate
# h2mb4p_c
#
# D-Galactarate
# galct__D_p
#
# D-Glucuronate
# glcur_p
#
# 5-phospho-?-D-ribose 1,2-cyclic phosphate
# prcp_c
#
# Maltopentaose
# maltpt_p
#
# L-Fuculose 1-phosphate
# fc1p_c
#
# Biotin
# btn_c
#
# Sulfate
# so4_p
#
# Succinate
# succ_c
#
# Ferroxamine minus Fe(3)
# feoxam_un_c
#
# Cob(I)alamin
# cbl1_e
#
# D-Glucosamine 6-phosphate
# gam6p_c
#
# L-Xylulose
# xylu__L_c
#
# Methanesulfonate
# mso3_c
#
# Adenosine 5'-phosphosulfate
# aps_c
#
# S-Formylglutathione
# Sfglutth_c
#
# L-Xylulose
# xylu__L_e
#
# L-Arginine
# arg__L_p
#
# 2,3,4,5-Tetrahydrodipicolinate
# thdp_c
#
# D-Glucosamine
# gam_p
#
# Phosphatidylethanolamine (ditetradecanoyl, n-C14:0)
# pe140_c
#
# Phosphatidylglycerophosphate (didodecanoyl, n-C12:0)
# pgp120_c
#
# CDP C9H12N3O11P2
# cdp_c
#
# Cardiolipin (tetraoctadecanoyl, n-C18:0)
# clpn180_p
#
# Glycine betaine
# glyb_p
#
# Isopentenyl diphosphate
# ipdp_c
#
# L-Lactate
# lac__L_p
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:0)
# 2agpe180_p
#
# Porphobilinogen
# ppbng_c
#
# D-Glucosamine 6-phosphate
# gam6p_p
#
# Methanol
# meoh_c
#
# Pyridoxal
# pydx_e
#
# L-methionine-R-sulfoxide
# metsox_R__L_c
#
# Protoheme C34H30FeN4O4
# pheme_c
#
# Hydroxymethylglutathione
# hmgth_c
#
# Fe(III)dicitrate
# fe3dcit_c
#
# Guanine
# gua_e
#
# 4-Hydroxy-L-threonine
# 4hthr_c
#
# Selenate
# sel_e
#
# (S)-Propane-1,2-diol
# 12ppd__S_c
#
# (R)-Glycerate
# glyc__R_e
#
# 2-Octaprenyl-6-hydroxyphenol
# 2ohph_c
#
# (enterobacterial common antigen)x4 core oligosaccharide lipid A
# eca4colipa_e
#
# 2 Deoxy D glucose C6H12O5
# 2dglc_p
#
# N2-Succinyl-L-glutamate
# sucglu_c
#
# Nitric oxide
# no_c
#
# Hydrogen cyanide
# cyan_e
#
# 2-Oxopent-4-enoate
# op4en_c
#
# L-Homoserine
# hom__L_p
#
# Nicotinamide adenine dinucleotide phosphate - reduced
# nadph_c
#
# Dimethyl sulfoxide
# dmso_c
#
# N-Acetyl-L-glutamate
# acglu_c
#
# (R)-3-Hydroxydodecanoyl-[acyl-carrier protein]
# 3hddecACP_c
#
# 2-Oxobutanoate
# 2obut_c
#
# DTDP-4-dehydro-6-deoxy-L-mannose
# dtdp4d6dm_c
#
# Dimethylallyl diphosphate
# dmpp_c
#
# Cis-dodec-5-enoyl-[acyl-carrier protein] (n-C12:1)
# cddec5eACP_c
#
# Reduced glutathione
# gthrd_p
#
# Maltotriose C18H32O16
# malttr_c
#
# 1-octadec-11-enoyl-sn-glycerol 3-phosphate
# 1odec11eg3p_p
#
# Reduced riboflavin
# rbflvrd_c
#
# N2-Succinyl-L-arginine
# sucarg_c
#
# D-Tagatose 1,6-biphosphate
# tagdp__D_c
#
# IscU scaffold protein
# iscu_c
#
# L-Arabinose
# arab__L_p
#
# Carboxy-S-adenosyl-L-methionine
# cxsam_c
#
# L-Carnitine
# crn_c
#
# Guanosine
# gsn_p
#
# Deamino-NAD+
# dnad_c
#
# Methanetelluronate
# mteo2_c
#
# Glycerol
# glyc_c
#
# Nitrate
# no3_p
#
# L-Valine
# val__L_c
#
# L-Proline
# pro__L_c
#
# Dodecanoate (n-C12:0)
# ddca_p
#
# Beta-Alanine
# ala_B_e
#
# N-Carbamoyl-L-aspartate
# cbasp_c
#
# Molybdate
# mobd_c
#
# Menaquinone 8
# mqn8_c
#
# D-Lactate
# lac__D_p
#
# Ferrichrome minus Fe(III)
# fecrm_un_e
#
# D-Alanine
# ala__D_p
#
# L-Fucose
# fuc__L_e
#
# Malonyl-[acyl-carrier protein]
# malACP_c
#
# Maltoheptaose
# malthp_c
#
# Thiosulfate
# tsul_e
#
# Cold adapted KDO(2)-lipid (A)
# lipa_cold_c
#
# 3  CMP C9H12N3O8P
# 3cmp_e
#
# Sarcosine C3H7NO2
# sarcs_c
#
# Butanesulfonate
# butso3_e
#
# Putrescine
# ptrc_e
#
# N-Acetyl-D-galactosamine 1-phosphate
# acgal1p_p
#
# Hexanoate (n-C6:0)
# hxa_e
#
# 3-(3-hydroxy-phenyl)propionate
# 3hpppn_c
#
# Fe(III)hydroxamate
# fe3hox_c
#
# N-Acetyl-D-galactosamine 1-phosphate
# acgal1p_e
#
# L-Leucine
# leu__L_p
#
# Maltohexaose
# malthx_e
#
# L-Lyxose
# lyx__L_p
#
# 3-Sulfino-L-alanine
# 3sala_c
#
# Generic ferrioxamine-Fe-III
# feoxam_p
#
# (R)-3-Hydroxydecanoyl-[acyl-carrier protein]
# 3hdecACP_c
#
# Taurine C2H7NO3S
# taur_p
#
# Cis-dec-3-enoyl-[acyl-carrier protein] (n-C10:1)
# cdec3eACP_c
#
# (R)-3-hydroxy-cis-myristol-7-eoyl-[acyl-carrier protein]
# 3hcmrs7eACP_c
#
# Hydrogen peroxide
# h2o2_p
#
# L-Glutamate
# glu__L_p
#
# DIMP C10H12N4O7P
# dimp_e
#
# 3  UMP C9H11N2O9P
# 3ump_e
#
# Phosphatidylethanolamine (dihexadec-9enoyl, n-C16:1)
# pe161_c
#
# 2-octadecanoyl-sn-glycerol 3-phosphate
# 2odecg3p_p
#
# Nicotinate
# nac_p
#
# 1-tetradecanoyl-sn-glycerol 3-phosphate
# 1tdecg3p_p
#
# N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid
# anhgm_p
#
# UDP-4-keto-pyranose
# udpLa4o_c
#
# Ethanesulfonate
# ethso3_e
#
# Psicoselysine
# psclys_e
#
# Undecaprenyl-diphospho N-acetylglucosamine-N-acetylmannosaminuronate-N-acetamido-4,6-dideoxy-D-galactose
# unagamuf_p
#
# D-tartrate
# tartr__D_p
#
# Nitrous oxide
# n2o_p
#
# UDPgalactose
# udpgal_p
#
# Galactofuranosyl-glucosyl-O-acetyl-rhamanosyl-N-acetylglucosamyl-undecaprenyl diphosphate
# gfgaragund_c
#
# 3-Oxododecanoyl-[acyl-carrier protein]
# 3oddecACP_c
#
# N-3-aminopropyl-1,5-diaminopentane
# na15dap_c
#
# Quinate
# quin_e
#
# (R)-Glycerate
# glyc__R_p
#
# 3-Aminoacrylate
# 3amac_c
#
# Phosphatidylglycerol (dioctadec-11-enoyl, n-C18:1)
# pg181_c
#
# Ethanesulfonate
# ethso3_p
#
# 1,2-Diacyl-sn-glycerol (ditetradec-7-enoyl, n-C14:1)
# 12dgr141_c
#
# Lipoate
# lipoate_c
#
# 3-Oxooctadecanoyl-[acyl-carrier protein]
# 3ooctdACP_c
#
# But-2-enoyl-[acyl-carrier protein]
# but2eACP_c
#
# Phosphatidylglycerophosphate (dihexadec-9-enoyl, n-C16:1)
# pgp161_p
#
# 2-3-dihydroxybenzoylserine trimer-Fe-III
# fe3dhbzs3_c
#
# 1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)
# 12dgr180_c
#
# Pseudouridine
# psuri_e
#
# Dodecanoate (n-C12:0)
# ddca_c
#
# Pyruvate
# pyr_c
#
# XDP
# xdp_c
#
# DUMP C9H11N2O8P
# dump_c
#
# Cis-Aconitate
# acon_C_c
#
# Periplasmic disulfide isomerase/thiol-disulphide oxidase (reduced)
# dsbgrd_p
#
# 2,3-dehydroadipyl-CoA
# 23dhacoa_c
#
# 4-Methyl-5-(2-phosphoethyl)-thiazole
# 4mpetz_c
#
# Propanal
# ppal_e
#
# L-Ribulose 5-phosphate
# ru5p__L_c
#
# Sucrose C12H22O11
# sucr_e
#
# (3S)-3-Hydroxyadipyl-CoA
# 3hadpcoa_c
#
# Octadecanoyl-phosphate (n-C18:0)
# ocdcap_c
#
# L-Lactate
# lac__L_c
#
# D-Malate
# mal__D_c
#
# 4-Amino-4-deoxy-L-arabinose modified core oligosaccharide lipid A
# acolipa_e
#
# 1,6-anhydrous-N-Acetylmuramate
# anhm_c
#
# Urea CH4N2O
# urea_e
#
# [4Fe-4S] iron-sulfur cluster
# 4fe4s_c
#
# Glycolaldehyde
# gcald_c
#
# Iron (Fe3+)
# fe3_p
#
# Fusidic acid
# fusa_e
#
# Phosphotyrosine
# tyrp_e
#
# Hexadecenoate (n-C16:1)
# hdcea_e
#
# GDP-4-dehydro-6-deoxy-D-mannose
# gdpddman_c
#
# 6,7-Dihydropteridine
# dhptdn_c
#
# D-Galactarate
# galct__D_c
#
# Glutaredoxin (oxidized)
# grxox_c
#
# 4-Hydroxybenzoate
# 4hbz_p
#
# 1-tetradec-7-enoyl-sn-glycerol 3-phosphate
# 1tdec7eg3p_c
#
# Phosphatidylglycerophosphate (dioctadecanoyl, n-C18:0)
# pgp180_c
#
# 2-dodecanoyl-sn-glycerol 3-phosphate
# 2ddecg3p_p
#
# Dihydroxyacetone
# dha_c
#
# Reduced glutathione
# gthrd_e
#
# (-)-Ureidoglycolate
# urdglyc_c
#
# Propenoyl-CoA
# prpncoa_c
#
# Decanoyl-CoA (n-C10:0CoA)
# dcacoa_c
#
# Sulfite
# so3_e
#
# N-Acetyl-D-glucosamine
# acgam_p
#
# 2-hexadec-9-enoyl-sn-glycerol 3-phosphate
# 2hdec9eg3p_p
#
# Selenate
# sel_c
#
# [3Fe-4S] damaged iron-sulfur cluster
# 3fe4s_c
#
# Lipoyl-AMP
# lipoamp_c
#
# Isocitrate
# icit_c
#
# 2 Deoxy D glucose C6H12O5
# 2dglc_e
#
# Melibiose C12H22O11
# melib_p
#
# L-Rhamnose
# rmn_p
#
# D-Galactonate
# galctn__D_p
#
# D-Lactate
# lac__D_c
#
# Fructoselysine
# frulys_e
#
# Nicotinamide adenine dinucleotide - reduced
# nadh_c
#
# 2-Deoxy-D-ribose 5-phosphate
# 2dr5p_c
#
# AMP C10H12N5O7P
# amp_c
#
# CMP C9H12N3O8P
# cmp_e
#
# Pyridoxamine
# pydam_e
#
# 3-Phosphohydroxypyruvate
# 3php_c
#
# DTDP C10H13N2O11P2
# dtdp_c
#
# 7,8-Dihydrofolate
# dhf_c
#
# GMP C10H12N5O8P
# gmp_p
#
# 5,6-dihydrouracil
# 56dura_c
#
# 4-Hydroxyphenylacetaldehyde
# 4hoxpacd_p
#
# Formate
# for_c
#
# Urate C5H4N4O3
# urate_c
#
# Phosphate
# pi_e
#
# 3  AMP C10H12N5O7P
# 3amp_e
#
# Hydrogen
# h2_c
#
# 1,4-alpha-D-glucan
# 14glucan_e
#
# Thiamin monophosphate
# thmmp_c
#
# Pseudouridine 5  phosphate C9H11N2O9P
# psd5p_c
#
# Crotonoyl-CoA
# b2coa_c
#
# Iron (Fe3+)
# fe3_e
#
# L-Aspartate
# asp__L_e
#
# L-Allo-threonine
# athr__L_c
#
# 3-Oxohexadecanoyl-[acyl-carrier protein]
# 3opalmACP_c
#
# (R)-3-hydroxy-cis-vacc-11-enoyl-[acyl-carrier protein]
# 3hcvac11eACP_c
#
# Sulphoquinovose
# sq_p
#
# L-Threonine
# thr__L_e
#
# Maltopentaose
# maltpt_e
#
# L-Methionine Sulfoxide
# metsox_S__L_e
#
# 2-N-acetamidomethylphosphonate
# acampnt_c
#
# Coenzyme A
# coa_c
#
# KDO(2)-lipid IV(A) with laurate
# kdo2lipid4L_c
#
# L-Asparagine
# asn__L_c
#
# Nicotinate
# nac_c
#
# 4-Phospho-D-erythronate
# 4per_c
#
# Nitrite
# no2_c
#
# 1,5-Diaminopentane
# 15dap_e
#
# UDP C9H11N2O12P2
# udp_c
#
# Trans-Hexadec-2-enoyl-CoA
# hdd2coa_c
#
# Hypoxanthine
# hxan_c
#
# 2-Dehydro-3-deoxy-D-galactonate 6-phosphate
# 2dh3dgal6p_c
#
# Nitric oxide
# no_e
#
# P1,P4-Bis(5'-adenosyl) tetraphosphate
# ap4a_c
#
# L-Leucine
# leu__L_c
#
# (S)-2-[5-Amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxamido]succinate
# 25aics_c
#
# Methanol
# meoh_e
#
# Melibiose C12H22O11
# melib_e
#
# 3',5'-Cyclic GMP
# 35cgmp_c
#
# 2-Dehydro-3-deoxy-D-gluconate
# 2ddglcn_p
#
# Adenosyl cobinamide phosphate
# adocbip_c
#
# Ethanolamine
# etha_e
#
# GDP-L-fucose
# gdpfuc_c
#
# Glycerol 3-phosphate
# glyc3p_p
#
# Undecaprenyl diphospho N-acetyl-glucosamine
# unaga_c
#
# Potassium
# k_p
#
# GTP C10H12N5O14P3
# gtp_p
#
# L-Xylulose
# xylu__L_p
#
# Maltotetraose
# maltttr_e
#
# D-Glucuronate
# glcur_e
#
# L-Methionine Sulfoxide
# metsox_S__L_c
#
# L-Carnitinyl-CoA
# crncoa_c
#
# Fe(III)hydroxamate
# fe3hox_e
#
# 3  UMP C9H11N2O9P
# 3ump_p
#
# Glycerophosphoserine
# g3ps_p
#
# Gamma-glutamyl-gamma-butyraldehyde
# ggbutal_c
#
# Gamma-butyrobetaine
# gbbtn_e
#
# Phosphatidylglycerol (ditetradecanoyl, n-C14:0)
# pg140_c
#
# 4-Aminobenzoate
# 4abz_c
#
# Methanesulfonate
# mso3_p
#
# 1,2-ditetradecanoyl-sn-glycerol 3-phosphate
# pa140_p
#
# L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate
# LalaDgluMdap_c
#
# Cob(I)alamin
# cbl1_p
#
# Enterochelin
# enter_e
#
# Acyl phosphatidylglycerol (n-C18:0)
# apg180_c
#
# Core oligosaccharide lipid A
# colipa_c
#
# L-alanine-L-glutamate
# LalaLglu_c
#
# 1-Aminopropan-2-ol
# appl_c
#
# O-acetyl-rhamanosyl-N-acetylglucosamyl-undecaprenyl diphosphate
# aragund_c
#
# 2 Deoxy D glucose C6H12O5
# 2dglc_c
#
# 1,4-dihydroxy-2-napthoyl-CoA
# 14dhncoa_c
#
# 3-Oxotetradecanoyl-[acyl-carrier protein]
# 3omrsACP_c
#
# (O16 antigen)x2 undecaprenyl diphosphate
# o16a2und_p
#
# S-Methyl-L-methionine
# mmet_c
#
# Phosphatidylglycerophosphate (dioctadec-11-enoyl, n-C18:1)
# pgp181_c
#
# Acetaldehyde
# acald_c
#
# Cyclopropane phosphatidylethanolamine (dioctadec-11,12-cyclo-anoyl, n-C18:0 cyclo)
# cpe180_c
#
# N-Acetyl-D-glucosamine 1-phosphate
# acgam1p_e
#
# 5-Amino-6-(5'-phosphoribitylamino)uracil
# 5aprbu_c
#
# 1,2-ditetradec-7-enoyl-sn-glycerol 3-phosphate
# pa141_p
#
# 5-Amino-4-oxopentanoate
# 5aop_c
#
# 1,2-Diacyl-sn-glycerol (ditetradec-7-enoyl, n-C14:1)
# 12dgr141_p
#
# 1,2-dioctadecanoyl-sn-glycerol 3-phosphate
# pa180_p
#
# Trans-Oct-2-enoyl-CoA
# oc2coa_c
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1)
# 2agpe141_c
#
# N1-(alpha-D-ribosyl)-5,6-dimethylbenzimidazole
# rdmbzi_c
#
# 1-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1)
# 1agpe141_p
#
# Crotonobetainyl-CoA
# ctbtcoa_c
#
# 1-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1)
# 1agpg161_p
#
# (R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]
# 3hmrsACP_c
#
# L-alanine-D-glutamate
# LalaDglu_e
#
# 5-Phospho-beta-D-ribosylamine
# pram_c
#
# SufBCD with two bound [2Fe-2S] clusters
# sufbcd_2fe2s2_c
#
# Urate C5H4N4O3
# urate_e
#
# Oxalureate
# oxur_c
#
# Octadecanoyl-phosphate (n-C18:1)
# ocdceap_c
#
# Chloramphenicol
# cm_e
#
# Agmatine
# agm_e
#
# 7-deaza-7-carboxyguanine
# cdg_c
#
# Fe-enterobactin
# feenter_c
#
# IscS sulfur acceptor protein
# iscs_c
#
# 2-3-dihydroxybenzoylserine trimer-Fe-III
# fe3dhbzs3_p
#
# Sodium
# na1_c
#
# 3-Carboxy-4-methyl-2-oxopentanoate
# 3c4mop_c
#
# D-Xylonate
# dxylnt_c
#
# L-Lysine
# lys__L_p
#
# S-ureidoglycine
# urdgci_c
#
# L-Homocysteine
# hcys__L_c
#
# Nitrate
# no3_c
#
# L-Malate
# mal__L_e
#
# CO2 CO2
# co2_c
#
# N-((R)-4-Phosphopantothenoyl)-L-cysteine
# 4ppcys_c
#
# L-Phenylalanine
# phe__L_e
#
# Coprogen
# cpgn_e
#
# Phosphate
# pi_p
#
# Allantoate
# alltt_c
#
# Fumarate
# fum_e
#
# Coprogen
# cpgn_p
#
# Acetaldehyde
# acald_e
#
# Hydrogen
# h2_p
#
# Tyramine
# tym_p
#
# Ethanol
# etoh_p
#
# 2,5-Diamino-6-(ribosylamino)-4-(3H)-pyrimidinone 5'-phosphate
# 25drapp_c
#
# Oxidized glutathione
# gthox_c
#
# Phenethylamine
# peamn_e
#
# N1-(5-Phospho-D-ribosyl)glycinamide
# gar_c
#
# Tungstate
# tungs_c
#
# 2',3'-Cyclic CMP
# 23ccmp_p
#
# Aerobactin minus Fe3
# arbtn_c
#
# Enterochelin
# enter_c
#
# Cu+
# cu_p
#
# Fe(III)hydroxamate
# fe3hox_p
#
# Ferroxamine minus Fe(3)
# feoxam_un_e
#
# UDP-N-acetyl-D-galactosamine
# udpacgal_e
#
# UMP C9H11N2O9P
# ump_p
#
# D-Lactaldehyde
# lald__D_c
#
# CMP C9H12N3O8P
# cmp_p
#
# Fe(III)hydoxamate, unloaded
# fe3hox_un_e
#
# Acetol cytosol
# acetol_c
#
# Pyridoxine
# pydxn_e
#
# 2',3'-Cyclic GMP
# 23cgmp_e
#
# Three disacharide linked murein units (tetrapeptide crosslinked tetrapeptide (A2pm->D-ala) & tetrapeptide corsslinked tetrapeptide (A2pm->D-ala)) (middle of chain)
# murein4px4px4p_p
#
# 2,3-dihydroxybenzoylserine
# 23dhbzs_c
#
# Tyramine
# tym_e
#
# (3R)-3-Hydroxyacyl-[acyl-carrier protein]
# 3haACP_c
#
# 3-Oxooctanoyl-[acyl-carrier protein]
# 3ooctACP_c
#
# O-Phospho-L-serine
# pser__L_e
#
# 3-oxo-cis-myristol-7-eoyl-[acyl-carrier protein]
# 3ocmrs7eACP_c
#
# Sulfur dioxide
# so2_c
#
# 1-octadecanoyl-sn-glycerol 3-phosphate
# 1odecg3p_c
#
# Peroxyaminoacrylate
# poaac_c
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C12:0)
# 2agpe120_p
#
# CDP-1,2-dihexadecanoylglycerol
# cdpdhdecg_c
#
# 5-Methylthio-D-ribose
# 5mtr_e
#
# Hexadecenoate (n-C16:1)
# hdcea_p
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0)
# 2agpg160_p
#
# 2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:0)
# 2agpe180_c
#
# 2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1)
# 2agpg161_p
#
# Molybdenum cofactor
# moco_c
#
# 1-tetradec-7-enoyl-sn-glycerol 3-phosphate
# 1tdec7eg3p_p
#
# 3-Hydroxypropanoate
# 3hpp_c
#
# 2-Dehydro-3-deoxy-D-gluconate 6-phosphate
# 2ddg6p_c
#
# Minocycline
# mincyc_e
#
# 1-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0)
# 1agpg140_p
#
# L-Arabinose
# arab__L_c
#
# SufBCD with bound [4Fe-4S] cluster
# sufbcd_4fe4s_c
#
# Dihydrocurcumin
# dhcur_c
#
# Adenine
# ade_c
#
# L-Rhamnulose
# rml_c
#
# Rifampin
# rfamp_e
#
# N-Acetyl-L-glutamyl 5-phosphate
# acg5p_c
#
# Rifampin
# rfamp_p
#
# 4-Phospho-L-aspartate
# 4pasp_c
#
# L-Glutamate 5-phosphate
# glu5p_c
#
# H2O H2O
# h2o_e
#
# Methane
# ch4_c
#
# 2,3-Dihydrodipicolinate
# 23dhdp_c
#
# (S)-3-Methyl-2-oxopentanoate
# 3mop_c
#
# (S)-3-Hydroxytetradecanoyl-CoA
# 3htdcoa_c
#
# DGTP C10H12N5O13P3
# dgtp_c
#
# D-Ribose
# rib__D_e
#
# Flavin adenine dinucleotide oxidized
# fad_c
#
# Uridine
# uri_e
#
# 4-Amino-5-hydroxymethyl-2-methylpyrimidine
# 4ahmmp_c
#
# L-Tryptophan
# trp__L_e
#
# Dephospho-CoA
# dpcoa_c
#
# 2-Octaprenyl-3-methyl-6-methoxy- 1,4-benzoquinol
# 2ommbl_c
#
# 2,3-Dihydro-2,3-dihydroxybenzoate
# 23ddhb_c
#
# Deoxyinosine
# din_e
#
# (3S)-3,6-Diaminohexanoate
# 36dahx_c
#
# Melibiose C12H22O11
# melib_c
#
# Undecaprenyl phosphate
# udcpp_c
#
# N6-(1,2-Dicarboxyethyl)-AMP
# dcamp_c
#
# KDO(2)-lipid IV(A)
# kdo2lipid4_c
#
# D-Galactarate
# galct__D_e
#
# UDP-D-glucuronate
# udpglcur_c
#
# 4-Hydroxy-2-oxopentanoate
# 4h2opntn_c
#
# D-biotin d-sulfoxide
# btnso_c
#
# Myristoyl-ACP (n-C14:0ACP)
# myrsACP_c
#
# Selenophosphate
# selnp_c
#
# CAMP C10H11N5O6P
# camp_c
#
# Dethiobiotin
# dtbt_c
#
# D-Galacturonate
# galur_e
#
# D-Glycero-D-manno-heptose 1,7-bisphosphate
# gmhep17bp_c
#
# Acyl carrier protein
# ACP_c
#
# D-Methionine
# met__D_p
#
# Palmitoyl-ACP (n-C16:0ACP)
# palmACP_c
#
# Allantoin
# alltn_p
#
# Deoxyadenosine
# dad_2_p
#
# Sucrose 6-phosphate
# suc6p_c
#
# Ethanolamine
# etha_p
#
# DGMP C10H12N5O7P
# dgmp_p
#
# 2,3-diaminopropionate
# 23dappa_p
#
# Sn-Glycero-3-phospho-1-inositol
# g3pi_p
#
# 2',3'-Cyclic AMP
# 23camp_e
#
# Undecaprenyl phosphate-4-amino-4-deoxy-L-arabinose
# uLa4n_p
#
# Cu+
# cu_c
#
# Coprogen unloaded (no Fe(III))
# cpgn_un_p
#
# Phosphatidylserine (ditetradec-7-enoyl, n-C14:1)
# ps141_c
#
# Phosphatidylglycerophosphate (ditetradec-7-enoyl, n-C14:1)
# pgp141_p
#
# Phosphatidylglycerophosphate (dioctadecanoyl, n-C18:0)
# pgp180_p
#
# Psicoselysine
# psclys_p
#
# 4-aminobenzoyl-glutamate
# 4abzglu_c
#
# 2,3-Dihydroxypropane-1-sulfonate
# dhps_e
#
# D-erythrose
# erthrs_c
#
# Succinyl-CoA
# succoa_c
#
# D-Xylose
# xyl__D_c
#
# Succinic semialdehyde
# sucsal_c
#
# Allantoin
# alltn_c
#
# (S)-3-Hydroxydecanoyl-CoA
# 3hdcoa_c
#
# D-Mannitol
# mnl_e
#
# Formate
# for_e
#
# KDO-lipid IV(A)
# kdolipid4_c
#
# L-seryl-AMP
# seramp_c
#
# Adenine
# ade_p
#
# D-Sorbitol
# sbt__D_p
#
# (S)-Propane-1,2-diol
# 12ppd__S_p
#
# Decanoate (n-C10:0)
# dca_p
#
# Fe(III)dicitrate
# fe3dcit_p
#
# Hydrogen peroxide
# h2o2_e
#
# 2',3'-Cyclic UMP
# 23cump_e
#
# (enterobacterial common antigen)x2 undecaprenyl-diphosphate
# eca2und_p
#
# Chloride
# cl_p
#
# Two linked disacharide tetrapeptide and tripeptide murein units (uncrosslinked, middle of chain)
# murein4p3p_p
#
# 1,2-Diacyl-sn-glycerol (dihexadecanoyl, n-C16:0)
# 12dgr160_p
#
# 1-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0)
# 1agpg120_p
#
# Tungstate
# tungs_e
#
# 5-Formyltetrahydrofolate
# 5fthf_c
#
# Aerobactin
# arbtn_fe3_c

# %%
model.metabolites.get_by_id("o2_e")
# Out:
# <Metabolite o2_e at 0x7fe05bad3bb0>

# %%
model.reactions.get_by_id("EX_glc__D_e")
# Out:
# <Reaction EX_glc__D_e at 0x7fe0459ef6a0>

# %% [markdown]
# ### Getting Metabolites already present in the model

# %%
phe__L_c = model.metabolites.get_by_id("phe__L_c") #L-phenylalanine
cinnm_c = model.metabolites.get_by_id("cinnm_c") #TransCinnamate
nadph_c = model.metabolites.get_by_id("nadph_c") #NADPH - reduced
nadp_c = model.metabolites.get_by_id("nadp_c") #NADP - oxidyzed
o2_c = model.metabolites.get_by_id("o2_c") #oxygen
h2o_c = model.metabolites.get_by_id("h2o_c") #h2p
tyr__L_c = model.metabolites.get_by_id("tyr__L_c") #L-tyrosine
atp_c = model.metabolites.get_by_id("atp_c") #ATP
coa_c = model.metabolites.get_by_id("coa_c") #COEnzymeA
amp_c = model.metabolites.get_by_id("amp_c") #AMP
ppi_c = model.metabolites.get_by_id("ppi_c") #diphosphate
co2_c = model.metabolites.get_by_id("co2_c") #Carbon dioxide
malcoa_c = model.metabolites.get_by_id("malcoa_c") #Malonyl-CoA
dmpp_c = model.metabolites.get_by_id("dmpp_c") #Dimethylallyl diphosphate
amet_c = model.metabolites.get_by_id("amet_c")
ahcys_c = model.metabolites.get_by_id("ahcys_c")

# %% [markdown]
# ### Creating Metabolites to add to the model

# %%
p_coumaric = Metabolite(
    "4hcinnm_c", #SId
    formula = "C9H8O3", #Chemical formula
    name = "p-Coumaric acid", #Name of chemical or metabolit
    compartment = "c") #cell compartment c-cytosolic
#same as p-coumaric acid

p_coumaroyl_coa = Metabolite(
    "4hcoumcoa_c",
    formula = "C30H42N7O18P3S",
    name = "p-Coumaroyl-CoA",
    compartment = "c")

naringenin_chalcone = Metabolite(
    "narinchalc_c",
    formula = "C15H12O5",
    name = "Naringenin chalcone",
    compartment = "c")

naringenin = Metabolite(
    "narin_c",
    formula = "C15H12O5",
    name = "Naringenin",
    compartment = "c")

desmethylxanthohumol = Metabolite(
    "dmxh_c",
    formula = "C20H20O5",
    name = "Desmethylxanthohumol",
    compartment = "c")

xanthohumol = Metabolite(
    "xh_c",
    formula="C21H22O5",
    name="Xanthohumol",
    compartment = "c")

prenylnaringenin = Metabolite(
    "8-pnarin_c",
    formula = "C20H20O5",
    name = "8-prenylnaringenin",
    compartment = "c")

# %% [markdown]
# ### Creating reactions for production of Naringenin

# %%
#Reaction R00697
reaction00697 =  Reaction("R00697")
reaction00697.name = ("L-phenylalanine ammonia-lyase")
reaction00697.subsystem =("Phenylpropanoid biosynthesis")

#Creating reversibility
reaction00697.lower_bound = -1000.0
reaction00697.upper_bound = 1000.0

#Adding metabolites
reaction00697.add_metabolites({
    phe__L_c : -1.0,
    cinnm_c : 1.0
})

reaction00697.gene_reaction_rule = "PAL1"

reaction00697
# Out:
# <Reaction R00697 at 0x7fe05ba14b50>

# %%
#Reaction R02253
reaction02253 =  Reaction("R02253")
reaction02253.name = ("trans-cinnamate (4-hydroxylating)")
reaction02253.subsystem =("Phenylpropanoid biosynthesis")

#Creating reversibility
reaction02253.lower_bound = -1000.0
reaction02253.upper_bound = 1000.0

#Adding metabolites
reaction02253.add_metabolites({
    cinnm_c : -1.0,
    nadph_c : -1.0,
    o2_c : -1.0,
    p_coumaric : 1.0,
    nadp_c: 1.0,
    h2o_c: 1.0
})

reaction02253.gene_reaction_rule = "CYP73A5"

reaction02253
# Out:
# <Reaction R02253 at 0x7fe047286580>

# %%
#Reaction R00737
reaction00737 =  Reaction("R00737")
reaction00737.name = ("L-tyrosine ammonia-lyase")
reaction00737.subsystem =("Phenylpropanoid biosynthesis")

#Creating reversibility
reaction00737.lower_bound = -1000
reaction00737.upper_bound = 1000.0

#Adding metabolites
reaction00737.add_metabolites({
    tyr__L_c : -1.0,
    p_coumaric : 1.0
})
reaction00737.gene_reaction_rule="PAL"
reaction00737
# Out:
# <Reaction R00737 at 0x7fe0399192b0>

# %%
#Reaction R01616

reaction01616 =  Reaction("R01616")
reaction01616.name = ("4-Coumarate:CoA ligase")
reaction01616.subsystem =("Phenylpropanoid biosynthesis")

#Creating reversibility
reaction01616.lower_bound = -1000
reaction01616.upper_bound = 1000.0

#Adding metabolites
reaction01616.add_metabolites({
    atp_c : -1.0,
    p_coumaric : -1.0,
    coa_c: -1.0,
    amp_c: 1.0,
    ppi_c: 1.0,
    p_coumaroyl_coa: 1.0
})
reaction01616.gene_reaction_rule = "(4CL1 or 4CL2 or 4CL3 or 4CL5)"
reaction01616
# Out:
# <Reaction R01616 at 0x7fe0472a1a90>

# %%
#Reaction R01613
reaction01613 =  Reaction("R01613")
reaction01613.name = ("Malonyl-CoA:4-Coumaroyl-CoA malonyltransferase(cyclizing)")
reaction01613.subsystem =("Phenylpropanoid biosynthesis")

#Creating reversibility
reaction01613.lower_bound = -1000
reaction01613.upper_bound = 1000.0

#Adding metabolites
reaction01613.add_metabolites({
    p_coumaroyl_coa: -1.0,
    malcoa_c: -3.0,
    naringenin_chalcone: 1.0,
    coa_c : 4.0,
    co2_c : 3.0
})

reaction01613.gene_reaction_rule = "CHS"

reaction01613
# Out:
# <Reaction R01613 at 0x7fe047286df0>

# %%
#Reaction R02446
reaction02446 =  Reaction("R02446")
reaction02446.name = ("flavanone lyase (decyclizing)")
reaction02446.subsystem =("Phenylpropanoid biosynthesis")

#Creating reversibility
reaction02446.lower_bound = -1000
reaction02446.upper_bound = 1000.0

#Adding metabolites
reaction02446.add_metabolites({
    naringenin_chalcone : -1.0,
    naringenin: 1.0,
})
reaction02446.gene_reaction_rule = "CHI1" 
reaction02446
# Out:
# <Reaction R02446 at 0x7fe047286c10>

# %% [markdown]
# ### Creating Reaction for Xanthohumol

# %%
#Reaction R08003
reaction08003 =  Reaction("R08003")
reaction08003.name = ("xanthohumol midstep (prenyltransferase)")
reaction08003.subsystem =("Flavonoid biosynthesis")

#Creating reversibility
reaction08003.lower_bound = -1000
reaction08003.upper_bound = 1000.0

#Adding metabolites
reaction08003.add_metabolites({
    naringenin_chalcone: -1.0,
    dmpp_c: -1.0,
    desmethylxanthohumol: 1.0,
    ppi_c: 1.0
})
reaction08003.gene_reaction_rule= "PT1L"
reaction08003
# Out:
# <Reaction R08003 at 0x7fe0472a1d00>

# %%
#Reaction R08004
reaction08004 =  Reaction("R08004")
reaction08004.name = ("S-adenosyl-L-methionine:desmethylxanthohumol 6'-O-methyltransferase")
reaction08004.subsystem =("Flavonoid biosynthesis")

#Creating reversibility
reaction08004.lower_bound = -1000
reaction08004.upper_bound = 1000.0

#Adding metabolites
reaction08004.add_metabolites({
    desmethylxanthohumol: -1.0,
    amet_c: -1.0,
    xanthohumol: 1.0,
    ahcys_c: 1.0
})
reaction08004.gene_reaction_rule= "OMT1"
reaction08004
# Out:
# <Reaction R08004 at 0x7fe047286a90>

# %% [markdown]
# ### Creating Reaction for 8-prenylnaringenin

# %%
#Reaction 	R08951
reaction08951 =  Reaction("R08951")
reaction08951.name = ("8-prenylnaringenin (prenyltransferase)")
reaction08951.subsystem =("Flavonoid biosynthesis")

#Creating reversibility
reaction08951.lower_bound = -1000
reaction08951.upper_bound = 1000.0

#Adding metabolites
reaction08951.add_metabolites({
    naringenin: -1.0,
    dmpp_c: -1.0,
    prenylnaringenin: 1.0,
    ppi_c: 1.0
})
reaction08951.gene_reaction_rule = "(N8DT-1 or N8DT-2)"
reaction08951
# Out:
# <Reaction R08951 at 0x7fe05940c400>

# %% [markdown]
# ### Creating Exchange reactions for products of interest

# %% [markdown]
# #### External Metabolites

# %%
xanthohumol_e = Metabolite(
    "xh_e",
    formula="C21H22O5",
    name="Xanthohumol",
    compartment = "e")

prenylnaringenin_e = Metabolite(
    "8-pnarin_e",
    formula = "C20H20O5",
    name = "8-prenylnaringenin",
    compartment = "e")

# %% [markdown]
# #### Citosolic to external reactions

# %%
#Reaction 8-prenyl_tex
xanthohumol_c_to_e =  Reaction("8-xantho_tex")
xanthohumol_c_to_e.name = ("Xanthohumol C to E")

#Creating reversibility
xanthohumol_c_to_e.lower_bound = -1000
xanthohumol_c_to_e.upper_bound = 1000.0

#Adding metabolites
xanthohumol_c_to_e.add_metabolites({
    xanthohumol: -1.0,
    xanthohumol_e : 1.0
})

xanthohumol_c_to_e
# Out:
# <Reaction 8-xantho_tex at 0x7fe05ba14b20>

# %%
#Reaction 8-prenyl_tex
prenylnaringenin_c_to_e =  Reaction("8-prenyl_tex")
prenylnaringenin_c_to_e.name = ("8-prenylnaringenin C to E")

#Creating reversibility
prenylnaringenin_c_to_e.lower_bound = -1000
prenylnaringenin_c_to_e.upper_bound = 1000.0

#Adding metabolites
prenylnaringenin_c_to_e.add_metabolites({
    prenylnaringenin: -1.0,
    prenylnaringenin_e : 1.0
})

prenylnaringenin_c_to_e
# Out:
# <Reaction 8-prenyl_tex at 0x7fe0472a12b0>

# %% [markdown]
# ### Adding metabolites to the model

# %%
model.add_metabolites([p_coumaric,p_coumaroyl_coa,naringenin,naringenin_chalcone,desmethylxanthohumol,xanthohumol,prenylnaringenin,xanthohumol_e,prenylnaringenin_e])

# %% [markdown]
# ### Adding boundaries

# %%
model.add_boundary(xanthohumol_e,type="exchange")
# Out:
# <Reaction EX_xh_e at 0x7fe05c0d73d0>

# %%
model.add_boundary(prenylnaringenin_e,type="exchange")
# Out:
# <Reaction EX_8-pnarin_e at 0x7fe0472a1250>

# %% [markdown]
# #### Setting bounds on exchange reaction for secretion

# %%
model.reactions.get_by_id("EX_xh_e").upper_bound = 1000
model.reactions.get_by_id("EX_8-pnarin_e").upper_bound = 1000

model.reactions.get_by_id("EX_xh_e").lower_bound = 0
model.reactions.get_by_id("EX_8-pnarin_e").lower_bound = 0

# %%
model.reactions.get_by_id("EX_xh_e")
# Out:
# <Reaction EX_xh_e at 0x7fe05c0d73d0>

# %%
model.reactions.get_by_id("EX_8-pnarin_e")
# Out:
# <Reaction EX_8-pnarin_e at 0x7fe0472a1250>

# %% [markdown]
# ### Adding Reactions to the model

# %%
reaction_list=[reaction00697,reaction02253,reaction00737,reaction01616,reaction01613,reaction02446,reaction08003,reaction08004,reaction08951,xanthohumol_c_to_e,prenylnaringenin_c_to_e]

# %%
model.add_reactions(reaction_list)

# %%
model
# Out:
# <Model iML1515 at 0x7fe05bc52970>

# %%
for reaction in model.reactions:
    print(reaction)
# Out:
# CYTDK2: cytd_c + gtp_c --> cmp_c + gdp_c + h_c
# XPPT: prpp_c + xan_c --> ppi_c + xmp_c
# HXPRT: hxan_c + prpp_c --> imp_c + ppi_c
# NDPK5: atp_c + dgdp_c <=> adp_c + dgtp_c
# SHK3Dr: 3dhsk_c + h_c + nadph_c <=> nadp_c + skm_c
# NDPK6: atp_c + dudp_c <=> adp_c + dutp_c
# NDPK8: atp_c + dadp_c <=> adp_c + datp_c
# DHORTS: dhor__S_c + h2o_c <=> cbasp_c + h_c
# OMPDC: h_c + orot5p_c --> co2_c + ump_c
# PYNP2r: pi_c + uri_c <=> r1p_c + ura_c
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + nadp_c + pi_c
# CS: accoa_c + h2o_c + oaa_c --> cit_c + coa_c + h_c
# ICDHyr: icit_c + nadp_c <=> akg_c + co2_c + nadph_c
# ALATA_L2: ala__L_c + pydx5p_c --> pyam5p_c + pyr_c
# DURIPP: duri_c + pi_c <=> 2dr1p_c + ura_c
# ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c
# PTRCTA: akg_c + ptrc_c --> 4abutn_c + glu__L_c
# ACS: ac_c + atp_c + coa_c --> accoa_c + amp_c + ppi_c
# CYSDS: cys__L_c + h2o_c --> h2s_c + nh4_c + pyr_c
# MAN6PI: man6p_c <=> f6p_c
# PPA: h2o_c + ppi_c --> h_c + 2.0 pi_c
# APRAUR: 5apru_c + h_c + nadph_c --> 5aprbu_c + nadp_c
# TRPAS2: h2o_c + trp__L_c <=> indole_c + nh4_c + pyr_c
# PPCK: atp_c + oaa_c --> adp_c + co2_c + pep_c
# ME1: mal__L_c + nad_c --> co2_c + nadh_c + pyr_c
# DB4PS: ru5p__D_c --> db4p_c + for_c + h_c
# ALAR: ala__L_c <=> ala__D_c
# RBFK: atp_c + ribflv_c --> adp_c + fmn_c + h_c
# ALATA_L: akg_c + ala__L_c <=> glu__L_c + pyr_c
# XYLK: atp_c + xylu__D_c --> adp_c + h_c + xu5p__D_c
# RBK: atp_c + rib__D_c --> adp_c + h_c + r5p_c
# GLYK: atp_c + glyc_c --> adp_c + glyc3p_c + h_c
# PPM: r1p_c <=> r5p_c
# ASPTA: akg_c + asp__L_c <=> glu__L_c + oaa_c
# ACP1_FMN: fmn_c + h2o_c --> pi_c + ribflv_c
# RBFSb: 2.0 dmlz_c --> 4r5au_c + ribflv_c
# NDP3: gdp_c + h2o_c --> gmp_c + h_c + pi_c
# CDPPH: cdp_c + h2o_c --> cmp_c + h_c + pi_c
# NDP7: h2o_c + udp_c --> h_c + pi_c + ump_c
# FBP: fdp_c + h2o_c --> f6p_c + pi_c
# EX_pi_e: pi_e <=>
# GLGC: atp_c + g1p_c + h_c --> adpglc_c + ppi_c
# ALATA_D2: ala__D_c + pydx5p_c --> pyam5p_c + pyr_c
# PYK: adp_c + h_c + pep_c --> atp_c + pyr_c
# SHCHD2: dscl_c + nad_c --> h_c + nadh_c + scl_c
# EX_co2_e: co2_e <=>
# A5PISO: ru5p__D_c <=> ara5p_c
# PMDPHT: 5aprbu_c + h2o_c --> 4r5au_c + pi_c
# CPPPGO: cpppg3_c + 2.0 h_c + o2_c --> 2.0 co2_c + 2.0 h2o_c + pppg9_c
# EX_met__L_e: met__L_e -->
# GTHOr: gthox_c + h_c + nadph_c <=> 2.0 gthrd_c + nadp_c
# ILETA: akg_c + ile__L_c <=> 3mop_c + glu__L_c
# DHORD5: dhor__S_c + mqn8_c --> mql8_c + orot_c
# EX_metsox_S__L_e: metsox_S__L_e -->
# GLYCTO2: glyclt_c + q8_c --> glx_c + q8h2_c
# VALTA: akg_c + val__L_c <=> 3mob_c + glu__L_c
# GLYCTO3: glyclt_c + mqn8_c --> glx_c + mql8_c
# IPPMIb: 2ippm_c + h2o_c <=> 3c3hmp_c
# GLYCTO4: 2dmmq8_c + glyclt_c --> 2dmmql8_c + glx_c
# ORPT: orot5p_c + ppi_c <=> orot_c + prpp_c
# RBFSa: 4r5au_c + db4p_c --> dmlz_c + 2.0 h2o_c + pi_c
# ACHBS: 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c
# PFK_3: atp_c + s7p_c --> adp_c + h_c + s17bp_c
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c
# TRPS2: indole_c + ser__L_c --> h2o_c + trp__L_c
# PSCVT: pep_c + skm5p_c <=> 3psme_c + pi_c
# G3PD5: glyc3p_c + q8_c --> dhap_c + q8h2_c
# G1PP: g1p_c + h2o_c --> glc__D_c + pi_c
# PFL: coa_c + pyr_c --> accoa_c + for_c
# EX_acgam_e: acgam_e -->
# ANS: chor_c + gln__L_c --> anth_c + glu__L_c + h_c + pyr_c
# FRD2: fum_c + mql8_c --> mqn8_c + succ_c
# FRD3: 2dmmql8_c + fum_c --> 2dmmq8_c + succ_c
# ANPRT: anth_c + prpp_c --> ppi_c + pran_c
# POX: h2o_c + pyr_c + q8_c --> ac_c + co2_c + q8h2_c
# CHORM: chor_c --> pphn_c
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# CHORS: 3psme_c --> chor_c + pi_c
# IGPS: 2cpr5p_c + h_c --> 3ig3p_c + co2_c + h2o_c
# ACKr: ac_c + atp_c <=> actp_c + adp_c
# EX_cellb_e: cellb_e -->
# EX_crn_e: crn_e -->
# EX_hxan_e: hxan_e -->
# EX_ile__L_e: ile__L_e -->
# EX_chol_e: chol_e -->
# EX_fe3_e: fe3_e <=>
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c
# EX_lac__L_e: lac__L_e -->
# EX_leu__L_e: leu__L_e -->
# EX_glcn_e: glcn_e -->
# EX_no3_e: no3_e -->
# EX_h_e: h_e <=>
# DMATT: dmpp_c + ipdp_c --> grdp_c + ppi_c
# EX_orn_e: orn_e -->
# GRTT: grdp_c + ipdp_c --> frdp_c + ppi_c
# EX_gln__L_e: gln__L_e -->
# UPP3S: hmbil_c --> h2o_c + uppg3_c
# EX_pro__L_e: pro__L_e -->
# EX_glyc_e: glyc_e -->
# UPPDC1: 4.0 h_c + uppg3_c --> 4.0 co2_c + cpppg3_c
# EX_man_e: man_e -->
# TMDPP: pi_c + thymd_c <=> 2dr1p_c + thym_c
# EX_ade_e: ade_e -->
# EX_mn2_e: mn2_e <=>
# EX_4abut_e: 4abut_e -->
# EX_ac_e: ac_e -->
# EX_akg_e: akg_e -->
# EX_ala__L_e: ala__L_e -->
# EX_arg__L_e: arg__L_e -->
# EX_asp__L_e: asp__L_e -->
# EX_pyr_e: pyr_e -->
# EX_succ_e: succ_e -->
# EX_thymd_e: thymd_e -->
# EX_rib__D_e: rib__D_e -->
# EX_tyr__L_e: tyr__L_e -->
# EX_cytd_e: cytd_e -->
# EX_dcyt_e: dcyt_e -->
# MOAT: ckdo_c + lipidA_c --> cmp_c + h_c + kdolipid4_c
# EX_fum_e: fum_e -->
# EX_sbt__D_e: sbt__D_e -->
# EX_glu__L_e: glu__L_e -->
# UDCPDPS: frdp_c + 8.0 ipdp_c --> 8.0 ppi_c + udcpdp_c
# ECOAH6: 3htdcoa_c <=> h2o_c + td2coa_c
# USHD: h2o_c + u23ga_c --> 2.0 h_c + lipidX_c + ump_c
# EX_gua_e: gua_e -->
# ENO: 2pg_c <=> h2o_c + pep_c
# FBA: fdp_c <=> dhap_c + g3p_c
# HCO3E: co2_c + h2o_c <=> h_c + hco3_c
# MGSA: dhap_c --> mthgxl_c + pi_c
# IMPC: h2o_c + imp_c <=> fprica_c
# IMPD: h2o_c + imp_c + nad_c --> h_c + nadh_c + xmp_c
# PPS: atp_c + h2o_c + pyr_c --> amp_c + 2.0 h_c + pep_c + pi_c
# ECOAH4: 3hdcoa_c <=> dc2coa_c + h2o_c
# LPADSS: lipidX_c + u23ga_c --> h_c + lipidAds_c + udp_c
# GLUTRS: atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
# TDSK: atp_c + lipidAds_c --> adp_c + h_c + lipidA_c
# PGI: g6p_c <=> f6p_c
# TMPPP: 2mahmp_c + 4mpetz_c + h_c --> ppi_c + thmmp_c
# EX_btn_e: btn_e -->
# PGK: 3pg_c + atp_c <=> 13dpg_c + adp_c
# EX_ptrc_e: ptrc_e -->
# EDA: 2ddg6p_c --> g3p_c + pyr_c
# EX_spmd_e: spmd_e -->
# EX_thym_e: thym_e -->
# EX_xtsn_e: xtsn_e -->
# NTPP1: dgtp_c + h2o_c --> dgmp_c + h_c + ppi_c
# URIK1: atp_c + uri_c --> adp_c + h_c + ump_c
# URIK2: gtp_c + uri_c --> gdp_c + h_c + ump_c
# NTPP2: gtp_c + h2o_c --> gmp_c + h_c + ppi_c
# PGL: 6pgl_c + h2o_c --> 6pgc_c + h_c
# NTPTP1: dgtp_c + h2o_c --> dgsn_c + pppi_c
# NTPTP2: gtp_c + h2o_c --> gsn_c + pppi_c
# CYTDK1: atp_c + cytd_c --> adp_c + cmp_c + h_c
# RPE: ru5p__D_c <=> xu5p__D_c
# DHQTi: 3dhq_c --> 3dhsk_c + h2o_c
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c
# AIRC3: 5aizc_c <=> 5caiz_c
# TALA: g3p_c + s7p_c <=> e4p_c + f6p_c
# PUNP1: adn_c + pi_c <=> ade_c + r1p_c
# PUNP2: dad_2_c + pi_c <=> 2dr1p_c + ade_c
# PUNP3: gsn_c + pi_c <=> gua_c + r1p_c
# ADSL2r: 25aics_c <=> aicar_c + fum_c
# TKT1: r5p_c + xu5p__D_c <=> g3p_c + s7p_c
# EX_fe2_e: fe2_e <=>
# PUNP5: ins_c + pi_c <=> hxan_c + r1p_c
# PUNP6: din_c + pi_c <=> 2dr1p_c + hxan_c
# PUNP7: pi_c + xtsn_c <=> r1p_c + xan_c
# G6PDA: gam6p_c + h2o_c --> f6p_c + nh4_c
# RNDR1: adp_c + trdrd_c --> dadp_c + h2o_c + trdox_c
# ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trdox_c
# RNDR4: trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
# ALDD2y: acald_c + h2o_c + nadp_c --> ac_c + 2.0 h_c + nadph_c
# TMDS: dump_c + mlthf_c --> dhf_c + dtmp_c
# RMI: rmn_c <=> rml_c
# TMDK1: atp_c + thymd_c --> adp_c + dtmp_c + h_c
# LYSAM: lys__L_c <=> 36dahx_c
# PPCDC: 4ppcys_c + h_c --> co2_c + pan4p_c
# FTHFD: 10fthf_c + h2o_c --> for_c + h_c + thf_c
# EX_glc__D_e: glc__D_e <=>
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c
# IPPMIa: 3c2hmp_c <=> 2ippm_c + h2o_c
# EX_alltn_e: alltn_e -->
# G3PD7: 2dmmq8_c + glyc3p_c --> 2dmmql8_c + dhap_c
# EDD: 6pgc_c --> 2ddg6p_c + h2o_c
# EX_ura_e: ura_e -->
# NADH9: 2dmmq8_c + h_c + nadh_c --> 2dmmql8_c + nad_c
# EX_val__L_e: val__L_e -->
# NADH10: h_c + mqn8_c + nadh_c --> mql8_c + nad_c
# ADK4: amp_c + itp_c <=> adp_c + idp_c
# INSK: atp_c + ins_c --> adp_c + h_c + imp_c
# MDH: mal__L_c + nad_c <=> h_c + nadh_c + oaa_c
# ABTA: 4abut_c + akg_c --> glu__L_c + sucsal_c
# EX_xan_e: xan_e -->
# FUM: fum_c + h2o_c <=> mal__L_c
# FMNAT: atp_c + fmn_c + h_c --> fad_c + ppi_c
# PYDXNK: atp_c + pydxn_c --> adp_c + h_c + pdx5p_c
# PYAM5PO: h2o_c + o2_c + pyam5p_c --> h2o2_c + nh4_c + pydx5p_c
# SSALx: h2o_c + nad_c + sucsal_c --> 2.0 h_c + nadh_c + succ_c
# ASPT: asp__L_c --> fum_c + nh4_c
# OHPBAT: glu__L_c + ohpb_c <=> akg_c + phthr_c
# SERD_L: ser__L_c --> nh4_c + pyr_c
# EX_dgsn_e: dgsn_e -->
# NADDP: h2o_c + nad_c --> amp_c + 2.0 h_c + nmn_c
# EX_arab__L_e: arab__L_e -->
# EX_fru_e: fru_e -->
# THRD: nad_c + thr__L_c --> 2aobut_c + h_c + nadh_c
# HEX4: atp_c + man_c --> adp_c + h_c + man6p_c
# EX_gal_e: gal_e -->
# NMNAT: atp_c + h_c + nmn_c --> nad_c + ppi_c
# EX_xyl__D_e: xyl__D_e -->
# KARA1: 23dhmb_c + nadp_c <=> alac__S_c + h_c + nadph_c
# HMPK1: 4ahmmp_c + atp_c --> 4ampm_c + adp_c + h_c
# KARA2: 2ahbut_c + h_c + nadph_c <=> 23dhmp_c + nadp_c
# EX_duri_e: duri_e -->
# EX_for_e: for_e -->
# EX_gly_e: gly_e -->
# EX_h2_e: h2_e -->
# EX_lys__L_e: lys__L_e -->
# ACCOAC: accoa_c + atp_c + hco3_c --> adp_c + h_c + malcoa_c + pi_c
# NADK: atp_c + nad_c --> adp_c + h_c + nadp_c
# GLXCL: 2.0 glx_c + h_c --> 2h3oppan_c + co2_c
# ICHORS_copy2: chor_c <=> ichor_c
# SUCBZS: 2shchc_c --> h2o_c + sucbz_c
# DHBD: 23ddhb_c + nad_c <=> 23dhb_c + h_c + nadh_c
# ICHORT: h2o_c + ichor_c --> 23ddhb_c + pyr_c
# EX_ser__L_e: ser__L_e -->
# EX_thm_e: thm_e -->
# EX_trp__L_e: trp__L_e -->
# GLUTRR: glutrna_c + h_c + nadph_c --> glu1sa_c + nadp_c + trnaglu_c
# GLCS1: adpglc_c --> adp_c + glycogen_c + h_c
# GLCP: glycogen_c + pi_c --> g1p_c
# EX_din_e: din_e -->
# RBK_L1: atp_c + rbl__L_c --> adp_c + h_c + ru5p__L_c
# RBP4E: ru5p__L_c <=> xu5p__D_c
# TARTD: tartr__L_c --> h2o_c + oaa_c
# NTD2: h2o_c + ump_c --> pi_c + uri_c
# GLCRAL: 5dh4dglc_c --> 2h3oppan_c + pyr_c
# NTD4: cmp_c + h2o_c --> cytd_c + pi_c
# NTD5: dtmp_c + h2o_c --> pi_c + thymd_c
# EX_fmn_e: fmn_e -->
# EX_gthox_e: gthox_e -->
# KAS14: acACP_c + h_c + malACP_c --> ACP_c + actACP_c + co2_c
# HEMEOS: frdp_c + h2o_c + pheme_c --> hemeO_c + ppi_c
# ADMDC: amet_c + h_c --> ametam_c + co2_c
# AGMT: agm_c + h2o_c --> ptrc_c + urea_c
# NTD6: damp_c + h2o_c --> dad_2_c + pi_c
# LGTHL: gthrd_c + mthgxl_c --> lgt__S_c
# PYDXPP: h2o_c + pydx5p_c --> pi_c + pydx_c
# PDXPP: h2o_c + pdx5p_c --> pi_c + pydxn_c
# ARGDC: arg__L_c + h_c --> agm_c + co2_c
# HACD6: 3otdcoa_c + h_c + nadh_c <=> 3htdcoa_c + nad_c
# ECOAH1: 3hbcoa_c <=> b2coa_c + h2o_c
# ECOAH2: 3hhcoa_c <=> h2o_c + hx2coa_c
# ARGSS: asp__L_c + atp_c + citr__L_c --> amp_c + argsuc_c + h_c + ppi_c
# AGPR: acg5sa_c + nadp_c + pi_c <=> acg5p_c + h_c + nadph_c
# SPMS: ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c
# G1SAT: glu1sa_c <=> 5aop_c
# KDOCT2: ctp_c + kdo_c --> ckdo_c + ppi_c
# ECOAH3: 3hocoa_c <=> h2o_c + oc2coa_c
# UGLT: gal1p_c + udpg_c <=> g1p_c + udpgal_c
# EDTXS1: ddcaACP_c + kdo2lipid4_c --> ACP_c + kdo2lipid4L_c
# DXPS: g3p_c + h_c + pyr_c --> co2_c + dxyl5p_c
# OAADC: h_c + oaa_c --> co2_c + pyr_c
# MNNH: mana_c --> 2ddglcn_c + h2o_c
# CDPMEK: 4c2me_c + atp_c --> 2p4c2me_c + adp_c + h_c
# EDTXS2: kdo2lipid4L_c + myrsACP_c --> ACP_c + lipa_c
# ALTRH: altrn_c --> 2ddglcn_c + h2o_c
# MECDPS: 2p4c2me_c --> 2mecdp_c + cmp_c
# GUI1: glcur_c <=> fruur_c
# EDTXS3: hdeACP_c + kdo2lipid4_c --> ACP_c + kdo2lipid4p_c
# PGAMT: gam1p_c <=> gam6p_c
# DDGLK: 2ddglcn_c + atp_c --> 2ddg6p_c + adp_c + h_c
# EDTXS4: kdo2lipid4p_c + myrsACP_c --> ACP_c + lipa_cold_c
# XYLI2: glc__D_c <=> fru_c
# PMANM: man1p_c <=> man6p_c
# ICL: icit_c --> glx_c + succ_c
# UAGDP: acgam1p_c + h_c + utp_c --> ppi_c + uacgam_c
# UAGCVT: pep_c + uacgam_c --> pi_c + uaccg_c
# GLUR: glu__D_c <=> glu__L_c
# EX_tmao_e: tmao_e -->
# UAG2E: uacgam_c <=> uacmam_c
# EX_acald_e: acald_e -->
# GLYCL: gly_c + nad_c + thf_c --> co2_c + mlthf_c + nadh_c + nh4_c
# CMPN: cmp_c + h2o_c --> csn_c + r5p_c
# NNDPR: 2.0 h_c + prpp_c + quln_c --> co2_c + nicrnt_c + ppi_c
# HCYSMT: amet_c + hcys__L_c --> ahcys_c + h_c + met__L_c
# EX_melib_e: melib_e -->
# MACPD: h_c + malACP_c --> acACP_c + co2_c
# DMQMT: 2omhmbl_c + amet_c --> ahcys_c + h_c + q8h2_c
# UDPG4E: udpg_c <=> udpgal_c
# LACZ: h2o_c + lcts_c --> gal_c + glc__D_c
# TRE6PH: h2o_c + tre6p_c --> g6p_c + glc__D_c
# XYLI1: xyl__D_c <=> xylu__D_c
# PPC: co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c
# ICHORS_copy1: chor_c --> ichor_c
# EX_sucr_e: sucr_e -->
# ALDD4: btal_c + h2o_c + nad_c --> but_c + 2.0 h_c + nadh_c
# HACD4: 3odcoa_c + h_c + nadh_c <=> 3hdcoa_c + nad_c
# G3PT: glyc3p_c + h2o_c --> glyc_c + pi_c
# CINNDO: cinnm_c + h_c + nadh_c + o2_c --> cenchddd_c + nad_c
# DHPPD: cechddd_c + nad_c --> dhpppn_c + h_c + nadh_c
# EX_tre_e: tre_e -->
# EX_zn2_e: zn2_e <=>
# HACD5: 3oddcoa_c + h_c + nadh_c <=> 3hddcoa_c + nad_c
# DHCIND: cenchddd_c + nad_c --> dhcinnm_c + h_c + nadh_c
# HACD7: 3ohdcoa_c + h_c + nadh_c <=> 3hhdcoa_c + nad_c
# CITL: cit_c --> ac_c + oaa_c
# GOFUCR: gdpofuc_c + h_c + nadph_c --> gdpfuc_c + nadp_c
# PYDXK: atp_c + pydx_c --> adp_c + h_c + pydx5p_c
# DNMPPA: dhpmp_c + h2o_c --> dhnpt_c + pi_c
# HPPK2: 6hmhpt_c + atp_c --> 6hmhptpp_c + amp_c + h_c
# PTPATi: atp_c + h_c + pan4p_c --> dpcoa_c + ppi_c
# HEX7: atp_c + fru_c --> adp_c + f6p_c + h_c
# DXPRIi: dxyl5p_c + h_c + nadph_c --> 2me4p_c + nadp_c
# GTPCII2: gtp_c + 3.0 h2o_c --> 25drapp_c + for_c + 2.0 h_c + ppi_c
# URIC: 2.0 h2o_c + o2_c + urate_c --> alltn_c + co2_c + h2o2_c
# SADT2: atp_c + gtp_c + h2o_c + so4_c --> aps_c + gdp_c + pi_c + ppi_c
# OPHBDC: 3ophb_c + h_c --> 2oph_c + co2_c
# AACPS1: ACP_c + atp_c + ttdca_c --> amp_c + myrsACP_c + ppi_c
# OHPHM: 2ohph_c + amet_c --> 2omph_c + ahcys_c + h_c
# GHMT2r: ser__L_c + thf_c <=> gly_c + h2o_c + mlthf_c
# DHORD2: dhor__S_c + q8_c --> orot_c + q8h2_c
# LCARS: h_c + lald__L_c + nadh_c <=> 12ppd__S_c + nad_c
# ALCD19: glyald_c + h_c + nadh_c <=> glyc_c + nad_c
# RMPA: rml1p_c <=> dhap_c + lald__L_c
# SBTPD: nad_c + sbt6p_c <=> f6p_c + h_c + nadh_c
# PFK_2: atp_c + tag6p__D_c --> adp_c + h_c + tagdp__D_c
# GLTPD: galt1p_c + nad_c <=> h_c + nadh_c + tag6p__D_c
# EX_hdcea_e: hdcea_e -->
# ACACCT: acac_c + accoa_c --> aacoa_c + ac_c
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c
# BUTCT: accoa_c + but_c --> ac_c + btcoa_c
# TGBPA: tagdp__D_c <=> dhap_c + g3p_c
# MANAO: mana_c + nad_c <=> fruur_c + h_c + nadh_c
# TAGURr: altrn_c + nad_c <=> h_c + nadh_c + tagur_c
# DMSOR1: dmso_c + mql8_c --> dms_c + h2o_c + mqn8_c
# PGLYCP: 2pglyc_c + h2o_c --> glyclt_c + pi_c
# 2DGULRx: 2dhguln_c + h_c + nadh_c --> idon__L_c + nad_c
# DKGLCNR2y: 25dkglcn_c + h_c + nadph_c --> 5dglcn_c + nadp_c
# G1PTT: dttp_c + g1p_c + h_c --> dtdpglu_c + ppi_c
# TDPGDH: dtdpglu_c --> dtdp4d6dg_c + h2o_c
# ADCS: chor_c + gln__L_c --> 4adcho_c + glu__L_c
# ADCL: 4adcho_c --> 4abz_c + h_c + pyr_c
# 2DGULRy: 2dhguln_c + h_c + nadph_c --> idon__L_c + nadp_c
# DHAPT: dha_c + pep_c --> dhap_c + pyr_c
# EX_lac__D_e: lac__D_e -->
# UDPGALM: udpgal_c --> udpgalfur_c
# TDPDRE: dtdp4d6dg_c --> dtdp4d6dm_c
# TDPDRR: dtdp4d6dm_c + h_c + nadph_c --> dtdprmn_c + nadp_c
# UMPK: atp_c + ump_c <=> adp_c + udp_c
# RZ5PP: 5prdmbz_c + h2o_c --> pi_c + rdmbzi_c
# DDPGALA: 2dh3dgal6p_c <=> g3p_c + pyr_c
# DURIK1: atp_c + duri_c --> adp_c + dump_c + h_c
# G3PD6: glyc3p_c + mqn8_c --> dhap_c + mql8_c
# ALLTN: alltn_c + h2o_c --> alltt_c + h_c
# UAPGR: h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
# UPPRT: prpp_c + ura_c --> ppi_c + ump_c
# NTD9: gmp_c + h2o_c --> gsn_c + pi_c
# CTPS2: atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c
# NTD1: dump_c + h2o_c --> duri_c + pi_c
# NTD7: amp_c + h2o_c --> adn_c + pi_c
# PAPPT3: udcpp_c + ugmda_c --> uagmda_c + ump_c
# UAGPT3: uacgam_c + uagmda_c --> h_c + uaagmda_c + udp_c
# NDPK7: atp_c + dcdp_c <=> adp_c + dctp_c
# AOBUTDs: 2aobut_c + h_c --> aact_c + co2_c
# GLYAT: accoa_c + gly_c <=> 2aobut_c + coa_c
# ADNUC: adn_c + h2o_c --> ade_c + rib__D_c
# GMHEPPA: gmhep17bp_c + h2o_c --> gmhep1p_c + pi_c
# S7PI: s7p_c --> gmhep7p_c
# TRPS3: 3ig3p_c --> g3p_c + indole_c
# EX_ttdcea_e: ttdcea_e -->
# F6PA: f6p_c <=> dha_c + g3p_c
# AGMHE: adphep_DD_c --> adphep_LD_c
# CRNBTCT: bbtcoa_c + crn_c <=> crncoa_c + gbbtn_c
# CRNCBCT: crn_c + ctbtcoa_c <=> crncoa_c + ctbt_c
# NTD10: h2o_c + xmp_c --> pi_c + xtsn_c
# CRNCDH: crncoa_c <=> ctbtcoa_c + h2o_c
# GMHEPAT: atp_c + gmhep1p_c + h_c --> adphep_DD_c + ppi_c
# EX_h2s_e: h2s_e -->
# ADPT: ade_c + prpp_c --> amp_c + ppi_c
# EX_gthrd_e: gthrd_e -->
# IDOND: 5dglcn_c + h_c + nadh_c <=> idon__L_c + nad_c
# IDOND2: 5dglcn_c + h_c + nadph_c --> idon__L_c + nadp_c
# FADRx: fad_c + h_c + nadh_c --> fadh2_c + nad_c
# GTPDPK: atp_c + gtp_c --> amp_c + gdptp_c + h_c
# NADN: h2o_c + nad_c --> adprib_c + h_c + ncam_c
# GLYCLTDx: glx_c + h_c + nadh_c --> glyclt_c + nad_c
# ADK1: amp_c + atp_c <=> 2.0 adp_c
# NDPK2: atp_c + udp_c <=> adp_c + utp_c
# NDPK3: atp_c + cdp_c <=> adp_c + ctp_c
# HPYRRy: h_c + hpyr_c + nadph_c --> glyc__R_c + nadp_c
# NDPK4: atp_c + dtdp_c <=> adp_c + dttp_c
# ACODA: acorn_c + h2o_c --> ac_c + orn_c
# ADA: adn_c + h2o_c + h_c --> ins_c + nh4_c
# DADA: dad_2_c + h2o_c + h_c --> din_c + nh4_c
# ADD: ade_c + h2o_c + h_c --> hxan_c + nh4_c
# FCLT: fe2_c + ppp9_c --> 2.0 h_c + pheme_c
# HBZOPT: 4hbz_c + octdp_c --> 3ophb_c + ppi_c
# PNTK: atp_c + pnto__R_c --> 4ppan_c + adp_c + h_c
# ADSS: asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
# AGDC: acgam6p_c + h2o_c --> ac_c + gam6p_c
# OCTDPS: frdp_c + 5.0 ipdp_c --> octdp_c + 5.0 ppi_c
# ASNN: asn__L_c + h2o_c --> asp__L_c + nh4_c
# DPCOAK: atp_c + dpcoa_c --> adp_c + coa_c + h_c
# HETZK: 4mhetz_c + atp_c --> 4mpetz_c + adp_c + h_c
# ASNS2: asp__L_c + atp_c + nh4_c --> amp_c + asn__L_c + h_c + ppi_c
# ASPCT: asp__L_c + cbp_c --> cbasp_c + h_c + pi_c
# KDOPS: ara5p_c + h2o_c + pep_c --> kdo8p_c + pi_c
# KDOPP: h2o_c + kdo8p_c --> kdo_c + pi_c
# DMPPS: h2mb4p_c + h_c + nadh_c --> dmpp_c + h2o_c + nad_c
# EX_26dap__M_e: 26dap__M_e -->
# MCOATA: ACP_c + malcoa_c <=> coa_c + malACP_c
# IPDPS: h2mb4p_c + h_c + nadh_c --> h2o_c + ipdp_c + nad_c
# AST: arg__L_c + succoa_c --> coa_c + h_c + sucarg_c
# SGDS: h2o_c + sucglu_c --> glu__L_c + succ_c
# CYNTAH: cynt_c + 3.0 h_c + hco3_c --> 2.0 co2_c + nh4_c
# DAPE: 26dap_LL_c <=> 26dap__M_c
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c
# EX_acnam_e: acnam_e -->
# HSK: atp_c + hom__L_c --> adp_c + h_c + phom_c
# SDPTA: akg_c + sl26da_c <=> glu__L_c + sl2a6o_c
# GSPMDA: gtspmd_c + h2o_c --> gthrd_c + spmd_c
# GSPMDS: atp_c + gthrd_c + spmd_c --> adp_c + gtspmd_c + h_c + pi_c
# GUAD: gua_c + h2o_c + h_c --> nh4_c + xan_c
# THRS: h2o_c + phom_c --> pi_c + thr__L_c
# EX_amp_e: amp_e -->
# HSST: hom__L_c + succoa_c --> coa_c + suchms_c
# PPNDH: h_c + pphn_c --> co2_c + h2o_c + phpyr_c
# TMAOR1: h_c + mql8_c + tmao_c --> h2o_c + mqn8_c + tma_c
# TMAOR2: 2dmmql8_c + h_c + tmao_c --> 2dmmq8_c + h2o_c + tma_c
# DGK1: atp_c + dgmp_c <=> adp_c + dgdp_c
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c
# NDPK1: atp_c + gdp_c <=> adp_c + gtp_c
# TRDR: h_c + nadph_c + trdox_c --> nadp_c + trdrd_c
# DDPA: e4p_c + h2o_c + pep_c --> 2dda7p_c + pi_c
# NMNDA: h2o_c + nmn_c --> nh4_c + nicrnt_c
# NNAM: h2o_c + ncam_c --> nac_c + nh4_c
# P5CD: 1pyr5c_c + 2.0 h2o_c + nad_c --> glu__L_c + h_c + nadh_c
# PGMT: g1p_c <=> g6p_c
# FRUK: atp_c + f1p_c --> adp_c + fdp_c + h_c
# SPMDAT1: accoa_c + spmd_c --> N1aspmd_c + coa_c + h_c
# RHCCE: rhcys_c --> dhptd_c + hcys__L_c
# EX_dha_e: dha_e -->
# KG6PDC: 3dhgulnp_c + h_c --> co2_c + xu5p__L_c
# SPMDAT2: accoa_c + spmd_c --> coa_c + h_c + n8aspmd_c
# TDPADGAT: accoa_c + dtdp4addg_c --> coa_c + dtdp4aaddg_c + h_c
# MALS: accoa_c + glx_c + h2o_c --> coa_c + h_c + mal__L_c
# X5PL3E: xu5p__L_c --> ru5p__L_c
# DOGULNR: 23doguln_c + h_c + nadh_c --> 3dhguln_c + nad_c
# TRE6PP: h2o_c + tre6p_c --> pi_c + tre_c
# EX_fuc__L_e: fuc__L_e -->
# EX_met__D_e: met__D_e -->
# EX_tartr__L_e: tartr__L_e -->
# BETALDHx: betald_c + h2o_c + nad_c --> glyb_c + 2.0 h_c + nadh_c
# BETALDHy: betald_c + h2o_c + nadp_c --> glyb_c + 2.0 h_c + nadph_c
# MLTG3: h2o_c + maltpt_c --> glc__D_c + maltttr_c
# EX_taur_e: taur_e -->
# EX_maltpt_e: maltpt_e -->
# EX_glyald_e: glyald_e -->
# EX_glcur_e: glcur_e -->
# ADPRDP: adprib_c + h2o_c --> amp_c + 2.0 h_c + r5p_c
# DKGLCNR1: 25dkglcn_c + h_c + nadph_c --> 2dhguln_c + nadp_c
# NADTRHD: nad_c + nadph_c --> nadh_c + nadp_c
# AACPS2: ACP_c + atp_c + ttdcea_c --> amp_c + ppi_c + tdeACP_c
# FMNRx2: fmn_c + h_c + nadph_c --> fmnh2_c + nadp_c
# ACPS1: apoACP_c + coa_c --> ACP_c + h_c + pap_c
# EX_nmn_e: nmn_e -->
# EX_urea_e: urea_e -->
# ARAI: arab__L_c <=> rbl__L_c
# M1PD: mnl1p_c + nad_c <=> f6p_c + h_c + nadh_c
# G3PD2: glyc3p_c + nadp_c <=> dhap_c + h_c + nadph_c
# GALS3: h2o_c + melib_c --> gal_c + glc__D_c
# FCI: fuc__L_c <=> fcl__L_c
# FCLK: atp_c + fcl__L_c --> adp_c + fc1p_c + h_c
# FCLPA: fc1p_c <=> dhap_c + lald__L_c
# GMPS2: atp_c + gln__L_c + h2o_c + xmp_c --> amp_c + glu__L_c + gmp_c + 2.0 h_c + ppi_c
# AMPN: amp_c + h2o_c --> ade_c + r5p_c
# GSNK: atp_c + gsn_c --> adp_c + gmp_c + h_c
# ACCOAL: atp_c + coa_c + ppa_c --> adp_c + pi_c + ppcoa_c
# GALUi: g1p_c + h_c + utp_c --> ppi_c + udpg_c
# AACPS3: ACP_c + atp_c + hdca_c --> amp_c + palmACP_c + ppi_c
# U23GAAT: 3hmrsACP_c + u3hga_c --> ACP_c + h_c + u23ga_c
# EX_f6p_e: f6p_e -->
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c
# AACPS4: ACP_c + atp_c + hdcea_c --> amp_c + hdeACP_c + ppi_c
# UAMAS: ala__L_c + atp_c + uamr_c --> adp_c + h_c + pi_c + uama_c
# UAMAGS: atp_c + glu__D_c + uama_c --> adp_c + h_c + pi_c + uamag_c
# UGLYCH: h2o_c + 2.0 h_c + urdglyc_c --> co2_c + glx_c + 2.0 nh4_c
# NTPP3: dctp_c + h2o_c --> dcmp_c + h_c + ppi_c
# NTPP6: atp_c + h2o_c --> amp_c + h_c + ppi_c
# NTPP7: dttp_c + h2o_c --> dtmp_c + h_c + ppi_c
# OP4ENH: h2o_c + op4en_c --> 4h2opntn_c
# EX_rmn_e: rmn_e -->
# HOPNTAL: 4h2opntn_c --> acald_c + pyr_c
# NTPP8: h2o_c + utp_c --> h_c + ppi_c + ump_c
# P5CR: 1pyr5c_c + 2.0 h_c + nadph_c --> nadp_c + pro__L_c
# CYANST: cyan_c + tsul_c --> h_c + so3_c + tcynt_c
# EX_ttdca_e: ttdca_e -->
# DHPPDA2: 25drapp_c + h2o_c + h_c --> 5apru_c + nh4_c
# 3HPPPNH: 3hpppn_c + h_c + nadh_c + o2_c --> dhpppn_c + h2o_c + nad_c
# G5SADs: glu5sa_c --> 1pyr5c_c + h2o_c + h_c
# GMAND: gdpmann_c --> gdpddman_c + h2o_c
# PPCSCT: ppcoa_c + succ_c --> ppa_c + succoa_c
# CYTD: cytd_c + h2o_c + h_c --> nh4_c + uri_c
# AKGDH: akg_c + coa_c + nad_c --> co2_c + nadh_c + succoa_c
# HPYRRx: h_c + hpyr_c + nadh_c --> glyc__R_c + nad_c
# GLYCDx: glyc_c + nad_c --> dha_c + h_c + nadh_c
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c
# UGMDDS: alaala_c + atp_c + ugmd_c --> adp_c + h_c + pi_c + ugmda_c
# DCYTD: dcyt_c + h2o_c + h_c --> duri_c + nh4_c
# DBTS: atp_c + co2_c + dann_c --> adp_c + dtbt_c + 3.0 h_c + pi_c
# DCTPD: dctp_c + h2o_c + h_c --> dutp_c + nh4_c
# UHGADA: h2o_c + u3aga_c --> ac_c + u3hga_c
# AMANK: acmana_c + atp_c --> acmanap_c + adp_c + h_c
# UAGAAT: 3hmrsACP_c + uacgam_c <=> ACP_c + u3aga_c
# ATPPRT: atp_c + prpp_c --> ppi_c + prbatp_c
# HISTD: h2o_c + histd_c + 2.0 nad_c --> 3.0 h_c + his__L_c + 2.0 nadh_c
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c
# G1PACT: accoa_c + gam1p_c --> acgam1p_c + coa_c + h_c
# GART: atp_c + for_c + gar_c --> adp_c + fgam_c + h_c + pi_c
# CSND: csn_c + h2o_c + h_c --> nh4_c + ura_c
# GF6PTA: f6p_c + gln__L_c --> gam6p_c + glu__L_c
# IGPDH: eig3p_c --> h2o_c + imacp_c
# EX_glyclt_e: glyclt_e -->
# PRPPS: atp_c + r5p_c <=> amp_c + h_c + prpp_c
# H2SO: h2s_c + 2.0 o2_c --> 2.0 h_c + so4_c
# GLUCYS: atp_c + cys__L_c + glu__L_c --> adp_c + glucys_c + h_c + pi_c
# PRATPP: h2o_c + prbatp_c --> h_c + ppi_c + prbamp_c
# GLUN: gln__L_c + h2o_c --> glu__L_c + nh4_c
# PRMICI: prfp_c <=> prlp_c
# GLUPRT: gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c + pram_c
# EX_g6p_e: g6p_e -->
# GMPR: gmp_c + 2.0 h_c + nadph_c --> imp_c + nadp_c + nh4_c
# SERAT: accoa_c + ser__L_c <=> acser_c + coa_c
# CYSS: acser_c + h2s_c --> ac_c + cys__L_c + h_c
# NADS1: atp_c + dnad_c + nh4_c --> amp_c + h_c + nad_c + ppi_c
# BPNT: h2o_c + pap_c --> amp_c + pi_c
# EX_2ddglcn_e: 2ddglcn_e -->
# PAPSR: paps_c + trdrd_c --> 2.0 h_c + pap_c + so3_c + trdox_c
# ASPK: asp__L_c + atp_c <=> 4pasp_c + adp_c
# ASAD: aspsa_c + nadp_c + pi_c <=> 4pasp_c + h_c + nadph_c
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c
# EX_mmet_e: mmet_e -->
# NTRIR2x: 5.0 h_c + 3.0 nadh_c + no2_c --> 2.0 h2o_c + 3.0 nad_c + nh4_c
# OCBT: cbp_c + orn_c <=> citr__L_c + h_c + pi_c
# GARFT: 10fthf_c + gar_c <=> fgam_c + h_c + thf_c
# GPDDA1: g3pc_c + h2o_c --> chol_c + glyc3p_c + h_c
# GPDDA2: g3pe_c + h2o_c --> etha_c + glyc3p_c + h_c
# PHETA1: akg_c + phe__L_c <=> glu__L_c + phpyr_c
# PPND: nad_c + pphn_c --> 34hpp_c + co2_c + nadh_c
# METAT: atp_c + h2o_c + met__L_c --> amet_c + pi_c + ppi_c
# ASCBPL: ascb6p_c + h2o_c --> 3dhgulnp_c + h_c
# ACBIPGT: adocbip_c + gtp_c + h_c --> agdpcbi_c + ppi_c
# TRPS1: 3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
# PRAMPC: h2o_c + prbamp_c --> prfp_c
# ADOCBLS: agdpcbi_c + rdmbzi_c --> adocbl_c + gmp_c + h_c
# EX_galct__D_e: galct__D_e -->
# ADOCBIK: adocbi_c + atp_c --> adocbip_c + adp_c + h_c
# TMPK: atp_c + thmmp_c --> adp_c + thmpp_c
# HPPPNDO: dhpppn_c + o2_c --> h_c + hkndd_c
# MCITL2: micit_c <=> pyr_c + succ_c
# DXYLK: atp_c + dxyl_c --> adp_c + dxyl5p_c + h_c
# MDH3: mal__L_c + mqn8_c --> mql8_c + oaa_c
# SOTA: akg_c + sucorn_c --> glu__L_c + sucgsa_c
# DHCINDO: dhcinnm_c + o2_c --> h_c + hkntd_c
# SGSAD: h2o_c + nad_c + sucgsa_c --> 2.0 h_c + nadh_c + sucglu_c
# HKNDDH: h2o_c + hkndd_c --> h_c + op4en_c + succ_c
# EX_idon__L_e: idon__L_e -->
# HKNTDH: h2o_c + hkntd_c --> fum_c + h_c + op4en_c
# GLYCK2: atp_c + glyc__R_c --> 2pg_c + adp_c + h_c
# PTA2: pi_c + ppcoa_c --> coa_c + ppap_c
# MDH2: mal__L_c + q8_c --> oaa_c + q8h2_c
# EX_indole_e: indole_e -->
# ACOTA: acorn_c + akg_c <=> acg5sa_c + glu__L_c
# GPDDA5: g3pi_c + h2o_c --> glyc3p_c + h_c + inost_c
# PDX5PS: dxyl5p_c + nad_c + phthr_c --> co2_c + 2.0 h2o_c + h_c + nadh_c + pdx5p_c + pi_c
# PPBNGS: 2.0 5aop_c --> 2.0 h2o_c + h_c + ppbng_c
# ENTCS: 3.0 23dhba_c + 3.0 seramp_c --> 6.0 amp_c + enter_c + 9.0 h_c
# SULR: 5.0 h_c + 3.0 nadph_c + so3_c --> 3.0 h2o_c + h2s_c + 3.0 nadp_c
# MANPGH: h2o_c + man6pglyc_c --> glyc__R_c + man6p_c
# URDGLYCD: nad_c + urdglyc_c --> h_c + nadh_c + oxur_c
# CBMKr: atp_c + co2_c + nh4_c <=> adp_c + cbp_c + 2.0 h_c
# PPNCL2: 4ppan_c + ctp_c + cys__L_c --> 4ppcys_c + cmp_c + h_c + ppi_c
# PRAGSr: atp_c + gly_c + pram_c <=> adp_c + gar_c + h_c + pi_c
# PRFGS: atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + fpram_c + glu__L_c + h_c + pi_c
# AMANAPEr: acmanap_c <=> acgam6p_c
# EX_3hcinnm_e: 3hcinnm_e -->
# ACM6PH: acmum6p_c + h2o_c --> acgam6p_c + lac__D_c
# NNATr: atp_c + h_c + nicrnt_c <=> dnad_c + ppi_c
# CYTDH: cytd_c + h2o_c --> csn_c + rib__D_c
# EX_acac_e: acac_e -->
# ETHAAL: etha_c --> acald_c + nh4_c
# MAN1PT2: gdp_c + h_c + man1p_c --> gdpmann_c + pi_c
# PSERT: 3php_c + glu__L_c --> akg_c + pser__L_c
# AP4AH: ap4a_c + h2o_c --> 2.0 adp_c + 2.0 h_c
# EX_acmana_e: acmana_e -->
# AP5AH: ap5a_c + h2o_c --> adp_c + atp_c + 2.0 h_c
# ADNCYC: atp_c --> camp_c + ppi_c
# AIRC2: air_c + atp_c + hco3_c --> 5caiz_c + adp_c + h_c + pi_c
# GAPD: g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
# MI1PP: h2o_c + mi1p__D_c --> inost_c + pi_c
# EX_galur_e: galur_e -->
# MCITS: h2o_c + oaa_c + ppcoa_c --> 2mcit_c + coa_c + h_c
# PPAKr: adp_c + ppap_c <=> atp_c + ppa_c
# HEX1: atp_c + glc__D_c --> adp_c + g6p_c + h_c
# GND: 6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c
# TAUDO: akg_c + o2_c + taur_c --> aacald_c + co2_c + h_c + so3_c + succ_c
# DM_amob_c: amob_c -->
# NTP3: gtp_c + h2o_c --> gdp_c + h_c + pi_c
# PPM2: 2dr1p_c <=> 2dr5p_c
# MOAT2: ckdo_c + kdolipid4_c --> cmp_c + h_c + kdo2lipid4_c
# EX_adn_e: adn_e -->
# EX_ins_e: ins_e -->
# G6PDH2r: g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c
# ME2: mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c
# ARGSL: argsuc_c <=> arg__L_c + fum_c
# CBPS: 2.0 atp_c + gln__L_c + h2o_c + hco3_c --> 2.0 adp_c + cbp_c + glu__L_c + 2.0 h_c + pi_c
# GLU5K: atp_c + glu__L_c --> adp_c + glu5p_c
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c
# EX_mg2_e: mg2_e <=>
# ACOATA: ACP_c + accoa_c <=> acACP_c + coa_c
# NADH5: h_c + nadh_c + q8_c --> nad_c + q8h2_c
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c
# EX_glyc3p_e: glyc3p_e -->
# MLTG2: h2o_c + maltttr_c --> glc__D_c + malttr_c
# EX_but_e: but_e -->
# MLTG1: h2o_c + malttr_c --> glc__D_c + malt_c
# AMALT3: malt_c + maltpt_c --> glc__D_c + malthx_c
# MLTP3: malthp_c + pi_c <=> g1p_c + malthx_c
# EX_lcts_e: lcts_e -->
# EX_ocdca_e: ocdca_e -->
# EX_cbl1_e: cbl1_e -->
# SPODM: 2.0 h_c + 2.0 o2s_c --> h2o2_c + o2_c
# AHCYSNS: ahcys_c + h2o_c --> ade_c + rhcys_c
# ACNML: acnam_c --> acmana_c + pyr_c
# TMK: atp_c + thm_c --> adp_c + h_c + thmmp_c
# NTPP4: ctp_c + h2o_c --> cmp_c + h_c + ppi_c
# GMPS: atp_c + nh4_c + xmp_c --> amp_c + gmp_c + 2.0 h_c + ppi_c
# CAT: 2.0 h2o2_c --> 2.0 h2o_c + o2_c
# FTHFLi: atp_c + for_c + thf_c --> 10fthf_c + adp_c + pi_c
# EX_nac_e: nac_e -->
# UDPGD: h2o_c + 2.0 nad_c + udpg_c --> 3.0 h_c + 2.0 nadh_c + udpglcur_c
# SERASr: atp_c + h_c + ser__L_c <=> ppi_c + seramp_c
# GLCRD: glcr_c --> 5dh4dglc_c + h2o_c
# PPPNDO: h_c + nadh_c + o2_c + pppn_c --> cechddd_c + nad_c
# 26DAHtex: 26dap__M_e <=> 26dap__M_p
# HCINNMtex: 3hcinnm_e <=> 3hcinnm_p
# HPPPNtex: 3hpppn_e <=> 3hpppn_p
# ACtex: ac_e <=> ac_p
# ACALDtex: acald_e <=> acald_p
# CHRPL: chor_c --> 4hbz_c + pyr_c
# TDPAGTA: dtdp4d6dg_c + glu__L_c --> akg_c + dtdp4addg_c
# UACMAMO: h2o_c + 2.0 nad_c + uacmam_c --> 3.0 h_c + 2.0 nadh_c + uacmamu_c
# FBA3: s17bp_c <=> dhap_c + e4p_c
# PMPK: 4ampm_c + atp_c --> 2mahmp_c + adp_c
# LCADi: h2o_c + lald__L_c + nad_c --> 2.0 h_c + lac__L_c + nadh_c
# ACMANAtex: acmana_e <=> acmana_p
# ACMUMtex: acmum_e --> acmum_p
# ACACT7r: accoa_c + tdcoa_c <=> 3ohdcoa_c + coa_c
# PSP_L: h2o_c + pser__L_c --> pi_c + ser__L_c
# ADK3: amp_c + gtp_c <=> adp_c + gdp_c
# GLUDC: glu__L_c + h_c --> 4abut_c + co2_c
# ACACT2r: accoa_c + btcoa_c <=> 3ohcoa_c + coa_c
# BSORy: btnso_c + h_c + nadph_c --> btn_c + h2o_c + nadp_c
# DMSOR2: 2dmmql8_c + dmso_c --> 2dmmq8_c + dms_c + h2o_c
# ADSK: aps_c + atp_c --> adp_c + h_c + paps_c
# ACACT3r: accoa_c + hxcoa_c <=> 3oocoa_c + coa_c
# ACACT4r: accoa_c + occoa_c <=> 3odcoa_c + coa_c
# SUCCt2_2pp: 2.0 h_p + succ_p --> 2.0 h_c + succ_c
# SUCFUMtpp: fum_p + succ_c <=> fum_c + succ_p
# HSDy: hom__L_c + nadp_c <=> aspsa_c + h_c + nadph_c
# CYSTL: cyst__L_c + h2o_c --> hcys__L_c + nh4_c + pyr_c
# ACMAMUT: uacmamu_c + unaga_c --> h_c + udp_c + unagamu_c
# SHSL1: cys__L_c + suchms_c --> cyst__L_c + h_c + succ_c
# SSALy: h2o_c + nadp_c + sucsal_c --> 2.0 h_c + nadph_c + succ_c
# SUCptspp: pep_c + sucr_p --> pyr_c + suc6p_c
# SULabcpp: atp_c + h2o_c + so4_p --> adp_c + h_c + pi_c + so4_c
# TSULabcpp: atp_c + h2o_c + tsul_p --> adp_c + h_c + pi_c + tsul_c
# TARTRt7pp: succ_c + tartr__L_p <=> succ_p + tartr__L_c
# EX_dad_2_e: dad_2_e -->
# EX_ser__D_e: ser__D_e -->
# DDGALK: 2dh3dgal_c + atp_c --> 2dh3dgal6p_c + adp_c + h_c
# EX_gam6p_e: gam6p_e -->
# EX_15dap_e: 15dap_e -->
# AB6PGH: arbt6p_c + h2o_c --> g6p_c + hqn_c
# EX_ocdcea_e: ocdcea_e -->
# EX_cynt_e: cynt_e -->
# EX_galctn__D_e: galctn__D_e -->
# AMALT1: malt_c + malttr_c --> glc__D_c + maltttr_c
# EX_glyb_e: glyb_e -->
# AHGDx: S2hglut_c + nad_c <=> akg_c + h_c + nadh_c
# MLTP2: malthx_c + pi_c <=> g1p_c + maltpt_c
# TAURabcpp: atp_c + h2o_c + taur_p --> adp_c + h_c + pi_c + taur_c
# THMDt2pp_copy1: h_p + thymd_p --> h_c + thymd_c
# 3HCINNMH: 3hcinnm_c + h_c + nadh_c + o2_c --> dhcinnm_c + h2o_c + nad_c
# BSORx: btnso_c + h_c + nadh_c --> btn_c + h2o_c + nad_c
# PACCOAL: atp_c + coa_c + pac_c --> amp_c + phaccoa_c + ppi_c
# NMNt7pp: h2o_c + nmn_p --> h_c + ncam_c + r5p_c
# EX_ca2_e: ca2_e <=>
# EX_so3_e: so3_e -->
# GLUtex: glu__L_e <=> glu__L_p
# Kt2pp: h_p + k_p --> h_c + k_c
# GLYtex: gly_e <=> gly_p
# GP4GH: gp4g_c + h2o_c --> 2.0 gdp_c + 2.0 h_c
# GLYALDtex: glyald_e <=> glyald_p
# AKGt2rpp: akg_p + h_p <=> akg_c + h_c
# ACGAMT: uacgam_c + udcpp_c --> ump_c + unaga_c
# XYLt2pp: h_p + xyl__D_p --> h_c + xyl__D_c
# EX_ascb__L_e: ascb__L_e -->
# GLYBtex: glyb_e <=> glyb_p
# GLYCtex: glyc_e <=> glyc_p
# GLYC3Ptex: glyc3p_e <=> glyc3p_p
# GLYCLTtex: glyclt_e <=> glyclt_p
# GTPtex: gtp_e <=> gtp_p
# GUAtex: gua_e <=> gua_p
# Htex: h_e <=> h_p
# EX_ala_B_e: ala_B_e -->
# EX_agm_e: agm_e -->
# EX_minohp_e: minohp_e -->
# EX_ppt_e: ppt_e -->
# EX_hxa_e: hxa_e -->
# H2tex: h2_e <=> h2_p
# H2Otex: h2o_e <=> h2o_p
# AADDGT: dtdp4aaddg_c + unagamu_c --> dtdp_c + h_c + unagamuf_c
# FACOAL160t2pp: atp_c + coa_c + h_p + hdca_p --> amp_c + h_c + pmtcoa_c + ppi_c
# FACOAL180t2pp: atp_c + coa_c + h_p + ocdca_p --> amp_c + h_c + ppi_c + stcoa_c
# SPODMpp: 2.0 h_p + 2.0 o2s_p --> h2o2_p + o2_p
# EX_lyx__L_e: lyx__L_e -->
# EX_acmum_e: acmum_e -->
# EX_dca_e: dca_e -->
# EX_all__D_e: all__D_e -->
# NO3R1bpp: no3_p + q8h2_c --> h2o_p + no2_p + q8_c
# O2tpp: o2_p <=> o2_c
# EX_octa_e: octa_e -->
# PHYTSpp: 6.0 h2o_p + minohp_p --> inost_p + 6.0 pi_p
# EX_gbbtn_e: gbbtn_e -->
# PPTHpp: h2o_p + ppt_p --> h2_p + pi_p
# PYRt2rpp: h_p + pyr_p <=> h_c + pyr_c
# NO3R2pp: 2.0 h_c + mql8_c + no3_c --> h2o_c + 2.0 h_p + mqn8_c + no2_c
# EX_xylu__L_e: xylu__L_e -->
# EX_gdp_e: gdp_e -->
# EX_gtp_e: gtp_e -->
# NTP3pp: gtp_p + h2o_p --> gdp_p + h_p + pi_p
# NO3R2bpp: mql8_c + no3_p --> h2o_p + mqn8_c + no2_p
# THMabcpp: atp_c + h2o_c + thm_p --> adp_c + h_c + pi_c + thm_c
# THMDt2pp_copy2: h_p + thymd_p <=> h_c + thymd_c
# THRabcpp: atp_c + h2o_c + thr__L_p --> adp_c + h_c + pi_c + thr__L_c
# TREptspp: pep_c + tre_p --> pyr_c + tre6p_c
# THD2pp: 2.0 h_p + nadh_c + nadp_c --> 2.0 h_c + nad_c + nadph_c
# TMAOR1pp: h_p + mql8_c + tmao_p --> h2o_p + mqn8_c + tma_p
# TMAOR2pp: 2dmmql8_c + h_p + tmao_p --> 2dmmq8_c + h2o_p + tma_p
# XANtpp: xan_p <=> xan_c
# DAPtex: 15dap_e <=> 15dap_p
# TRPt2rpp: h_p + trp__L_p <=> h_c + trp__L_c
# TYRt2rpp: h_p + tyr__L_p <=> h_c + tyr__L_c
# EX_tma_e: tma_e -->
# URIt2pp_copy1: h_p + uri_p --> h_c + uri_c
# URIt2pp_copy2: h_p + uri_p <=> h_c + uri_c
# VALabcpp: atp_c + h2o_c + val__L_p --> adp_c + h_c + pi_c + val__L_c
# 12PPDStex: 12ppd__S_e <=> 12ppd__S_p
# DDGLCNtex: 2ddglcn_e <=> 2ddglcn_p
# XTSNt2rpp: h_p + xtsn_p <=> h_c + xtsn_c
# XYLabcpp: atp_c + h2o_c + xyl__D_p --> adp_c + h_c + pi_c + xyl__D_c
# GMHEPK: atp_c + gmhep7p_c --> adp_c + gmhep17bp_c + h_c
# XYLUt2pp: h_p + xylu__L_p --> h_c + xylu__L_c
# THRt4pp: na1_p + thr__L_p --> na1_c + thr__L_c
# GALURtex: galur_e <=> galur_p
# GTPCI: gtp_c + h2o_c --> ahdt_c + for_c + h_c
# FDMO: fmnh2_c + isetac_c + o2_c --> fmn_c + gcald_c + h2o_c + h_c + so3_c
# FEOXAMabcpp: atp_c + feoxam_p + h2o_c --> adp_c + feoxam_c + h_c + pi_c
# EX_fruur_e: fruur_e -->
# GALtex: gal_e <=> gal_p
# CBL1abcpp: atp_c + cbl1_p + h2o_c --> adp_c + cbl1_c + h_c + pi_c
# EX_malttr_e: malttr_e -->
# ACACt2pp: acac_p + h_p <=> acac_c + h_c
# ACGAptspp: acgam_p + pep_c --> acgam6p_c + pyr_c
# ACMANAptspp: acmana_p + pep_c --> acmanap_c + pyr_c
# ACNAMt2pp: acnam_p + h_p --> acnam_c + h_c
# GALCTtex: galct__D_e <=> galct__D_p
# GALCTNtex: galctn__D_e <=> galctn__D_p
# GALTtex: galt_e <=> galt_p
# EX_cbi_e: cbi_e -->
# CHOLD: chol_c + nad_c --> betald_c + h_c + nadh_c
# TRE6PS: g6p_c + udpg_c --> h_c + tre6p_c + udp_c
# DRPA: 2dr5p_c --> acald_c + g3p_c
# TKT2: e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# EX_arbtn_fe3_e: arbtn_fe3_e -->
# UDCPDP: h2o_c + udcpdp_c --> h_c + pi_c + udcpp_c
# EX_cpgn_e: cpgn_e -->
# EX_ch4_e: ch4_e -->
# FEENTERabcpp: atp_c + feenter_p + h2o_c --> adp_c + feenter_c + h_c + pi_c
# EX_adocbl_e: adocbl_e -->
# FECRMabcpp: atp_c + fecrm_p + h2o_c --> adp_c + fecrm_c + h_c + pi_c
# TREH: h2o_c + tre_c --> 2.0 glc__D_c
# GAMtex: gam_e <=> gam_p
# GBBTNtex: gbbtn_e <=> gbbtn_p
# ATPS4rpp: adp_c + 4.0 h_p + pi_c <=> atp_c + h2o_c + 3.0 h_c
# INDOLEtex: indole_e <=> indole_p
# ARBt2rpp: arab__L_p + h_p <=> arab__L_c + h_c
# CYTK1: atp_c + cmp_c <=> adp_c + cdp_c
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c
# L_LACtex: lac__L_e <=> lac__L_p
# ACt4pp: ac_p + na1_p --> ac_c + na1_c
# ADEt2rpp: ade_p + h_p <=> ade_c + h_c
# CO2tpp: co2_p <=> co2_c
# DHAtpp: dha_p <=> dha_c
# DMSOR1pp: dmso_p + mql8_c --> dms_p + h2o_p + mqn8_c
# ARGabcpp: arg__L_p + atp_c + h2o_c --> adp_c + arg__L_c + h_c + pi_c
# ADNt2pp_copy1: adn_p + h_p --> adn_c + h_c
# ADNt2pp_copy2: adn_p + h_p <=> adn_c + h_c
# ALAabcpp: ala__L_p + atp_c + h2o_c --> adp_c + ala__L_c + h_c + pi_c
# ALLabcpp: all__D_p + atp_c + h2o_c --> adp_c + all__D_c + h_c + pi_c
# ALLTNt2rpp: alltn_p + h_p <=> alltn_c + h_c
# ARBabcpp: arab__L_p + atp_c + h2o_c --> adp_c + arab__L_c + h_c + pi_c
# ARGAGMt7pp: agm_c + arg__L_p <=> agm_p + arg__L_c
# ASCBptspp: ascb__L_p + pep_c --> ascb6p_c + pyr_c
# CYTK2: atp_c + dcmp_c <=> adp_c + dcdp_c
# ASNt2rpp: asn__L_p + h_p <=> asn__L_c + h_c
# ASPabcpp: asp__L_p + atp_c + h2o_c --> adp_c + asp__L_c + h_c + pi_c
# ASPt2pp: asp__L_p + h_p --> asp__L_c + h_c
# ECOAH8: 3hodcoa_c <=> h2o_c + od2coa_c
# GLCDpp: glc__D_p + h2o_p + q8_c --> glcn_p + h_p + q8h2_c
# GUAtpp: gua_p <=> gua_c
# ASPt2_2pp: asp__L_p + 2.0 h_p --> asp__L_c + 2.0 h_c
# HYD2pp: h2_c + 2.0 h_c + mqn8_c --> 2.0 h_p + mql8_c
# GK1: atp_c + gmp_c <=> adp_c + gdp_c
# HYXNtpp: hxan_p <=> hxan_c
# NACtpp: nac_p --> nac_c
# ASPt2_3pp: asp__L_p + 3.0 h_p --> asp__L_c + 3.0 h_c
# HIStex: his__L_e <=> his__L_p
# FE3DCITabcpp: atp_c + fe3dcit_p + h2o_c --> adp_c + 2.0 cit_c + fe3_c + h_c + pi_c
# HXAtex: hxa_e <=> hxa_p
# HACD1: aacoa_c + h_c + nadh_c <=> 3hbcoa_c + nad_c
# HYXNtex: hxan_e <=> hxan_p
# IDONtex: idon__L_e <=> idon__L_p
# ILEtex: ile__L_e <=> ile__L_p
# INSTtex: inost_e <=> inost_p
# INStex: ins_e <=> ins_p
# Ktex: k_e <=> k_p
# CPGNtonex: cpgn_e + h_p --> cpgn_p + h_c
# GLCRtex: glcr_e <=> glcr_p
# GLCNtex: glcn_e <=> glcn_p
# GLCURtex: glcur_e <=> glcur_p
# GLNtex: gln__L_e <=> gln__L_p
# O2tex: o2_e <=> o2_p
# EX_ppa_e: ppa_e -->
# HACD2: 3ohcoa_c + h_c + nadh_c <=> 3hhcoa_c + nad_c
# OCTAtex: octa_e <=> octa_p
# D_LACtex: lac__D_e <=> lac__D_p
# NTD8pp: dgmp_p + h2o_p --> dgsn_p + pi_p
# ORNtex: orn_e <=> orn_p
# FRULYStex: frulys_e <=> frulys_p
# MALTtexi: malt_e --> malt_p
# ECOAH5: 3hddcoa_c <=> dd2coa_c + h2o_c
# DHFS: atp_c + dhpt_c + glu__L_c --> adp_c + dhf_c + h_c + pi_c
# CITt7pp: cit_p + succ_c --> cit_c + succ_p
# CRNt7pp: crn_p + gbbtn_c --> crn_c + gbbtn_p
# EX_ni2_e: ni2_e <=>
# GLCtex_copy1: glc__D_e --> glc__D_p
# EX_no_e: no_e -->
# CHLabcpp: atp_c + chol_p + h2o_c --> adp_c + chol_c + h_c + pi_c
# DGSNt2pp: dgsn_p + h_p --> dgsn_c + h_c
# FE3DCITtonex: fe3dcit_e + h_p --> fe3dcit_p + h_c
# DINSt2pp: din_p + h_p --> din_c + h_c
# DURIt2pp: duri_p + h_p --> duri_c + h_c
# FE2abcpp: atp_c + fe2_p + h2o_c --> adp_c + fe2_c + h_c + pi_c
# FRUptspp: fru_p + pep_c --> f1p_c + pyr_c
# FUCtpp: fuc__L_p + h_p <=> fuc__L_c + h_c
# EX_fad_e: fad_e -->
# GALCTt2rpp: galct__D_p + h_p <=> galct__D_c + h_c
# GALt2pp: gal_p + h_p --> gal_c + h_c
# ASPtex: asp__L_e <=> asp__L_p
# ABUTt2pp: 4abut_p + h_p --> 4abut_c + h_c
# FUMt2_2pp: fum_p + 2.0 h_p --> fum_c + 2.0 h_c
# FUMt2_3pp: fum_p + 3.0 h_p --> fum_c + 3.0 h_c
# PHEtex: phe__L_e <=> phe__L_p
# FEENTERtonex: feenter_e + h_p --> feenter_p + h_c
# CSNt2pp: csn_p + h_p --> csn_c + h_c
# CYNTt2pp: cynt_p + h_p --> cynt_c + h_c
# CYSabcpp: atp_c + cys__L_p + h2o_c --> adp_c + cys__L_c + h_c + pi_c
# SBTptspp: pep_c + sbt__D_p --> pyr_c + sbt6p_c
# PItex: pi_e <=> pi_p
# TREHpp: h2o_p + tre_p --> 2.0 glc__D_p
# CYTBDpp: 2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_p + q8_c
# CYTDt2pp_copy1: cytd_p + h_p --> cytd_c + h_c
# CYTDt2pp_copy2: cytd_p + h_p <=> cytd_c + h_c
# DADNt2pp: dad_2_p + h_p --> dad_2_c + h_c
# DCYTt2pp: dcyt_p + h_p --> dcyt_c + h_c
# CYTBD2pp: 2.0 h_c + mql8_c + 0.5 o2_c --> h2o_c + 2.0 h_p + mqn8_c
# ACGAMK: acgam_c + atp_c --> acgam6p_c + adp_c + h_c
# ACALDtpp: acald_p <=> acald_c
# ACt2rpp: ac_p + h_p <=> ac_c + h_c
# DDGLCNt2rpp: 2ddglcn_p + h_p <=> 2ddglcn_c + h_c
# RMNtex: rmn_e <=> rmn_p
# EX_meoh_e: meoh_e -->
# EX_fe3dcit_e: fe3dcit_e -->
# EX_fe3hox_e: fe3hox_e -->
# EX_fecrm_e: fecrm_e -->
# EX_feenter_e: feenter_e -->
# EX_feoxam_e: feoxam_e -->
# MALTTRtexi: malttr_e --> malttr_p
# MALTTTRtexi: maltttr_e --> maltttr_p
# MALTPTtexi: maltpt_e --> maltpt_p
# METS: 5mthf_c + hcys__L_c --> h_c + met__L_c + thf_c
# ASPO3: asp__L_c + q8_c --> h_c + iasp_c + q8h2_c
# ASPO5: asp__L_c + fum_c --> h_c + iasp_c + succ_c
# ASPO4: asp__L_c + mqn8_c --> h_c + iasp_c + mql8_c
# EX_3amp_e: 3amp_e -->
# EX_3gmp_e: 3gmp_e -->
# EX_3ump_e: 3ump_e -->
# ASPO6: asp__L_c + o2_c --> h2o2_c + h_c + iasp_c
# EX_cu2_e: cu2_e <=>
# LCTStex: lcts_e <=> lcts_p
# LEUtex: leu__L_e <=> leu__L_p
# LYStex: lys__L_e <=> lys__L_p
# EX_glyc__R_e: glyc__R_e -->
# EX_eca4colipa_e: eca4colipa_e -->
# GLYOX3: h2o_c + mthgxl_c --> h_c + lac__D_c
# FDMO3: ethso3_c + fmnh2_c + o2_c --> acald_c + fmn_c + h2o_c + h_c + so3_c
# LYXtex: lyx__L_e <=> lyx__L_p
# MANtex: man_e <=> man_p
# MAN6Ptex: man6p_e <=> man6p_p
# FDMO4: butso3_c + fmnh2_c + o2_c --> btal_c + fmn_c + h2o_c + h_c + so3_c
# CYSabc2pp: atp_c + cys__L_c + h2o_c --> adp_c + cys__L_p + h_c + pi_c
# BUTSO3abcpp: atp_c + butso3_p + h2o_c --> adp_c + butso3_c + h_c + pi_c
# ETHSO3abcpp: atp_c + ethso3_p + h2o_c --> adp_c + ethso3_c + h_c + pi_c
# MELIBtex: melib_e <=> melib_p
# DMSOtex: dmso_e <=> dmso_p
# DURItex: duri_e <=> duri_p
# EX_mal__D_e: mal__D_e -->
# FRUtex: fru_e <=> fru_p
# FUCtex: fuc__L_e <=> fuc__L_p
# EX_sel_e: sel_e <=>
# EX_hg2_e: hg2_e -->
# O16GLCT1: aragund_c + udpg_c --> garagund_c + h_c + udp_c
# O16AP2pp: o16a2und_p + o16aund_p --> h_p + o16a3und_p + udcpdp_p
# O16AP3pp: o16a3und_p + o16aund_p --> h_p + o16a4und_p + udcpdp_p
# FUMtex: fum_e <=> fum_p
# ACACT5r: accoa_c + dcacoa_c <=> 3oddcoa_c + coa_c
# O16A4Lpp: colipa_p + o16a4und_p --> h_p + o16a4colipa_p + udcpdp_p
# PRASCSi: 5aizc_c + asp__L_c + atp_c --> 25aics_c + adp_c + h_c + pi_c
# MALTATr: accoa_c + malt_c <=> acmalt_c + coa_c
# DHBSH: 23dhbzs_c + h2o_c --> 23dhb_c + ser__L_c
# MALDDH: mal__D_c + nad_c --> co2_c + nadh_c + pyr_c
# FE2tex: fe2_e <=> fe2_p
# NMNtex: nmn_e <=> nmn_p
# ENTERES: enter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + 3.0 h_c
# NO2tex: no2_e <=> no2_p
# TRSARr: 2h3oppan_c + h_c + nadh_c <=> glyc__R_c + nad_c
# DHPS2: 4abz_c + 6hmhptpp_c --> dhpt_c + ppi_c
# FEOXAMUtex: feoxam_un_p + h_p --> feoxam_un_e + h_c
# ARBTNtpp: arbtn_c + h_p --> arbtn_p + h_c
# MTHFC: h2o_c + methf_c <=> 10fthf_c + h_c
# ARBTNtex: arbtn_p + h_p --> arbtn_e + h_c
# MTHFD: mlthf_c + nadp_c <=> methf_c + nadph_c
# LYXI: lyx__L_c --> xylu__L_c
# BUTt2rpp: but_p + h_p <=> but_c + h_c
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c
# QULNS: dhap_c + iasp_c --> 2.0 h2o_c + pi_c + quln_c
# 23CAMPtex: 23camp_e <=> 23camp_p
# 23CCMPtex: 23ccmp_e <=> 23ccmp_p
# 23CUMPtex: 23cump_e <=> 23cump_p
# 23CGMPtex: 23cgmp_e <=> 23cgmp_p
# 3AMPtex: 3amp_e <=> 3amp_p
# 3CMPtex: 3cmp_e <=> 3cmp_p
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c
# ALKP: dhap_c + h2o_c --> dha_c + pi_c
# GDPtex: gdp_e <=> gdp_p
# EX_cobalt2_e: cobalt2_e <=>
# ALAGLUE: LalaDglu_c <=> LalaLglu_c
# FEENTERtpp: enter_c + h_p --> enter_p + h_c
# TMAtex: tma_e <=> tma_p
# EX_pheme_e: pheme_e -->
# TMAOtex: tmao_e <=> tmao_p
# TREtex: tre_e <=> tre_p
# L_LACD3: lac__L_c + mqn8_c --> mql8_c + pyr_c
# FEENTERtex: enter_p + h_p --> enter_e + h_c
# FE3HOXUtpp: fe3hox_un_p + h_p --> fe3hox_un_e + h_c
# FEOXAMUtpp: feoxam_un_c + h_p --> feoxam_un_p + h_c
# FECRMUtpp: fecrm_un_c + h_p --> fecrm_un_p + h_c
# FE3HOXR2: 2.0 fe3hox_c + fmnh2_c --> 2.0 fe2_c + 2.0 fe3hox_un_c + fmn_c + 2.0 h_c
# L_LACD2: lac__L_c + q8_c --> pyr_c + q8h2_c
# ACACT6r: accoa_c + ddcacoa_c <=> 3otdcoa_c + coa_c
# TRPtex: trp__L_e <=> trp__L_p
# PTRCt2pp: h_p + ptrc_p --> h_c + ptrc_c
# GGGABAH: gg4abut_c + h2o_c --> 4abut_c + glu__L_c
# PNTOtex: pnto__R_e <=> pnto__R_p
# FRULYSK: atp_c + frulys_c --> adp_c + frulysp_c + h_c
# FDMO6: fmnh2_c + o2_c + sulfac_c --> fmn_c + glx_c + h2o_c + h_c + so3_c
# TSULtex: tsul_e <=> tsul_p
# TYRtex: tyr__L_e <=> tyr__L_p
# URAtex: ura_e <=> ura_p
# UREAtex: urea_e <=> urea_p
# URItex: uri_e <=> uri_p
# SULFACabcpp: atp_c + h2o_c + sulfac_p --> adp_c + h_c + pi_c + sulfac_c
# ETHSO3tex: ethso3_e <=> ethso3_p
# BUTSO3tex: butso3_e <=> butso3_p
# LIPOtex: lipoate_e <=> lipoate_p
# CYANSTpp: cyan_p + tsul_p --> h_p + so3_p + tcynt_p
# VALtex: val__L_e <=> val__L_p
# XANtex: xan_e <=> xan_p
# MCPST: cyan_c + mercppyr_c --> h_c + pyr_c + tcynt_c
# XYLtex: xyl__D_e <=> xyl__D_p
# PPPNtex: pppn_e <=> pppn_p
# ABUTtex: 4abut_e <=> 4abut_p
# FORtppi: for_c --> for_p
# PHEMEabcpp: atp_c + h2o_c + pheme_c --> adp_c + h_c + pheme_p + pi_c
# METSOX1abcpp: atp_c + h2o_c + metsox_S__L_p --> adp_c + h_c + metsox_S__L_c + pi_c
# PPTtex: ppt_e <=> ppt_p
# GALBDtex: gal_bD_e <=> gal_bD_p
# LIPAHT2ex: colipa_e + h_e + hdca_e --> h2o_e + hacolipa_e
# DATPHs: datp_c + h2o_c + h_c --> ditp_c + nh4_c
# GLCTR1: icolipa_c + udpg_c --> gicolipa_c + h_c + udp_c
# LIPAabcpp: atp_c + h2o_c + lipa_c --> adp_c + h_c + lipa_p + pi_c
# LIPAHTex: h_e + hdca_e + lipa_e --> h2o_e + halipa_e
# LIPACabcpp: atp_c + h2o_c + lipa_cold_c --> adp_c + h_c + lipa_cold_p + pi_c
# ECAP1pp: 2.0 unagamuf_p --> eca2und_p + h_p + udcpdp_p
# PTRCtex: ptrc_e <=> ptrc_p
# UDCPDPpp: h2o_p + udcpdp_p --> h_p + pi_p + udcpp_p
# GGGABADr: ggbutal_c + h2o_c + nadp_c <=> gg4abut_c + 2.0 h_c + nadph_c
# EX_mso3_e: mso3_e -->
# EX_23camp_e: 23camp_e -->
# EX_23cgmp_e: 23cgmp_e -->
# EX_23cump_e: 23cump_e -->
# ECAP2pp: eca2und_p + unagamuf_p --> eca3und_p + h_p + udcpdp_p
# ECA4OALpp: colipa_p + eca4und_p --> eca4colipa_p + h_p + udcpdp_p
# FE3Ri: fadh2_c + 2.0 fe3_c --> fad_c + 2.0 fe2_c + 2.0 h_c
# FE3HOXR3: 2.0 fe3hox_c + rbflvrd_c --> 2.0 fe2_c + 2.0 fe3hox_un_c + 2.0 h_c + ribflv_c
# FEENTERR1: fadh2_c + 2.0 feenter_c --> 2.0 enter_c + fad_c + 2.0 fe2_c + 2.0 h_c
# NODOy: nadph_c + 2.0 no_c + 2.0 o2_c --> h_c + nadp_c + 2.0 no3_c
# PYRtex: pyr_e <=> pyr_p
# GALM2pp: gal_bD_p --> gal_p
# CU1abcpp: atp_c + cu_c + h2o_c --> adp_c + cu_p + h_c + pi_c
# HG2abcpp: atp_c + h2o_c + hg2_c --> adp_c + h_c + hg2_p + pi_c
# FEENTERR3: 2.0 feenter_c + rbflvrd_c --> 2.0 enter_c + 2.0 fe2_c + 2.0 h_c + ribflv_c
# SULFACtex: sulfac_e <=> sulfac_p
# EX_sulfac_e: sulfac_e -->
# EX_butso3_e: butso3_e -->
# GLCTR3: ggagicolipa_c + udpg_c --> gggagicolipa_c + h_c + udp_c
# HEPT4: adphep_LD_c + gggagicolipa_c --> adp_c + colipa_c + h_c
# EX_ethso3_e: ethso3_e -->
# DSERtex: ser__D_e <=> ser__D_p
# LA4NTpp: colipa_p + uLa4n_p --> acolipa_p + udcpp_p
# NODOx: nadh_c + 2.0 no_c + 2.0 o2_c --> h_c + nad_c + 2.0 no3_c
# SERtex: ser__L_e <=> ser__L_p
# NOtex: no_e <=> no_p
# NOtpp: no_p <=> no_c
# NHFRBO: h_c + nadh_c + 2.0 no_c --> h2o_c + n2o_c + nad_c
# N2Otpp: n2o_p <=> n2o_c
# N2Otex: n2o_e <=> n2o_p
# CRNt8pp: crn__D_c + crn_p --> crn__D_p + crn_c
# CRNt2rpp: crn_p + h_p <=> crn_c + h_c
# CRNDt2rpp: crn__D_p + h_p <=> crn__D_c + h_c
# CTBTt2rpp: ctbt_p + h_p <=> ctbt_c + h_c
# 42A12BOOXpp: dopa_p + h2o_p + o2_p --> 34dhpac_p + h2o2_p + nh4_p
# TYROXDApp: h2o_p + o2_p + tym_p --> 4hoxpacd_p + h2o2_p + nh4_p
# PACALDt2rpp: h_p + pacald_p <=> h_c + pacald_c
# PEAMNtex: peamn_e <=> peamn_p
# PACALDtex: pacald_e <=> pacald_p
# LIPOt2pp: h_p + lipoate_p --> h_c + lipoate_c
# AGM4PA: anhgm4p_c + h2o_c --> LalaDgluMdapDala_c + anhgm_c
# RNDR3b: cdp_c + grxrd_c --> dcdp_c + grxox_c + h2o_c
# RNDR4b: grxrd_c + udp_c --> dudp_c + grxox_c + h2o_c
# ACGAL1Ptex: acgal1p_e <=> acgal1p_p
# ACGALtex: acgal_e <=> acgal_p
# GLCUR1Ptex: glcur1p_e <=> glcur1p_p
# UDPGLCURtex: udpglcur_e <=> udpglcur_p
# UDPGALPpp: h2o_p + udpgal_p --> gal1p_p + 2.0 h_p + ump_p
# UACGAMPpp: h2o_p + uacgam_p --> acgam1p_p + 2.0 h_p + ump_p
# UACGALPpp: h2o_p + udpacgal_p --> acgal1p_p + 2.0 h_p + ump_p
# UGLCURPpp: h2o_p + udpglcur_p --> glcur1p_p + 2.0 h_p + ump_p
# FEROpp: 4.0 fe2_p + 4.0 h_p + o2_p --> 4.0 fe3_p + 2.0 h2o_p
# ISETACabcpp: atp_c + h2o_c + isetac_p --> adp_c + h_c + isetac_c + pi_c
# ISETACtex: isetac_e <=> isetac_p
# GUR1PPpp: glcur1p_p + h2o_p --> glcur_p + pi_p
# UDPGtex: udpg_e <=> udpg_p
# ACGAL1PPpp: acgal1p_p + h2o_p --> acgal_p + pi_p
# UDPGALtex: udpgal_e <=> udpgal_p
# ACGAM1Ptex: acgam1p_e <=> acgam1p_p
# UACGAMtex: uacgam_e <=> uacgam_p
# UDPACGALtex: udpacgal_e <=> udpacgal_p
# AM4PCP: anhm4p_c + h2o_c --> ala__D_c + anhm3p_c
# AM3PA: anhm3p_c + h2o_c --> LalaDgluMdap_c + anhm_c
# UM4PCP: h2o_c + um4p_c --> ala__D_c + ugmd_c
# CBLAT: atp_c + cbl1_c + h_c <=> adocbl_c + pppi_c
# NTRIR4pp: 2.0 h_p + 3.0 mql8_c + no2_p --> 2.0 h2o_p + 3.0 mqn8_c + nh4_p
# NTRIR3pp: 2.0 h_p + no2_p + 3.0 q8h2_c --> 2.0 h2o_p + nh4_p + 3.0 q8_c
# INOSTt4pp: inost_p + na1_p --> inost_c + na1_c
# PHEMEtiex: pheme_p --> pheme_e
# AGM3PA: anhgm3p_c + h2o_c --> LalaDgluMdap_c + anhgm_c
# CYANtex: cyan_e <=> cyan_p
# SO3tex: so3_e <=> so3_p
# TCYNTtex: tcynt_e <=> tcynt_p
# ACANTHAT: accoa_c + anth_c --> acanth_c + coa_c
# METSOX2abcpp: atp_c + h2o_c + metsox_R__L_p --> adp_c + h_c + metsox_R__L_c + pi_c
# METSOX1tex: metsox_S__L_e <=> metsox_S__L_p
# METSOX2tex: metsox_R__L_e <=> metsox_R__L_p
# 3UMPtex: 3ump_e <=> 3ump_p
# MSO3abcpp: atp_c + h2o_c + mso3_p --> adp_c + h_c + mso3_c + pi_c
# MSO3tex: mso3_e <=> mso3_p
# FECRMR1: fadh2_c + 2.0 fecrm_c --> fad_c + 2.0 fe2_c + 2.0 fecrm_un_c + 2.0 h_c
# FECRMR2: 2.0 fecrm_c + fmnh2_c --> 2.0 fe2_c + 2.0 fecrm_un_c + fmn_c + 2.0 h_c
# TDP: h2o_c + thmpp_c --> h_c + pi_c + thmmp_c
# 3PEPTabcpp: LalaDgluMdap_p + atp_c + h2o_c --> LalaDgluMdap_c + adp_c + h_c + pi_c
# 4PEPTabcpp: LalaDgluMdapDala_p + atp_c + h2o_c --> LalaDgluMdapDala_c + adp_c + h_c + pi_c
# 3GMPtex: 3gmp_e <=> 3gmp_p
# FALDtpp: fald_p <=> fald_c
# EX_tym_e: tym_e -->
# AGM3Pt2pp: anhgm3p_p + h_p --> anhgm3p_c + h_c
# SO4tex: so4_e <=> so4_p
# AGM4Pt2pp: anhgm4p_p + h_p --> anhgm4p_c + h_c
# AGMt2pp: anhgm_p + h_p --> anhgm_c + h_c
# FECRMexs: fe3_e + fecrm_un_e --> fecrm_e
# ARBTNR1: 2.0 arbtn_fe3_c + fadh2_c --> 2.0 arbtn_c + fad_c + 2.0 fe2_c + 2.0 h_c
# ARBTNR2: 2.0 arbtn_fe3_c + fmnh2_c --> 2.0 arbtn_c + 2.0 fe2_c + fmn_c + 2.0 h_c
# METSOXR1: metsox_S__L_c + trdrd_c --> h2o_c + met__L_c + trdox_c
# ...
# COLIPAKpp: colipa_p + udcpdp_p --> colipap_p + udcpp_p
# ACPPAT120: ddcaACP_c + h_c + pi_c --> ACP_c + ddcap_c
# 3HPPtpp: 3hpp_c + h_c --> 3hpp_p + h_p
# MPTSS: atp_c + h_c + moadcoo_c --> moadamp_c + ppi_c
# CPMPS: gtp_c + h2o_c --> cpmp_c + ppi_c
# LIPOCT: h_c + ocACP_c --> ACP_c + octapb_c
# LIPATPT: atp_c + lipoate_c --> lipoamp_c + ppi_c
# LIPAMPL: lipoamp_c --> amp_c + lipopb_c
# ALDD19xr: h2o_c + nad_c + pacald_c <=> 2.0 h_c + nadh_c + pac_c
# MMM: succoa_c --> mmcoa__S_c
# MOGDS: gtp_c + h_c + moco_c --> mocogdp_c + ppi_c
# CPH4S: ahdt_c + h2o_c --> acald_c + cph4_c + h_c + pppi_c
# WCOS: 2.0 h_c + mptamp_c + tungs_c --> amp_c + cu2_c + h2o_c + wco_c
# RFAMPtpp: h_p + rfamp_p --> h_c + rfamp_e
# SHCHCS3: 2sephchc_c --> 2shchc_c + pyr_c
# VPAMTr: 3mob_c + ala__L_c <=> pyr_c + val__L_c
# ACOLIPAabctex: acolipa_p + atp_c + h2o_c --> acolipa_e + adp_c + h_c + pi_c
# PYK4: cdp_c + h_c + pep_c --> ctp_c + pyr_c
# NADPHXD: adp_c + nadphx__S_c --> amp_c + h_c + nadph_c + pi_c
# NADHHR: h2o_c + nadh_c --> nadhx__R_c
# ECA4COLIPAabctex: atp_c + eca4colipa_p + h2o_c --> adp_c + eca4colipa_e + h_c + pi_c
# EX_ttrcyc_e: ttrcyc_e -->
# COLIPAPabctex: atp_c + colipap_p + h2o_c --> adp_c + colipap_e + h_c + pi_c
# NADPHXE: nadphx__R_c <=> nadphx__S_c
# ALAtpp: ala__L_c --> ala__L_p
# CH4tex: ch4_e <=> ch4_p
# EX_mincyc_e: mincyc_e -->
# TARTRDtex: tartr__D_e <=> tartr__D_p
# DM_4crsol_c: 4crsol_c -->
# 3OXCOAT: coa_c + oxadpcoa_c --> accoa_c + succoa_c
# BTNt2ipp: btn_p + h_p --> btn_c + h_c
# URACPAH: h2o_c + uracp_c --> cbm_c + h_c + poaac_c
# BTNtex: btn_e <=> btn_p
# DHBSZ3FEabcpp: atp_c + fe3dhbzs3_p + h2o_c --> adp_c + fe3dhbzs3_c + h_c + pi_c
# FE3DHBZS3R: 2.0 fe3dhbzs3_c + nadph_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + 3.0 h_c + nadp_c
# DXYLONtpp: dxylnt_p <=> dxylnt_c
# DXYLTD: dxylnt_c <=> 2ddara_c + h2o_c
# 2DDARAA: 2ddara_c <=> gcald_c + pyr_c
# 2DGLCptspp: 2dglc_p + pep_c --> 2doxg6p_c + pyr_c
# 2DGULRGx: 2dhguln_c + h_c + nadh_c --> glcn_c + nad_c
# 2DGULRGy: 2dhguln_c + h_c + nadph_c --> glcn_c + nadp_c
# AP4AS: 2.0 atp_c + h_c --> ap4a_c + ppi_c
# ARBTptspp: arbt_p + pep_c --> arbt6p_c + pyr_c
# ARBTtex: arbt_e --> arbt_p
# EX_arbt_e: arbt_e -->
# GNP: 6pgc_c + h2o_c --> glcn_c + pi_c
# ALLTAMH2: alltt_c + h2o_c + 2.0 h_c --> co2_c + nh4_c + urdgci_c
# UGCIAMH: h2o_c + urdgci_c --> nh4_c + urdglyc_c
# DMSOtpp: dmso_p <=> dmso_c
# POAACR: nadh_c + poaac_c --> 3amac_c + h2o_c + nad_c
# PYDXtex: pydx_e <=> pydx_p
# PYDXtpp: pydx_p --> pydx_c
# SUCASPtpp: asp__L_p + succ_c <=> asp__L_c + succ_p
# METGLCUR: h2o_c + metglcur_c --> glcur_c + meoh_c
# ACOAD1fr: b2coa_c + fadh2_c --> btcoa_c + fad_c
# 23DOGULNt4pp: 23doguln_p + na1_p --> 23doguln_c + na1_c
# FE3DCITexs: 2.0 cit_e + fe3_e --> fe3dcit_e
# SUCMALtpp: mal__L_p + succ_c <=> mal__L_c + succ_p
# PYDXNtex: pydxn_e <=> pydxn_p
# FEENTERES: feenter_c + h2o_c --> fe3dhbzs3_c
# PYDXNtpp: pydxn_p --> pydxn_c
# FEENTERR4: 2.0 feenter_c + nadph_c --> 2.0 enter_c + 2.0 fe2_c + h_c + nadp_c
# ACPPAT160: h_c + palmACP_c + pi_c --> ACP_c + hdcap_c
# DXYLONtex: dxylnt_e <=> dxylnt_p
# PYDAMtex: pydam_e <=> pydam_p
# PYDAMtpp: pydam_p --> pydam_c
# PSURItex: psuri_e <=> psuri_p
# ALR2x: h_c + mthgxl_c + nadh_c --> acetol_c + nad_c
# OMPHHXy: 2omph_c + h_c + nadph_c + o2_c --> 2ombzl_c + h2o_c + nadp_c
# CHLt3pp: chol_c + h_p --> chol_p + h_c
# 13PPDH2: 3hppnl_c + h_c + nadph_c <=> 13ppd_c + nadp_c
# TARTt2_3pp: 3.0 h_p + tartr__D_p --> 3.0 h_c + tartr__D_c
# SUCTARTtpp: succ_c + tartr__D_p <=> succ_p + tartr__D_c
# APCS: 15dap_c + ametam_c --> 5mta_c + h_c + na15dap_c
# CHTBSptspp: chtbs_p + pep_c --> chtbs6p_c + pyr_c
# GLYBt3pp: glyb_c + h_p --> glyb_p + h_c
# AI2tpp: mththf_c --> mththf_p
# ACPPAT181: h_c + octeACP_c + pi_c --> ACP_c + ocdceap_c
# Ftpp: f_c --> f_p
# SQVOSI: sq_c --> sf_c
# 6D6SPA: sfp_c --> dhap_c + sla_c
# CHTBStex: chtbs_e <=> chtbs_p
# TRPtipp: trp__L_c --> trp__L_p
# TYRtipp: tyr__L_c --> tyr__L_p
# ThDPAT: adp_c + h_c + thmpp_c --> athtp_c + pi_c
# GHBDHx: h_c + nadh_c + sucsal_c <=> ghb_c + nad_c
# DHPStr: dhps_c --> dhps_p
# SQtr: sq_p --> sq_c
# DHPStex: dhps_e <=> dhps_p
# APPLDHr: aact_c + h_c + nadh_c <=> appl_c + nad_c
# SPMDt3pp: h_p + spmd_c --> h_c + spmd_p
# FMNtex: fmn_p <=> fmn_e
# APH141: h2o_c + ttdceap_c --> 2.0 h_c + pi_c + ttdcea_c
# EX_dxylnt_e: dxylnt_e -->
# AI2K: atp_c + dhptd_c --> adp_c + dhptdp_c + h_c
# PHEtipp: phe__L_c --> phe__L_p
# G2PP: glyc2p_c + h2o_c --> glyc_c + pi_c
# MALt3pp: h_p + mal__L_c --> h_c + mal__L_p
# CITt3pp: cit_c + h_p --> cit_p + h_c
# APH161: h2o_c + hdceap_c --> 2.0 h_c + hdcea_c + pi_c
# DHNPA2r: dhnpt_c <=> 6hmhpt_c + gcald_c
# QUIN2tpp: quin_p <=> quin_c
# GLYC2Pabcpp: atp_c + glyc2p_p + h2o_c --> adp_c + glyc2p_c + h_c + pi_c
# CRNDtex: crn__D_e <=> crn__D_p
# SHGO: S2hglut_c + o2_c --> akg_c + h2o2_c
# CLBtex: cellb_e <=> cellb_p
# ACOXT: accoa_c + oxa_c <=> ac_c + oxalcoa_c
# EX_mththf_e: mththf_e -->
# 2HESR: dtgcl_c + 2.0 gthrd_c --> gthox_c + 2.0 mercpeth_c
# CHOLID: cholate_c + nad_c --> dhcholn_c + h_c + nadh_c
# CHOLATEtpp: cholate_c + h_p --> cholate_p + h_c
# NADHXD: adp_c + nadhx__S_c --> amp_c + h_c + nadh_c + pi_c
# NADPHHR: h2o_c + nadph_c --> nadphx__R_c
# NADPHHS: h2o_c + nadph_c --> nadphx__S_c
# 4ABZGLUH: 4abzglu_c + h2o_c <=> 4abz_c + glu__L_c
# 4ABZGLUtr: 4abzglu_p + h_p <=> 4abzglu_c + h_c
# NADHHS: h2o_c + nadh_c --> nadhx__S_c
# APH180: h2o_c + ocdcap_c --> 2.0 h_c + ocdca_c + pi_c
# NADHXE: nadhx__S_c <=> nadhx__R_c
# SELabcpp: atp_c + h2o_c + sel_p --> adp_c + h_c + pi_c + sel_c
# PHDA: 5phdt_c + h2o_c --> 5phua_c
# TEO2M: amet_c + teo2_c --> ahcys_c + mteo2_c
# PACOAT: h2o_c + phaccoa_c --> coa_c + h_c + pac_c
# CYSItpp: cysi__L_c --> cysi__L_p
# PYK2: h_c + pep_c + udp_c --> pyr_c + utp_c
# PYK3: gdp_c + h_c + pep_c --> gtp_c + pyr_c
# APH181: h2o_c + ocdceap_c --> 2.0 h_c + ocdcea_c + pi_c
# DHPTDNR: dhptdn_c + 3.0 h_c + nadph_c --> nadp_c + thptdn_c
# DHPTDNRN: dhptdn_c + 3.0 h_c + nadh_c --> nad_c + thptdn_c
# GTHPi: 2.0 gthrd_c + h2o2_c --> gthox_c + 2.0 h2o_c
# SEPHCHCS: akg_c + h_c + ichor_c --> 2sephchc_c + co2_c
# DHNCOAS: h_c + sbzcoa_c --> 14dhncoa_c + h2o_c
# PCNO: nadp_c + ppcoa_c <=> h_c + nadph_c + prpncoa_c
# PYK6: dtdp_c + h_c + pep_c --> dttp_c + pyr_c
# DHNCOAT: 14dhncoa_c + h2o_c --> coa_c + dhna_c + h_c
# FADt: fad_c --> fad_p
# HPACOAT: 34dphacoa_c + h2o_c --> 34dhpha_c + coa_c + h_c
# PUACGAMtr: puacgam_c --> puacgam_p
# DC6PDA: chtbs6p_c + h2o_c --> ac_c + mchtbs6p_c
# 5DGLCNR: 5dglcn_c + h_c + nadph_c --> glcn_c + nadp_c
# PIt2rpp: h_p + pi_p --> h_c + pi_c
# FADtex: fad_p <=> fad_e
# AI2abcpp: atp_c + h2o_c + mththf_p --> adp_c + h_c + mththf_c + pi_c
# PAI2I: dhptdp_c --> dhptdd_c
# 4HBZt3pp: 4hbz_c + h_p --> 4hbz_p + h_c
# CURR: cur_c + h_c + nadph_c --> dhcur_c + nadp_c
# LKDRA: lkdr_c <=> lald__L_c + pyr_c
# LEUt2rpp: h_p + leu__L_p --> h_c + leu__L_c
# LCTStpp: h_p + lcts_p --> h_c + lcts_c
# ILEt3pp: h_p + ile__L_c --> h_c + ile__L_p
# METNA: accoa_c + met__L_c <=> acmet_c + coa_c + h_c
# METt3pp: h_p + met__L_c --> h_c + met__L_p
# FESD1s: 2.0 4fe4s_c + h2o2_c + 2.0 h_c --> 2.0 3fe4s_c + 2.0 fe3_c + 2.0 h2o_c
# GSNt3pp: gsn_c + h_p --> gsn_p + h_c
# CLtipp: cl_p --> cl_c
# 5DKGR: glcn_c + nad_c <=> 5dglcn_c + h_c + nadh_c
# XYHDL: h2o_c + iprimv_c --> glc__D_c + xyl__D_c
# 2DGLCtex: 2dglc_e <=> 2dglc_p
# E4PP: e4p_c + h2o_c --> erthrs_c + pi_c
# PUACGAMS: puacgam_c + udp_c <=> uacgam_c
# PItpp: pi_c --> pi_p
# RU5PP: h2o_c + ru5p__D_c --> pi_c + rbl__D_c
# EX_doxrbcn_e: doxrbcn_e -->
# 6D6SFK: atp_c + sf_c --> adp_c + h_c + sfp_c
# 3SLAR: h_c + nadh_c + sla_c --> dhps_c + nad_c
# LEUt3pp: h_p + leu__L_c --> h_c + leu__L_p
# INSt3pp: h_p + ins_c --> h_c + ins_p
# INDOLEt2rpp: h_p + indole_p --> h_c + indole_c
# SQtex: sq_e <=> sq_p
# ILEt2rpp: h_p + ile__L_p --> h_c + ile__L_c
# GLYtpp: gly_c <=> gly_p
# EX_dhps_e: dhps_e -->
# MOX: mal__L_c + o2_c --> h2o2_c + oaa_c
# URATEtex: urate_e <=> urate_p
# EX_cs1_e: cs1_e -->
# EX_fusa_e: fusa_e -->
# CBL1tonex: cbl1_e + h_p --> cbl1_p + h_c
# CBItonex: cbi_e + h_p --> cbi_p + h_c
# ARHGDx: nad_c + r2hglut_c <=> akg_c + h_c + nadh_c
# CPL: prpmn_c --> ch4_c + prcp_c
# EX_mepn_e: mepn_e -->
# PSURItpp: psuri_p --> psuri_c
# CYSTA: akg_c + cys__L_c --> glu__L_c + mercppyr_c
# FE3DCITR5: 2.0 fe3dcit_c + nadph_c --> 4.0 cit_c + 2.0 fe2_c + h_c + nadp_c
# CH4t2pp: ch4_c --> ch4_p
# EX_cm_e: cm_e -->
# 4HTHRA: 4hthr_c <=> gcald_c + gly_c
# EX_novbcn_e: novbcn_e -->
# I2FE2SR: 2fe1s_c + iscssh_c + iscu_c --> 4.0 h_c + iscs_c + iscu_2fe2s_c
# GAPP: g3p_c + h2o_c --> glyald_c + pi_c
# TYRL: amet_c + nadph_c + tyr__L_c --> 4crsol_c + dad_5_c + dhgly_c + h_c + met__L_c + nadp_c
# METGLCURt2pp: h_p + metglcur_p --> h_c + metglcur_c
# METGLCURtex: metglcur_e <=> metglcur_p
# INOSTO: inost_c + o2_c <=> glcur_c + h2o_c + h_c
# THZPSN3: atp_c + dhgly_c + dxyl5p_c + h_c + iscssh_c + nadph_c --> 4mpetz_c + amp_c + co2_c + 2.0 h2o_c + iscs_c + nadp_c + ppi_c
# HPYRP: 3php_c + h2o_c --> hpyr_c + pi_c
# PSURIK: atp_c + psuri_c --> adp_c + h_c + psd5p_c
# FMNt: fmn_c --> fmn_p
# AI2tex: mththf_e <=> mththf_p
# PAI2T: coa_c + dhptdd_c --> accoa_c + dhap_c
# CUt2pp: cu_c --> cu_p
# Ftex: f_p <=> f_e
# APG3PAT120: ddcap_c + glyc3p_c --> 1ddecg3p_c + h_c + pi_c
# CYSItex: cysi__L_e <=> cysi__L_p
# SERtpp: ser__L_c --> ser__L_p
# QUINDHyi: nadp_c + quin_c --> 3dhq_c + 2.0 h_c + nadph_c
# DHCURR: dhcur_c + h_c + nadph_c --> nadp_c + thcur_c
# RHMND: rhmn_c <=> h2o_c + lkdr_c
# 3HBZCT: 3hbzcoa_c + h2o_c --> 3hbz_c + coa_c
# CXSAMS: amet_c + pphn_c --> cxsam_c + h2o_c + phpyr_c
# EX_2dglc_e: 2dglc_e -->
# THRt2rpp: h_p + thr__L_p --> h_c + thr__L_c
# SERt2rpp: h_p + ser__L_p --> h_c + ser__L_c
# DHGLYH: dhgly_c + h2o_c + h_c --> glx_c + nh4_c
# PNSPA: gmplys_c + h2o_c --> gmp_c + nalme_c
# 4HTHRK: 4hthr_c + atp_c --> adp_c + h_c + phthr_c
# ACOAD1f: btcoa_c + fad_c --> b2coa_c + fadh2_c
# AMPNTAT: accoa_c + ampnt_c --> acampnt_c + coa_c
# EX_sq_e: sq_e -->
# APH120: ddcap_c + h2o_c --> ddca_c + 2.0 h_c + pi_c
# URATEtpp: h_p + urate_p --> h_c + urate_c
# CS1tex: cs1_e <=> cs1_p
# ADOCBLtonex: adocbl_e + h_p --> adocbl_p + h_c
# SQGH: h2o_c + sqg_c --> glyc_c + sq_c
# URAtpp: ura_c --> ura_p
# ASPtpp: asp__L_p <=> asp__L_c
# FUMt1pp: fum_p <=> fum_c
# SUCCt1pp: succ_p <=> succ_c
# QUINDH: nad_c + quin_c --> 3dhq_c + 2.0 h_c + nadh_c
# PETNT181pp: lipa_p + pe181_p --> 12dgr181_p + enlipa_p
# ARMEPNS: atp_c + mepn_c --> ade_c + rpntp_c
# LCARSyi: h_c + lald__L_c + nadph_c --> 12ppd__S_c + nadp_c
# MOCDS: ctp_c + h_c + moco_c --> mococdp_c + ppi_c
# BIOMASS_Ec_iML1515_core_75p37M: 0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223 2ohph_c + 0.00026 4fe4s_c + 0.513689 ala__L_c + 0.000223 amet_c + 0.295792 arg__L_c + 0.241055 asn__L_c + 0.241055 asp__L_c + 75.55223 atp_c + 2e-06 btn_c + 0.005205 ca2_c + 0.005205 cl_c + 0.000576 coa_c + 2.5e-05 cobalt2_c + 0.133508 ctp_c + 0.000709 cu2_c + 0.09158 cys__L_c + 0.026166 datp_c + 0.027017 dctp_c + 0.027017 dgtp_c + 0.026166 dttp_c + 0.000223 fad_c + 0.006715 fe2_c + 0.007808 fe3_c + 0.26316 gln__L_c + 0.26316 glu__L_c + 0.612638 gly_c + 0.215096 gtp_c + 70.028756 h2o_c + 0.094738 his__L_c + 0.290529 ile__L_c + 0.195193 k_c + 0.019456 kdo2lipid4_e + 0.450531 leu__L_c + 0.343161 lys__L_c + 0.153686 met__L_c + 0.008675 mg2_c + 0.000223 mlthf_c + 0.000691 mn2_c + 7e-06 mobd_c + 0.013894 murein5px4p_p + 0.001831 nad_c + 0.000447 nadp_c + 0.013013 nh4_c + 0.000323 ni2_c + 0.063814 pe160_p + 0.075214 pe161_p + 0.185265 phe__L_c + 0.000223 pheme_c + 0.221055 pro__L_c + 0.000223 pydx5p_c + 0.000223 ribflv_c + 0.215792 ser__L_c + 0.000223 sheme_c + 0.004338 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmpp_c + 0.253687 thr__L_c + 0.056843 trp__L_c + 0.137896 tyr__L_c + 5.5e-05 udcpdp_c + 0.144104 utp_c + 0.423162 val__L_c + 0.000341 zn2_c --> 75.37723 adp_c + 75.37723 h_c + 75.37323 pi_c + 0.773903 ppi_c
# BIOMASS_Ec_iML1515_WT_75p37M: 0.000223 10fthf_c + 0.000223 2dmmql8_c + 2.5e-05 2fe2s_c + 0.000248 4fe4s_c + 0.000223 5mthf_c + 0.000279 accoa_c + 0.000223 adocbl_c + 0.499149 ala__L_c + 0.000223 amet_c + 0.28742 arg__L_c + 0.234232 asn__L_c + 0.234232 asp__L_c + 75.55223 atp_c + 2e-06 btn_c + 0.004952 ca2_c + 0.000223 chor_c + 0.004952 cl_c + 0.002944 clpn160_p + 0.00229 clpn161_p + 0.00118 clpn181_p + 0.000168 coa_c + 2.4e-05 cobalt2_c + 0.008151 colipa_e + 0.129799 ctp_c + 0.000674 cu2_c + 0.088988 cys__L_c + 0.024805 datp_c + 0.025612 dctp_c + 0.025612 dgtp_c + 0.024805 dttp_c + 0.000223 enter_c + 0.000223 fad_c + 0.006388 fe2_c + 0.007428 fe3_c + 0.255712 gln__L_c + 0.255712 glu__L_c + 0.595297 gly_c + 0.154187 glycogen_c + 0.000223 gthrd_c + 0.209121 gtp_c + 70.028756 h2o_c + 0.000223 hemeO_c + 0.092056 his__L_c + 0.282306 ile__L_c + 0.18569 k_c + 0.437778 leu__L_c + 3e-06 lipopb_c + 0.333448 lys__L_c + 3.1e-05 malcoa_c + 0.149336 met__L_c + 0.008253 mg2_c + 0.000223 mlthf_c + 0.000658 mn2_c + 7e-06 mobd_c + 7e-06 mococdp_c + 7e-06 mocogdp_c + 0.000223 mql8_c + 0.001345 murein3p3p_p + 0.000605 murein3px4p_p + 0.005381 murein4p4p_p + 0.005448 murein4px4p_p + 0.000673 murein4px4px4p_p + 0.001787 nad_c + 4.5e-05 nadh_c + 0.000112 nadp_c + 0.000335 nadph_c + 0.012379 nh4_c + 0.000307 ni2_c + 0.044164 pe160_p + 0.03435 pe161_p + 0.017704 pe181_p + 0.010599 pg160_p + 0.008244 pg161_p + 0.004249 pg181_p + 0.180021 phe__L_c + 0.000223 pheme_c + 0.214798 pro__L_c + 0.03327 ptrc_c + 0.000223 pydx5p_c + 0.000223 q8h2_c + 0.000223 ribflv_c + 0.209684 ser__L_c + 0.000223 sheme_c + 0.004126 so4_c + 0.006744 spmd_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmpp_c + 0.246506 thr__L_c + 0.055234 trp__L_c + 0.133993 tyr__L_c + 5.5e-05 udcpdp_c + 0.140101 utp_c + 0.411184 val__L_c + 0.000324 zn2_c --> 75.37723 adp_c + 75.37723 h_c + 75.37323 pi_c + 0.749831 ppi_c
# RPNTPH: h2o_c + rpntp_c --> h_c + ppi_c + prpmn_c
# PRCPD: h2o_c + prcp_c --> h_c + r15bp_c
# FUSAtex: fusa_e <=> fusa_p
# MEPNtex: mepn_e <=> mepn_p
# UDPGPT: udcpp_c + udpg_c <=> udcpgl_c + ump_c
# MEPNabcpp: atp_c + h2o_c + mepn_p --> adp_c + h_c + mepn_c + pi_c
# OMMBLHXy: 2ommbl_c + h_c + nadph_c + o2_c --> 2omhmbl_c + h2o_c + nadp_c
# OPHHXy: 2oph_c + h_c + nadph_c + o2_c --> 2ohph_c + h2o_c + nadp_c
# PROD3: pro__L_c + q8_c --> 1pyr5c_c + h_c + q8h2_c
# NOVBCNtex: novbcn_e <=> novbcn_p
# F1PP: f1p_c + h2o_c --> fru_c + pi_c
# ACP1p: fmn_p + h2o_p --> pi_p + ribflv_p
# EX_4abzglu_e: 4abzglu_e -->
# EX_rfamp_e: rfamp_e -->
# 3HPADHi: 3hppnl_c + h2o_c + nad_c --> 3hpp_c + 2.0 h_c + nadh_c
# 4ABZGLUtex: 4abzglu_e <=> 4abzglu_p
# QUIN2tex: quin_e <=> quin_p
# 2HPTCOAT: 2hptcoa_c + h2o_c --> 2hptcl_c + coa_c
# EX_metglcur_e: metglcur_e -->
# EX_quin_e: quin_e -->
# MC6PH: h2o_c + mchtbs6p_c --> acgam6p_c + gam_c
# FORCT: forcoa_c + oxa_c <=> for_c + oxalcoa_c
# SLNTabcpp: atp_c + h2o_c + slnt_p --> adp_c + h_c + pi_c + slnt_c
# VALt2rpp: h_p + val__L_p --> h_c + val__L_c
# DHPTDCs2: dhptd_c --> mdhdhf_c
# VALt3pp: h_p + val__L_c --> h_c + val__L_p
# MN2tipp: mn2_c --> mn2_p
# EX_3hpp_e: 3hpp_e -->
# PACCOAE: h_c + nadph_c + o2_c + phaccoa_c --> h2o_c + nadp_c + rephaccoa_c
# OXDHCOAT: 3oxdhscoa_c + coa_c --> 23dhacoa_c + accoa_c
# HADPCOADH3: 3hadpcoa_c + nad_c <=> h_c + nadh_c + oxadpcoa_c
# O16A4COLIPAabctex: atp_c + h2o_c + o16a4colipa_p --> adp_c + h_c + o16a4colipa_e + pi_c
# COLIPAabctex: atp_c + colipa_p + h2o_c --> adp_c + colipa_e + h_c + pi_c
# ENLIPAabctex: atp_c + enlipa_p + h2o_c --> adp_c + enlipa_e + h_c + pi_c
# DM_mththf_c: mththf_c -->
# PYROX: h_c + nadh_c + o2_c + ura_c --> nad_c + uracp_c
# BMOGDS1: bmoco_c + gtp_c + h_c --> bmoco1gdp_c + ppi_c
# MPTS: cpmp_c + cu2_c + 2.0 moadcosh_c --> 5.0 h_c + 2.0 moadcoo_c + mpt_c
# MOCOS: 2.0 h_c + mobd_c + mptamp_c --> amp_c + cu2_c + h2o_c + moco_c
# BMOGDS2: bmoco1gdp_c + gtp_c + h_c --> bmocogdp_c + ppi_c
# FESD2s: 2.0 4fe4s_c + 2.0 h_c + 2.0 no_c --> 2.0 3fe4s_c + 2.0 fe3_c + h2o_c + n2o_c
# OCTNLL: atp_c + h_c + octa_c --> amp_c + octapb_c + ppi_c
# EX_xh_e: xh_e -->
# EX_8-pnarin_e: 8-pnarin_e -->
# R00697: phe__L_c <=> cinnm_c
# R02253: cinnm_c + nadph_c + o2_c <=> 4hcinnm_c + h2o_c + nadp_c
# R00737: tyr__L_c <=> 4hcinnm_c
# R01616: 4hcinnm_c + atp_c + coa_c <=> 4hcoumcoa_c + amp_c + ppi_c
# R01613: 4hcoumcoa_c + 3.0 malcoa_c <=> 3.0 co2_c + 4.0 coa_c + narinchalc_c
# R02446: narinchalc_c <=> narin_c
# R08003: dmpp_c + narinchalc_c <=> dmxh_c + ppi_c
# R08004: amet_c + dmxh_c <=> ahcys_c + xh_c
# R08951: dmpp_c + narin_c <=> 8-pnarin_c + ppi_c
# 8-xantho_tex: xh_c <=> xh_e
# 8-prenyl_tex: 8-pnarin_c <=> 8-pnarin_e

# %% [markdown]
# ### Validating model

# %%
from pprint import pprint
from cobra.io import write_sbml_model, validate_sbml_model

write_sbml_model(model, filename="edited_e_coli.xml")
report = validate_sbml_model("edited_e_coli.xml")

pprint(report)
# Out:
# (<Model iML1515 at 0x7fe047286fd0>,
#  {'COBRA_CHECK': [],
#   'COBRA_ERROR': [],
#   'COBRA_FATAL': [],
#   'COBRA_WARNING': [],
#   'SBML_ERROR': [],
#   'SBML_FATAL': [],
#   'SBML_SCHEMA_ERROR': [],
#   'SBML_WARNING': []})
